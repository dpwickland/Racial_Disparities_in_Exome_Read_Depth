# %% [markdown]
# # TCGA RACIAL DISPARITY ANALYSIS

# %% [markdown]
# ## LOAD LIBRARIES AND SET ENVIRONMENTAL VARIABLESS

# %%
from IPython.display import display, HTML,IFrame,Image
display(HTML(data="""
<style>
    div#notebook-container    { width: 70%; }
    div#menubar-container     { width: 80%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from notebook.services.config import ConfigManager
c = ConfigManager()
c.update('notebook', {"CodeCell": {"cm_config": {"autoCloseBrackets": False}}})
c.update('notebook', {"CodeCell": {"cm_config": {"lineWrapping": True}}})
# Out:
# <style>
#     div#notebook-container    { width: 70%; }
#     div#menubar-container     { width: 80%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# {'Cell': {'cm_config': {'lineNumbers': True}},
#  'CodeCell': {'cm_config': {'autoCloseBrackets': False, 'lineWrapping': True}}}

# %%
#Note: First needed to install r-essentials via conda:  /home/mayo/m187735/s212975.Wickland_Immunomics/pvactools/conda/bin/conda install --name=jupyter -c conda-forge r-essential

# %env R_HOME=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/pvactools/conda/envs/jupyter/lib/R
#%env LD_LIBRARY_PATH=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/pvactools/conda/envs/jupyter/lib/R/library
#%env PATH=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/pvactools/conda/envs/jupyter/lib/R/lib

# %reload_ext rpy2.ipython
# Out:
# env: R_HOME=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/pvactools/conda/envs/jupyter/lib/R
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/pvactools/conda/envs/jupyter/lib/python3.6/site-packages/rpy2/ipython/rmagic.py:77: UserWarning: The Python package `pandas` is strongly recommended when using `rpy2.ipython`. Unfortunately it could not be loaded (error: this version of pandas is incompatible with numpy < 1.15.4
# your numpy version is 1.12.1.
# Please upgrade numpy to >= 1.15.4 to use this pandas version), but at least we found `numpy`.
#   'but at least we found `numpy`.' % str(ie))

# %%
# %%R
# #install packages using jupyter conda environment
# library(forcats)
# library(ggplot2)
# library(scales)
# library(reshape2)
# library(sjPlot)
# library(lemon)
# library(ggpubr)
# library(repr)
# library(tidyr)
# library(stringr)
# library(plyr)
# library(dplyr)
# library(ggpubr)
# library(shades)
# library(ggforce)
# Out:
# R[write to console]: Registered S3 methods overwritten by 'parameters':
#   method                           from
#   as.double.parameters_kurtosis    datawizard
#   as.double.parameters_skewness    datawizard
#   as.double.parameters_smoothness  datawizard
#   as.numeric.parameters_kurtosis   datawizard
#   as.numeric.parameters_skewness   datawizard
#   as.numeric.parameters_smoothness datawizard
#   print.parameters_distribution    datawizard
#   print.parameters_kurtosis        datawizard
#   print.parameters_skewness        datawizard
#   summary.parameters_kurtosis      datawizard
#   summary.parameters_skewness      datawizard
#
# R[write to console]: Learn more about sjPlot with 'browseVignettes("sjPlot")'.
#
# R[write to console]:
# Attaching package: 'lemon'
#
#
# R[write to console]: The following objects are masked from 'package:ggplot2':
#
#     CoordCartesian, element_render
#
#
# R[write to console]:
# Attaching package: 'tidyr'
#
#
# R[write to console]: The following object is masked from 'package:reshape2':
#
#     smiths
#
#
# R[write to console]:
# Attaching package: 'plyr'
#
#
# R[write to console]: The following object is masked from 'package:ggpubr':
#
#     mutate
#
#
# R[write to console]:
# Attaching package: 'dplyr'
#
#
# R[write to console]: The following objects are masked from 'package:plyr':
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# R[write to console]: The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # PART 1 - CALCULATE TOTAL EXOME READ DEPTH AND CREATE TABLES OF SAMPLE INFORMATION
# ## Group samples by cancer type, by sequencing center, by tumor purity, by sequencing center, by capture kit

# %% [markdown]
# ## A. CALCULATE OVERALL EXOME READ DEPTH
# • For each TCGA patient for given cancer type
# • For mapped reads, all reads, and unmapped reads
# • Now also for HLA region

# %% [markdown]
# ### Script to run: [calc_exome_read_depth_in_batches.sh](./Scripts/calc_exome_read_depth_in_batches.sh)

# %%
# %%bash
#
# for CANCER_NAME in {BRCA,LUAD,COAD,PRAD,UCEC,KIRC,KIRP};
# do
#     bash /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/calc_exome_read_depth_in_batches.sh ${CANCER_NAME} mapped_reads;
#
#     bash /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/calc_exome_read_depth_in_batches.sh ${CANCER_NAME} all_reads;
#
#     bash /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/calc_exome_read_depth_in_batches.sh ${CANCER_NAME} unmapped_reads;
#
#
# done;

# %% [markdown]
# ### For BRCA, also calculate total read depth *within* Nimblegen capture regions -- note that only samples captured by the three nimblegen kits should be retained (do that later, as right now I'm just doing it on all BRCA samples)

# %%
# %%bash
#
# bash /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/calc_exome_read_depth_in_batches.sh BRCA mapped_reads_within_nimblegen_SeqCap_EZ_Exome_v2_hg38liftover_SORTED
#
# bash /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/calc_exome_read_depth_in_batches.sh BRCA mapped_reads_within_nimblegen_SeqCap_EZ_Exome_v3_hg19_capture_targets_hg38liftover_SORTED
#
# bash /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/calc_exome_read_depth_in_batches.sh BRCA mapped_reads_within_nimblegen_hg18_nimblegen_exome_version_2_hg38liftover_SORTED

# %% [markdown]
# ### Combine results of above script

# %%
# %%bash
#
# CANCER_NAME=BRCA
# MAPPED_OR_ALL=mapped_reads_within_nimblegen_SeqCap_EZ_Exome_v2_hg38liftover_SORTED
# #mapped_reads_within_nimblegen_SeqCap_EZ_Exome_v2_hg38liftover_SORTED
# #mapped_reads_within_nimblegen_SeqCap_EZ_Exome_v3_hg19_capture_targets_hg38liftover_SORTED
# #mapped_reads_within_nimblegen_hg18_nimblegen_exome_version_2_hg38liftover_SORTED
#
#
# #when above qsubs are done, run the following to combine everything:
# cat /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/overall_read_depths/${MAPPED_OR_ALL}/${CANCER_NAME}/read_depths*.txt > /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/overall_read_depths/${MAPPED_OR_ALL}/${CANCER_NAME}/all_samples_read_depths.txt
#
# #make sure that number of entries in all_read_depths.txt matches TOTAL_NUMBER_OF_BAMS
# echo "Number of bams with profiled read depths: "`wc -l /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/overall_read_depths/${MAPPED_OR_ALL}/${CANCER_NAME}/all_samples_read_depths.txt | awk '{print $1}'`
# TOTAL_NUMBER_OF_BAMS=`wc -l /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/overall_read_depths/${MAPPED_OR_ALL}/${CANCER_NAME}/${CANCER_NAME}_bam_list.txt | cut -d ' ' -f1`
# echo "Total number of mforge bams for cancer type: "$TOTAL_NUMBER_OF_BAMS
#
# #if above are not equal, pinpoint which file(s) have no read depth output
# # for file in  /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/overall_read_depths/${MAPPED_OR_ALL}/${CANCER_NAME}/*samples*; do echo `basename $file`;cut -f2 $file | wc -l;done;
#
# #manually delete any lines that don't have read depth
#
# #also make sure all analyzed bams are unique
# echo "Number of unique samples with profiled read depths: "`cut -f1 /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/overall_read_depths/${MAPPED_OR_ALL}/${CANCER_NAME}/all_samples_read_depths.txt | sort | uniq | wc -l`

# %% [markdown]
# ## B. Create master table for each cancer type (updated 11/16/2021)
# - Clinical data (from TCGA)
# - Variant data (from protected MAF)
# - Overall exome read depth (from above script)
# - FILTERING STEPS:
#     - Only keep samples with both tumor and matched normal exome bam
#     - For samples with more than one bam for particular tissue type, keep the one with highest read depth

# %% [markdown]
# ### Script to run: [master_table_variants_depths_clinical.R](./Scripts/master_table_variants_depths_clinical.R)

# %%
# %%bash
#
# #note: added one more column to the Immune_Thorsson file (TMB); if downstream problems, revert back to original file
# for CANCER_NAME in {BRCA,LUAD,COAD,UCEC,PRAD,KIRC,KIRP}; do
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/bin/Rscript --vanilla /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/master_table_variants_depths_clinical.R ${CANCER_NAME} mapped_reads exome;done
#
# for CANCER_NAME in {BRCA,LUAD,COAD,UCEC,PRAD,KIRC,KIRP}; do
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/bin/Rscript --vanilla /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/master_table_variants_depths_clinical.R ${CANCER_NAME} all_reads exome;done
#
# for CANCER_NAME in {BRCA,LUAD,COAD,UCEC,PRAD,KIRC,KIRP}; do
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/bin/Rscript --vanilla /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/master_table_variants_depths_clinical.R ${CANCER_NAME} unmapped_reads exome;done
#
#
# CANCER_NAME=BRCA;
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/bin/Rscript --vanilla /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/master_table_variants_depths_clinical.R ${CANCER_NAME} mapped_reads_within_nimblegen_SeqCap_EZ_Exome_v2_hg38liftover_SORTED exome
#
# CANCER_NAME=BRCA;
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/bin/Rscript --vanilla /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/master_table_variants_depths_clinical.R ${CANCER_NAME} mapped_reads_within_nimblegen_SeqCap_EZ_Exome_v3_hg19_capture_targets_hg38liftover_SORTED exome
#
# CANCER_NAME=BRCA;
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/bin/Rscript --vanilla /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/master_table_variants_depths_clinical.R ${CANCER_NAME} mapped_reads_within_nimblegen_hg18_nimblegen_exome_version_2_hg38liftover_SORTED exome
# Out:
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"
# WARNING: ignoring environment value of R_HOME
# [1] "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/lib64/R/library"

# %% [markdown]
# # PART 2 - PLOT PRINCIPAL COMPONENTS OF GENOTYPES OF ALL INDIVIDUALS FROM 7 CANCER TYPES AS WELL AS 1000 GENOMES (updated 11/8/21)

# %% [markdown]
# ## 1. 1000 Genomes Dataset

# %% [markdown]
# ### Download hg38 VCFs
# - See release notes here: http://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/supporting/GRCh38_positions/README_GRCh38_liftover_20170504.txt

# %%
# %%bash
#
# mkdir -p /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38
#
# cd /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38
#
# for i in {1..22}; do wget http://ftp.1000genomes.ebi.ac.uk/vol1/ftp/data_collections/1000_genomes_project/release/20190312_biallelic_SNV_and_INDEL/ALL.chr${i}.shapeit2_integrated_snvindels_v2a_27022019.GRCh38.phased.vcf.gz.tbi;done;

# %% [markdown]
# ### 2. Merge all chromosomes

# %%
# %%bash
#
# cat <(zcat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ALL.chr1.shapeit2_integrated_snvindels_v2a_27022019.GRCh38.phased.vcf.gz | grep -v ^\#\# | head -n1) <(zcat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/*chr*.vcf.gz | grep -v ^\#) > /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr.vcf

# %% [markdown]
# ### 2b. Remove the samples for whom we have no population information and who are NOT EUR or AFR or EAS!
# - Get psam from here: https://www.dropbox.com/s/a3pfx4w2jlru50b/chrM_phase3_corrected.psam?dl=1
# - Make col 3 and col 4 all 0

# %%
# %%bash
#
# awk 'NR==FNR{c[$1]++;next};c[$1] >  0' <(head -n1 /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr.vcf | sed 's/\t/\n/g' | sed -n '10,$p') <(grep -e EUR -e AFR -e EAS /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/chrM_phase3_corrected.psam?dl=1 | cut -f1) > /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/list_of_samples_with_info.txt

# %%
# %%bash
#
# cat <(head -n1 /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/chrM_phase3_corrected.psam?dl=1) <(awk 'NR==FNR{c[$1]++;next};c[$1] >  0' /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/list_of_samples_with_info.txt /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/chrM_phase3_corrected.psam?dl=1) | sed 's/\#//'> /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ThnsdGnms_corrected_use.psam

# %% [markdown]
# ### 3. Convert to plink format (pgen, pvar, psam)

# %%
# %%bash
#
# /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink2 --vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr.vcf --keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/list_of_samples_with_info.txt --make-pgen --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr

# %% [markdown]
# ### 4. Focus on biallelic variants

# %%
# %%bash
#
# /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink2 --pfile /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr --max-alleles 2 --make-bed --chr 1-22 XY --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr

# %% [markdown]
# ### 5. Rename bim file for reference so that each variant named according to chromosomal coordinates

# %%
# %%bash
#
# mv /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr.bim /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr.bim.tmp
# awk  '{ gsub($2,$1":"$4,$2); print}' OFS="\t" /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr.bim.tmp > /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr.bim

# %% [markdown]
# ### 6. Create bed file of those coordinates (78 Mb)
# - For individual loci, do (chr) (locus - 1) (locus)

# %%
# %%bash
#
# awk '{print "chr"$1,$4-1,$4}' OFS='\t' /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr.bim > /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_biallelic_positions.bed

# %% [markdown]
# ### 7. Modify PSAM file for easier plotting later

# %%
# %%R
#
# THSND_GNMS_PSAM <- read.table('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ThnsdGnms_corrected_use.psam',header=TRUE)
# names(THSND_GNMS_PSAM)[5] <- 'Pop'
# THSND_GNMS_PSAM$Pop <- paste0('1000 Genomes: ',THSND_GNMS_PSAM$Pop)
#
#
# write.table(THSND_GNMS_PSAM,paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ThnsdGnms_corrected_use_FOR_PLOT.psam'),sep='\t',row.names=FALSE,quote=FALSE)

# %% [markdown]
# ## 2. Gather and process data: TCGA

# %% [markdown]
# ### Create lists of Normal samples and their bam file locations from seven TCGA cancer types
# - Note that for any individuals with multiple normal bams, only the bam with greatest overall depth is retained (step in one of the above scripts)
# - Autosomes only -- no sex chromosomes

# %%
# %%bash
#
# CANCER_NAME=BRCA
#
# echo "Total no. normal bams: " `grep Blood /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/TCGA_metadata/exome_bams/${CANCER_NAME}_bams_metadata.txt | wc -l`
#
#
# echo "No. (paired) normals with read depth info: " `cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/overall_read_depths_and_sample_information/${CANCER_NAME}_all_reads_exome_master_table.txt | awk '{print $1,$4,$5,$6}' FS='\t' OFS='\t' | awk '$2 == "Blood_Normal" && $3 != 0' FS='\t' | wc -l`
# Out:
# Total no. normal bams:  966
# No. (paired) normals with read depth info:  955

# %%
# %%bash
#
# for CANCER_NAME in BRCA PRAD LUAD UCEC KIRC COAD KIRP; do
#
#    echo " " > /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/TCGA_metadata/exome_bams/${CANCER_NAME}_normals_list_for_ancestry.txt #must create empty first line; otherwise skips when generating qsubs
#
#    cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/overall_read_depths_and_sample_information/${CANCER_NAME}_all_reads_exome_master_table.txt | awk '{print $1,$4,$5,$6}' FS='\t' OFS='\t' | awk '$2 == "Blood_Normal" && $3 != 0' FS='\t' | cut -f1,4 >> /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/TCGA_metadata/exome_bams/${CANCER_NAME}_normals_list_for_ancestry.txt;
#
# done;

# %% [markdown]
# ### Run HaplotypeCaller on those bams

# %%
# %%bash
#
# CANCER_NAME=BRCA
# BAM_LIST=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/TCGA_metadata/exome_bams/${CANCER_NAME}_normals_list_for_ancestry.txt
# BED_FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_biallelic_positions.bed
# OUTPUT_DIR=s212975.Wickland_Immunomics
# #OUTPUT_DIR=s303213.Marenco_RNAseq_A549
# #OUTPUT_DIR=s214917.TCGA_LUAD_AND_LUSC_PROTAC
#
# #create scripts for sets of 2 samples
# TOTAL_NUMBER_OF_BAMS=`wc -l ${BAM_LIST} | cut -d ' ' -f1`
# NUMBER_OF_SPLITS=`echo $((TOTAL_NUMBER_OF_BAMS/2))`
# BAM_LOOP_END=`echo $((NUMBER_OF_SPLITS*2))`
#
# mkdir -p  /home/mayo/m187735/${OUTPUT_DIR}/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/${CANCER_NAME}
# rm -r  /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/${CANCER_NAME}
# mkdir -p /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/${CANCER_NAME}
#
# COUNTER=1
# COUNTER2=3
# #the positional variables in awk correspond to the order of cols in the bam_list.txt generated above
# until [ ${COUNTER} -eq $(($BAM_LOOP_END+3)) ];  do awk -v a=${COUNTER} -v b=${COUNTER2} "NR==a,NR==b" ${BAM_LIST} | while read line; do awk -v CANCER_NAME=${CANCER_NAME} -v BED_FILE=${BED_FILE} -v OUTPUT_DIR=${OUTPUT_DIR} '{print "if [ ! -f /home/mayo/m187735/"OUTPUT_DIR"/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/"CANCER_NAME"/"$1".g.vcf.idx ]; then java -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T HaplotypeCaller -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa -I "$2" -ERC GVCF --intervals "BED_FILE" -o  /home/mayo/m187735/"OUTPUT_DIR"/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/"CANCER_NAME"/"$1".g.vcf;fi"}' OFS='\t' > /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/${CANCER_NAME}_${COUNTER}-${COUNTER2}.qsub;done;COUNTER=`echo $((${COUNTER}+2))`;COUNTER2=`echo $((${COUNTER}+2))`;done;

# %%
# %%bash
#
# CANCER_NAME=BRCA
#
# #submit qsubs
# for file in /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/*qsub; do qsub -l h_vmem=10G -e /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/`basename ${file} .qsub`.err -o /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/${CANCER_NAME}
# Your job 1047298 ("BRCA_933-935.qsub") has been submitted
# Your job 1047299 ("BRCA_935-937.qsub") has been submitted
# Your job 1047300 ("BRCA_937-939.qsub") has been submitted
# Your job 1047301 ("BRCA_939-941.qsub") has been submitted
# Your job 1047302 ("BRCA_941-943.qsub") has been submitted
# Your job 1047303 ("BRCA_943-945.qsub") has been submitted
# Your job 1047304 ("BRCA_945-947.qsub") has been submitted
# Your job 1047305 ("BRCA_947-949.qsub") has been submitted
# Your job 1047306 ("BRCA_949-951.qsub") has been submitted
# Your job 1047307 ("BRCA_95-97.qsub") has been submitted
# Your job 1047308 ("BRCA_951-953.qsub") has been submitted
# Your job 1047309 ("BRCA_953-955.qsub") has been submitted
# Your job 1047310 ("BRCA_955-957.qsub") has been submitted
# Your job 1047311 ("BRCA_97-99.qsub") has been submitted
# Your job 1047312 ("BRCA_99-101.qsub") has been submitted

# %%
# %%bash
# ### LUAD,BRCA STRAGGLES WITH MANUALLY CREATED INDEXES
#
# #echo "java -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T HaplotypeCaller -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa -I /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s214917.TCGA_LUAD_AND_LUSC_PROTAC/processing/C509.TCGA-55-8208-10A-01D-2238-08.1_gdc_realn.bam -ERC GVCF --intervals /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_biallelic_positions.bed -o  /home/mayo/m187735/s214917.TCGA_LUAD_AND_LUSC_PROTAC/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/LUAD/TCGA-55-8208-10A-01D-2238-08.g.vcf" | qsub -l h_vmem=10G -e /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/LUAD/TCGA-55-8208-10A-01D-2238-08.err -o /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/LUAD/TCGA-55-8208-10A-01D-2238-08.OUT -pe threaded 4 -q 1-day,4-day,7-day,30-day -N TCGA-55-8208-10A-01D-2238-08
#
#
#
# #echo "java -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T HaplotypeCaller -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa -I /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s214917.TCGA_LUAD_AND_LUSC_PROTAC/processing/C509.TCGA-62-A46R-10A-01D-A24F-08.1_gdc_realn.bam -ERC GVCF --intervals /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_biallelic_positions.bed -o  /home/mayo/m187735/s214917.TCGA_LUAD_AND_LUSC_PROTAC/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/LUAD/TCGA-62-A46R-10A-01D-A24F-08.g.vcf" | qsub -l h_vmem=10G -e /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/LUAD/TCGA-62-A46R-10A-01D-A24F-08.err -o /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/LUAD/TCGA-62-A46R-10A-01D-A24F-08.OUT -pe threaded 4 -q 1-day,4-day,7-day,30-day -N LUAD_TCGA-62-A46R-10A-01D-A24F-08
#
#
#
# #echo "java -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T HaplotypeCaller -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa -I /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s214917.TCGA_LUAD_AND_LUSC_PROTAC/processing/C509.TCGA-MP-A4TC-10A-01D-A24P-08.5_gdc_realn.bam -ERC GVCF --intervals /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_biallelic_positions.bed -o  /home/mayo/m187735/s214917.TCGA_LUAD_AND_LUSC_PROTAC/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/LUAD/TCGA-MP-A4TC-10A-01D-A24P-08.g.vcf" | qsub -l h_vmem=10G -e /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/LUAD/TCGA-MP-A4TC-10A-01D-A24P-08.err -o /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/LUAD/TCGA-MP-A4TC-10A-01D-A24P-08.OUT -pe threaded 4 -q 1-day,4-day,7-day,30-day -N LUAD_TCGA-MP-A4TC-10A-01D-A24P-08
#
# echo "java -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T HaplotypeCaller -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa -I /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/scratch/52eb322cfa74f917722c18e6d874a7aa_gdc_realn.bam -ERC GVCF --intervals /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_biallelic_positions.bed -o  /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/BRCA/TCGA-A2-A1G1-10A-01D-A13O-09.g.vcf" | qsub -l h_vmem=10G -e /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/BRCA/TCGA-A2-A1G1-10A-01D-A13O-09.err -o /home/mayo/m187735/s303213.Marenco_RNAseq_A549/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/BRCA/TCGA-A2-A1G1-10A-01D-A13O-09.OUT -pe threaded 4 -q 1-day,4-day,7-day,30-day -N BRCA_TCGA-A2-A1G1-10A-01D-A13O-09
# Out:
# Your job 1059396 ("BRCA_TCGA-A2-A1G1-10A-01D-A13O-09") has been submitted

# %% [markdown]
# #### Monitor progress of HaplotypeCaller jobs

# %%
# %%bash
#
#
# CANCER_NAME=BRCA
#
#
# #OUTPUT_DIR=s212975.Wickland_Immunomics
# #OUTPUT_DIR=s303213.Marenco_RNAseq_A549
# #OUTPUT_DIR=s214917.TCGA_LUAD_AND_LUSC_PROTAC
#
#
#
# echo "BAMS COMPLETED: " `ls /home/mayo/m187735/*/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/*idx| wc -l`
#
# echo "BAMS INCOMPLETE: " `awk 'NR==FNR{c[$1]++;next};c[$1] ==  0' <(for file in  /home/mayo/m187735/*/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/*.idx; do basename $file;done | cut -d '.' -f1) <( cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/TCGA_metadata/exome_bams/${CANCER_NAME}_normals_list_for_ancestry.txt | cut -f1 )`
# Out:
# BAMS COMPLETED:  955
# BAMS INCOMPLETE:

# %% [markdown]
# ### Run Genotype GVCFs

# %%
# %%bash
#
# CANCER_NAME=BRCA
#
# #default is nt 6 threaded 7 Xmx49
# #if keeps failing, do nt 11 threaded 12, Xmx79 OR nt 22 threaded 20 Xmx24g
#
# #WHICH_INPUT=s212975.Wickland_Immunomics
# #WHICH_INPUT=s303213.Marenco_RNAseq_A549
# #WHICH_INPUT=s214917.TCGA_LUAD_AND_LUSC_PROTAC
#
#
# INPUT_DIR=/home/mayo/m187735/*/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/NORMALS_FOR_ANCESTRY/${CANCER_NAME}
# OUTPUT_DIR=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}
#
# mkdir -p ${OUTPUT_DIR}/logs
#
# for GVCF in ${INPUT_DIR}/*g.vcf; do GVCFS_LIST="${GVCFS_LIST} --variant ${GVCF}"; done
#
# for CHR in 17 ;do
#
#
#
#     echo "java -Xmx49g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T GenotypeGVCFs -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa ${GVCFS_LIST} -o ${OUTPUT_DIR}/${CANCER_NAME}_chr${CHR}2.vcf  --intervals chr${CHR} --disable_auto_index_creation_and_locking_when_reading_rods -nt 18" | qsub -l h_vmem=50G -e ${OUTPUT_DIR}/logs/${CANCER_NAME}_chr${CHR}2_GenotypeGVCFs.err -o ${OUTPUT_DIR}/logs/${CANCER_NAME}_chr${CHR}2_GenotypeGVCFs.out -q 4-day,1-day,7-day,30-day,lg-mem -pe threaded 16 -N ${CANCER_NAME}_chr${CHR}2_GenotypeGVCFs;done
# Out:
# Your job 1108853 ("BRCA_chr172_GenotypeGVCFs") has been submitted

# %% [markdown]
# ### Combine VCFs within cancers

# %%
# %%bash
#
# CANCER_NAME=BRCA
# OUTPUT_DIR=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}
#
# for VCF in `ls -v ${OUTPUT_DIR}/*vcf`;
#
#         do
#            VCFS_LIST="${VCFS_LIST} --variant ${VCF}"  ;
#          done;
#
#     java -cp /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar org.broadinstitute.gatk.tools.CatVariants -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa ${VCFS_LIST} -out `dirname ${OUTPUT_DIR}`/${CANCER_NAME}.vcf
# Out:
# .........10.........20..
# There were no warn messages.
# INFO  17:04:54,920 HelpFormatter - -------------------------------------------------------
# INFO  17:04:54,922 HelpFormatter - Program Name: org.broadinstitute.gatk.tools.CatVariants
# INFO  17:04:54,925 HelpFormatter - Program Args: -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr1.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr2.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr3.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr4.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr5.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr6.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr7.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr8.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr9.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr10.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr11.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr12.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr13.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr14.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr15.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr16.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr17.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr18.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr19.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/UCEC/UCEC_chr20.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANC ...
# INFO  17:04:54,932 HelpFormatter - Executing as m187735@mforgehn2.mayo.edu on Linux 3.10.0-1160.42.2.el7.x86_64 amd64; OpenJDK 64-Bit Server VM 1.8.0_302-b08.
# INFO  17:04:54,933 HelpFormatter - Date/Time: 2021/11/13 17:04:54
# INFO  17:04:54,933 HelpFormatter - -------------------------------------------------------
# INFO  17:04:54,933 HelpFormatter - -------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Done. ------------------------------------------------------------------------------------------

# %% [markdown]
# ### RUN VQSR

# %%
# %%bash
#
# #set VQSR variables
# REF=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa
# HAPMAP=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/VQSR/hapmap_3.3.hg38.vcf.gz
# OMNI=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/VQSR/1000G_omni2.5.hg38.vcf.gz
# G1000=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/VQSR/1000G_phase1.snps.high_confidence.hg38.vcf.gz
# DBSNP=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/VQSR/Homo_sapiens_assembly38.dbsnp138.vcf
# MILLS=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/VQSR/Mills_and_1000G_gold_standard.indels.hg38.vcf.gz
#
#
# for CANCER in BRCA; do
#
#         rm -r /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER}/logs
#         mkdir -p /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER}/logs
#
#
#
#     INPUT=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER}/${CANCER}.vcf
#     OUTPUT_DIR=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER}
#
#     mkdir -p ${OUTPUT_DIR}/logs
#
#     ############################
#     #SNPs############ NOTE LACK OF INBREEDING COEFFICIENT; THAT DAT JUST NOT PRESENT
#     ############################
#         echo "java -Xmx10g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T VariantRecalibrator -R ${REF} -input ${INPUT} -tranche 100.0 -tranche 99.9 -tranche 99.0 -tranche 90.0 -mode SNP -an QD -an MQ -an MQRankSum -an ReadPosRankSum -an FS -an SOR -resource:hapmap,VCF,known=false,training=true,truth=true,prior=15.0 ${HAPMAP} -resource:omni,known=false,training=true,truth=true,prior=12.0 ${OMNI} -resource:1000G,known=false,training=true,truth=false,prior=10.0 ${G1000} -resource:dbsnp,known=true,training=false,truth=false,prior=2.0 ${DBSNP} -recalFile ${OUTPUT_DIR}/${CANCER}_VQSR_recalibrate_SNPs -tranchesFile ${OUTPUT_DIR}/${CANCER}_VQSR_tranches_SNPs -rscriptFile ${OUTPUT_DIR}/${CANCER}_VQSR_SNPs_only.plots.R --disable_auto_index_creation_and_locking_when_reading_rods --target_titv 3.2
#
#         java -Xmx10g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T ApplyRecalibration -R ${REF} -input ${INPUT} -o ${OUTPUT_DIR}/${CANCER}_VQSR_SNPs_only.vcf  -nt 5 -recalFile ${OUTPUT_DIR}/${CANCER}_VQSR_recalibrate_SNPs -tranchesFile ${OUTPUT_DIR}/${CANCER}_VQSR_tranches_SNPs --ts_filter_level 99.5 -mode SNP" > ${OUTPUT_DIR}/logs/${CANCER}_VQSR.qsub
#
#         ############################
#         #INDELs############
#         ############################
#         echo "java -Xmx10g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T VariantRecalibrator -R ${REF} -input ${OUTPUT_DIR}/${CANCER}_VQSR_SNPs_only.vcf -tranche 100.0 -tranche 99.9 -tranche 99.0 -tranche 90.0 -mode INDEL -an QD -an MQRankSum -an ReadPosRankSum -an FS -an SOR --maxGaussians 4 -resource:mills,known=false,training=true,truth=true,prior=12.0 ${MILLS} -resource:dbsnp,known=true,training=false,truth=false,prior=2.0 ${DBSNP} -recalFile ${OUTPUT_DIR}/${CANCER}_VQSR_SNPs_recalibrate_INDELs -tranchesFile ${OUTPUT_DIR}/${CANCER}_VQSR_SNPs_tranches_INDELs --disable_auto_index_creation_and_locking_when_reading_rods
#
#     java -Xmx10g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T ApplyRecalibration -R ${REF} -input ${OUTPUT_DIR}/${CANCER}_VQSR_SNPs_only.vcf -o ${OUTPUT_DIR}/${CANCER}_VQSR_final.vcf -recalFile ${OUTPUT_DIR}/${CANCER}_VQSR_SNPs_recalibrate_INDELs -tranchesFile ${OUTPUT_DIR}/${CANCER}_VQSR_SNPs_tranches_INDELs --ts_filter_level 99 -mode INDEL" >> ${OUTPUT_DIR}/logs/${CANCER}_VQSR.qsub
#
#         #submit job
#         qsub -l h_vmem=20G -e ${OUTPUT_DIR}/logs/${CANCER}.err -o ${OUTPUT_DIR}/logs/${CANCER}.out -q 1-day -pe threaded 6 ${OUTPUT_DIR}/logs/${CANCER}_VQSR.qsub
#
# done
# Out:
# Your job 1116535 ("BRCA_VQSR.qsub") has been submitted

# %% [markdown]
# ### Select the PASS variants and modify sample names

# %%
# %%bash
#
# for CANCER_NAME in BRCA;do
#
#     FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/${CANCER_NAME}_VQSR_final.vcf
#
#     echo "awk '/#/ || /PASS/' ${FILE} | sed 's/H_LS/TCGA/g' | sed 's/H_LK/TCGA/g' | sed 's/H_LR/TCGA/g' | sed 's/Pooled_DNA-2011-03/TCGA-AQ-A04L/' > `dirname ${FILE}`/`basename ${FILE} .vcf`_PASS.vcf" |  qsub -l h_vmem=4G -e /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/logs/${CANCER_NAME}_PASS.err -o /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/logs/${CANCER_NAME}_PASS.out -q 1-day,lg-mem -pe threaded 1 -N ${CANCER_NAME}_PASS;
#
# done;
# Out:
# Your job 1116928 ("BRCA_PASS") has been submitted

# %% [markdown]
# ### Remove HLA, LCT, 8p and 17 q regions; Remove multiallelic positions
# - HLA: chr6:28,477,797-33,448,354 ((https://www.ncbi.nlm.nih.gov/grc/human/regions/MHC?asm=GRCh38))
# - LCT: chr2:136,545,420-136,594,754 ((https://www.ncbi.nlm.nih.gov/genome/gdv/browser/gene/?id=3938 // https://www.ncbi.nlm.nih.gov/gene?Cmd=DetailsSearch&Term=3938))
# - 8p: 0-45600000 ((https://hgdownload.cse.ucsc.edu/goldenPath/hg38/database/cytoBand.txt.gz))
# - 17q: 24000000-81195210 ((https://hgdownload.cse.ucsc.edu/goldenPath/hg38/database/cytoBand.txt.gz))
# - Biallelic alleles only

# %%
# %%bash
#
# for CANCER_NAME in BRCA;do
#
#     FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/${CANCER_NAME}_VQSR_final_PASS.vcf
#
# echo "/home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink2 --vcf ${FILE} --exclude range /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/VQSR/HLA_LCT_8p_17q_for_TCGA_racial_hg38.bed --make-bed --max-alleles 2 --out `dirname ${FILE}`/`basename ${FILE} .vcf`_biallelic_without_HLA_LCT_8p_17q --const-fid" | qsub -l h_vmem=10G -e /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/logs/${CANCER_NAME}_PASS_biallelic_without_HLA_LCT_8p_17q.err -o /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/logs/${CANCER_NAME}_PASS_biallelic_without_HLA_LCT_8p_17q.out -q 1-day,lg-mem -pe threaded 4 -N ${CANCER_NAME}_filter1;
# done
# Out:
# Your job 1119054 ("BRCA_filter1") has been submitted

# %% [markdown]
# ### Remove variants with LD > 0.20 in 0.1 MB windows

# %%
# %%bash
#
# for CANCER_NAME in BRCA;do
#
#     FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/${CANCER_NAME}_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q
#
#     echo "/home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink1.9/plink  --bfile ${FILE} --recode vcf --out ${FILE}; /home/mayo/m187735/s212975.Wickland_Immunomics/tools/bcftools-1.10.2/bin/bcftools +prune ${FILE}.vcf  -l 0.20 -w 100kb -Ov -o ${FILE}_LDlessThan02_Window100kb.vcf" | qsub -l h_vmem=10G -e /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/logs/${CANCER_NAME}_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb.err -o /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/logs/${CANCER_NAME}_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb.out -q 1-day,lg-mem -pe threaded 4 -N ${CANCER_NAME}_filter2;
#     done
# Out:
# Your job 1119073 ("BRCA_filter2") has been submitted

# %% [markdown]
# ### Remove variants with HWE < 0.0005 & MAF

# %%
# %%bash
#
# for CANCER_NAME in BRCA;do
#
#     FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/${CANCER_NAME}_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb.vcf
#
#     echo "/home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink2 --vcf ${FILE} --keep-allele-order  --export vcf --maf .05 --hwe .00001 --out `dirname ${FILE}`/`basename ${FILE} .vcf`_HWE00001_MAF05 --const-fid" |  qsub -l h_vmem=10G -e /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/logs/${CANCER_NAME}_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05.err -o /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/logs/${CANCER_NAME}_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05.out -q 1-day,lg-mem -pe threaded 4 -N ${CANCER_NAME}_filter3;
#     done;
# Out:
# Your job 1119392 ("BRCA_filter3") has been submitted

# %%
# %%bash
# ### make ped files from above
#
# for CANCER_NAME in BRCA; do
#     VCF=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/${CANCER_NAME}_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05.vcf
#
#     /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink2 --vcf ${VCF} --make-bed  --out `dirname ${VCF}`/`basename ${VCF} .vcf` --const-fid;
# done
# Out:
# PLINK v2.00a3LM 64-bit Intel (11 Oct 2021)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05.log.
# Options in effect:
#   --const-fid
#   --make-bed
#   --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05
#   --vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05.vcf
#
# Start time: Thu Nov 18 07:08:28 2021
# 773957 MiB RAM detected; reserving 386978 MiB for main workspace.
# Using up to 80 threads (change this with --threads).
# --vcf: 20478 variants scanned.
# --vcf:
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05-temporary.pgen
# +
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05-temporary.pvar.zst
# +
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05-temporary.psam
# written.
# 955 samples (0 females, 0 males, 955 ambiguous; 955 founders) loaded from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05-temporary.psam.
# 20478 variants loaded from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05-temporary.pvar.zst.
# Note: No phenotype data present.
# Writing
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05.fam
# ... done.
# Writing
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05.bim
# ... done.
# Writing
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05.bed
# done.
# End time: Thu Nov 18 07:08:29 2021

# %% [markdown]
# ### Rename bim file for TCGA so that each variant named according to chromosomal coordinates

# %%
# %%bash
#
# for CANCER_NAME in BRCA; do
#
#     FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/${CANCER_NAME}_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05.bim
#
#     mv ${FILE} ${FILE}.tmp
#
#     awk  '{ gsub($2,$1":"$4,$2); print}' OFS="\t" ${FILE}.tmp > ${FILE}
#
#
#     rm ${FILE}.tmp;
# done;

# %% [markdown]
# ###  Create psam file for TCGA files; sample information (i.e. race)

# %%
# %%R
#
#
# for (CANCER_NAME in c('COAD','UCEC','KIRP','KIRC','PRAD','LUAD','BRCA')){
#
#     system(paste0("mkdir -p /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/",CANCER_NAME))
#
#     SAMPLE_INFO <- read.table(paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/overall_read_depths_and_sample_information/',CANCER_NAME,'_all_reads_exome_master_table.txt'),header=TRUE,sep='\t')[,c('submitter_id_long','race')]
#     SAMPLE_INFO$PAT=0
#     SAMPLE_INFO$MAT=0
#     SAMPLE_INFO$SEX=1
#     names(SAMPLE_INFO)[1:2] <- c('IID','Pop')
#
#     SAMPLE_INFO$Pop <- paste0('TCGA: ',SAMPLE_INFO$Pop)
#
#     write.table(x=SAMPLE_INFO,file=paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/',CANCER_NAME,'/',CANCER_NAME,'_sample_info.txt'),sep='\t',row.names=FALSE,quote=FALSE)
#
# }

# %% [markdown]
# ## 3. Joint PCA analysis of 1000 Genomes and TCGA

# %% [markdown]
# ### 1. Identify shared/overlapping variants between the two datasets#

# %%
# %%bash
#
# for CANCER_NAME in BRCA; do
#
#
# STUDY_FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/${CANCER_NAME}_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05
#
# awk 'NR==FNR{c[$1$2$4$5$6]++;next};c[$1$2$4$5$6] >  0' ${STUDY_FILE}.bim /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr.bim | cut -f2 > /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/shared_SNPs_TCGA_${CANCER_NAME}_1000G.txt ;
# done

# %% [markdown]
# ### 2. Extract shared/overlapping variants from both reference (1000 Genomes) and study (TCGA) dataset

# %%
# %%bash
#
# for CANCER_NAME in BRCA; do
#
#     SHARED_POSITIONS=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/shared_SNPs_TCGA_${CANCER_NAME}_1000G.txt
#
#     REF_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr
#
#     STUDY_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/${CANCER_NAME}/${CANCER_NAME}_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05
#
#     #Reference (1000 Genomes)
#     /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink2 --bfile ${REF_BFILE} --keep-allele-order --extract ${SHARED_POSITIONS} --make-bed --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/1000G_overlap_with_TCGA_${CANCER_NAME}
#
#     #Study (TCGA)
#     /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink2 --bfile ${STUDY_BFILE} --keep-allele-order --extract ${SHARED_POSITIONS}  --make-bed --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/TCGA_${CANCER_NAME}_overlap_with_1000G;
# done
# Out:
# PLINK v2.00a3LM 64-bit Intel (11 Oct 2021)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA.log.
# Options in effect:
#   --bfile /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr
#   --extract /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/shared_SNPs_TCGA_BRCA_1000G.txt
#   --keep-allele-order
#   --make-bed
#   --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA
#
# Start time: Thu Nov 18 07:13:50 2021
# Note: --keep-allele-order no longer has any effect.
# 773957 MiB RAM detected; reserving 386978 MiB for main workspace.
# Using up to 80 threads (change this with --threads).
# 1666 samples (0 females, 0 males, 1666 ambiguous; 1666 founders) loaded from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr.fam.
# 78122255 variants loaded from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Thnsd_Gnms_all_chr.bim.
# Note: No phenotype data present.
# --extract: 17889 variants remaining.
# 17889 variants remaining after main filters.
# Writing
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA.fam
# ... done.
# Writing
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA.bim
# ... done.
# Writing
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA.bed
# done.
# End time: Thu Nov 18 07:15:03 2021
# PLINK v2.00a3LM 64-bit Intel (11 Oct 2021)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G.log.
# Options in effect:
#   --bfile /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05
#   --extract /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/shared_SNPs_TCGA_BRCA_1000G.txt
#   --keep-allele-order
#   --make-bed
#   --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G
#
# Start time: Thu Nov 18 07:15:03 2021
# Note: --keep-allele-order no longer has any effect.
# 773957 MiB RAM detected; reserving 386978 MiB for main workspace.
# Using up to 80 threads (change this with --threads).
# 955 samples (0 females, 0 males, 955 ambiguous; 955 founders) loaded from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05.fam.
# 20478 variants loaded from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/NORMALS_FOR_ANCESTRY/BRCA/BRCA_VQSR_final_PASS_biallelic_without_HLA_LCT_8p_17q_LDlessThan02_Window100kb_HWE00001_MAF05.bim.
# Note: No phenotype data present.
# --extract: 17820 variants remaining.
# 17820 variants remaining after main filters.
# Writing
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G.fam
# ... done.
# Writing
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G.bim
# ... done.
# Writing
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G.bed
# done.
# End time: Thu Nov 18 07:15:03 2021

# %% [markdown]
# ### Attempt merge; will likely fail, but this step needed to get list of 'missnps'

# %%
# %%bash
#
# for CANCER_NAME in BRCA; do
#
#     STUDY_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/TCGA_${CANCER_NAME}_overlap_with_1000G
#     REF_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/1000G_overlap_with_TCGA_${CANCER_NAME}
#     OUT_FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/combined_1000G_TCGA_${CANCER_NAME}
#
#     #Attempt merge
#     /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink1.9/plink --bfile ${STUDY_BFILE} --bmerge ${REF_BFILE} --make-bed --out ${OUT_FILE};
# done
#
#     #Merge likely to fail due to multiallelic sites, but still needed to run this to get list of "missnps" to remove from each dataset
# Out:
# PLINK v1.90b6.21 32-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA.log.
# Options in effect:
#   --bfile /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G
#   --bmerge /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA
#   --make-bed
#   --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA
#
# 773957 MB RAM detected; reserving 2047 MB for main workspace.
# 955 people loaded from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G.fam.
# 1666 people to be merged from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA.fam.
# Of these, 1666 are new, while 0 are present in the base dataset.
# 17820 markers loaded from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G.bim.
# 17889 markers to be merged from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA.bim.
# Of these, 0 are new, while 17889 are present in the base dataset.
# Error: 69 variants with 3+ alleles present.
# * If you believe this is due to strand inconsistency, try --flip with
#   /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA-merge.missnp.
#   (Warning: if this seems to work, strand errors involving SNPs with A/T or C/G
#   alleles probably remain in your data.  If LD between nearby SNPs is high,
#   --flip-scan should detect them.)
# * If you are dealing with genuine multiallelic variants, we recommend exporting
#   that subset of the data to VCF (via e.g. '--recode vcf'), merging with
#   another tool/script, and then importing the result; PLINK is not yet suited
#   to handling them.
# See https://www.cog-genomics.org/plink/1.9/data#merge3 for more discussion.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-14-37e2cfc3cd87> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', '\nfor CANCER_NAME in BRCA; do\n\n    STUDY_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/TCGA_${CANCER_NAME}_overlap_with_1000G\n    REF_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/1000G_overlap_with_TCGA_${CANCER_NAME}\n    OUT_FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/combined_1000G_TCGA_${CANCER_NAME}\n\n    #Attempt merge\n    /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink1.9/plink --bfile ${STUDY_BFILE} --bmerge ${REF_BFILE} --make-bed --out ${OUT_FILE};\ndone\n\n    #Merge likely to fail due to multiallelic sites, but still needed to run this to get list of "missnps" to remove from each dataset\n')
#
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/pvactools/conda/envs/jupyter/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2369             with self.builtin_trap:
#    2370                 args = (magic_arg_s, cell)
# -> 2371                 result = fn(*args, **kwargs)
#    2372             return result
#    2373
#
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/pvactools/conda/envs/jupyter/lib/python3.6/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-110> in shebang(self, line, cell)
#
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/pvactools/conda/envs/jupyter/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/pvactools/conda/envs/jupyter/lib/python3.6/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nfor CANCER_NAME in BRCA; do\n\n    STUDY_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/TCGA_${CANCER_NAME}_overlap_with_1000G\n    REF_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/1000G_overlap_with_TCGA_${CANCER_NAME}\n    OUT_FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/combined_1000G_TCGA_${CANCER_NAME}\n\n    #Attempt merge\n    /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink1.9/plink --bfile ${STUDY_BFILE} --bmerge ${REF_BFILE} --make-bed --out ${OUT_FILE};\ndone\n\n    #Merge likely to fail due to multiallelic sites, but still needed to run this to get list of "missnps" to remove from each dataset\n'' returned non-zero exit status 3.

# %% [markdown]
# ###  Remove missnps from dataset (i.e. loci with too many variants)

# %%
# %%bash
#
#
# for CANCER_NAME in BRCA; do
#
#     STUDY_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/TCGA_${CANCER_NAME}_overlap_with_1000G
#     REF_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/1000G_overlap_with_TCGA_${CANCER_NAME}
#
#     MISSNPS=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/combined_1000G_TCGA_${CANCER_NAME}
#
#     STUDY_OUT_FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/TCGA_${CANCER_NAME}_overlap_with_1000G_fixed
#     REF_OUT_FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/1000G_overlap_with_TCGA_${CANCER_NAME}_fixed
#
#
#     #reference
#     /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink1.9/plink --bfile ${REF_BFILE} --keep-allele-order --exclude ${MISSNPS}-merge.missnp  --make-bed  --out ${REF_OUT_FILE}
#
#     #study
#     /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink1.9/plink --bfile ${STUDY_BFILE}  --keep-allele-order --exclude ${MISSNPS}-merge.missnp --make-bed --out ${STUDY_OUT_FILE};
#
# done
# Out:
# PLINK v1.90b6.21 32-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA_fixed.log.
# Options in effect:
#   --bfile /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA
#   --exclude /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA-merge.missnp
#   --keep-allele-order
#   --make-bed
#   --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA_fixed
#
# 773957 MB RAM detected; reserving 2047 MB for main workspace.
# 17889 variants loaded from .bim file.
# 1666 people (0 males, 0 females, 1666 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA_fixed.nosex
# .
# --exclude: 17751 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1666 founders and 0 nonfounders present.
#  done.
# 17751 variants and 1666 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA_fixed.bed
# +
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA_fixed.bim
# +
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA_fixed.fam
# done.
# PLINK v1.90b6.21 32-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G_fixed.log.
# Options in effect:
#   --bfile /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G
#   --exclude /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA-merge.missnp
#   --keep-allele-order
#   --make-bed
#   --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G_fixed
#
# 773957 MB RAM detected; reserving 2047 MB for main workspace.
# 17820 variants loaded from .bim file.
# 955 people (0 males, 0 females, 955 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G_fixed.nosex
# .
# --exclude: 17751 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 955 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.937606.
# 17751 variants and 955 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G_fixed.bed
# +
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G_fixed.bim
# +
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G_fixed.fam
# done.

# %% [markdown]
# ### Re-attempt merge

# %%
# %%bash
#
# for CANCER_NAME in BRCA; do
#
#     STUDY_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/TCGA_${CANCER_NAME}_overlap_with_1000G_fixed
#     REF_BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/1000G_overlap_with_TCGA_${CANCER_NAME}_fixed
#     OUT_FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/combined_1000G_TCGA_${CANCER_NAME}_fixed
#
#     #Re-attempt merge
#     /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink1.9/plink --bfile ${STUDY_BFILE} --bmerge ${REF_BFILE} --make-bed --out ${OUT_FILE};
#
# done;
#
# #Rename fam file for easier plotting
# #cp /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/ADSP/pruned_SNPs_for_substructure_analysis/Ancestry/ADSP_overlap_with_1000Genomes_fixed.fam /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/ADSP/pruned_SNPs_for_substructure_analysis/Ancestry/ADSP.fam
# Out:
# PLINK v1.90b6.21 32-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed.log.
# Options in effect:
#   --bfile /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G_fixed
#   --bmerge /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA_fixed
#   --make-bed
#   --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed
#
# 773957 MB RAM detected; reserving 2047 MB for main workspace.
# 955 people loaded from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G_fixed.fam.
# 1666 people to be merged from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA_fixed.fam.
# Of these, 1666 are new, while 0 are present in the base dataset.
# 17751 markers loaded from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/TCGA_BRCA_overlap_with_1000G_fixed.bim.
# 17751 markers to be merged from
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/1000G_overlap_with_TCGA_BRCA_fixed.bim.
# Of these, 0 are new, while 17751 are present in the base dataset.
# Performing single-pass merge (2621 people, 17751 variants).
# Merged fileset written to
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed-merge.bed
# +
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed-merge.bim
# +
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed-merge.fam
# .
# 17751 variants loaded from .bim file.
# 2621 people (0 males, 0 females, 2621 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2621 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.977266.
# 17751 variants and 2621 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed.bed
# +
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed.bim
# +
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed.fam
# done.

# %% [markdown]
# ### PCA

# %%
# %%bash
#
# for CANCER_NAME in BRCA; do
#
#     BFILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/${CANCER_NAME}/combined_1000G_TCGA_${CANCER_NAME}_fixed
#
#     /home/mayo/m187735/s212975.Wickland_Immunomics/tools/plink1.9/plink --bfile ${BFILE} --pca --out ${BFILE};
#
# done;
# Out:
# PLINK v1.90b6.21 32-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed.log.
# Options in effect:
#   --bfile /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed
#   --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed
#   --pca
#
# 773957 MB RAM detected; reserving 2047 MB for main workspace.
# 17751 variants loaded from .bim file.
# 2621 people (0 males, 0 females, 2621 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed.nosex
# .
# Using up to 79 threads (change this with --threads).
# Before main variant filters, 2621 founders and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.977266.
# 17751 variants and 2621 people pass filters and QC.
# Note: No phenotypes present.
# Relationship matrix calculation complete.
# --pca: Results saved to
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed.eigenval
# and
# /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/BRCA/combined_1000G_TCGA_BRCA_fixed.eigenvec
# .

# %% [markdown]
# ## 4. PLOT PCA-classified ancestry and add to master tables

# %%
# %%R
#
# TCGA_samples_all <- data.frame()
# TCGA_samples_summary_all <- data.frame()
# data_all_cancers <- data.frame()
#
# for (CANCER_NAME in c('BRCA','UCEC','PRAD','LUAD','COAD','KIRP','KIRC')){
#
# TCGA_FAM=paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/',CANCER_NAME,'/TCGA_',CANCER_NAME,'_overlap_with_1000G_fixed.fam')
# EIGENVEC=paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/',CANCER_NAME,'/combined_1000G_TCGA_',CANCER_NAME,'_fixed.eigenvec') # the eigenvec file
# refSamplesFile=paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ThnsdGnms_corrected_use_FOR_PLOT.psam')
# refSamplesPop='Pop'
# refSamplesIID = 'IID'
# studySamplesFile=paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/ANCESTRY_ANALYSIS_FOR_TCGA/',CANCER_NAME,'/',CANCER_NAME,'_sample_info.txt')
#
# refColorsFile=paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Colors_Populations.txt')
# studyColorsFile=paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/ThsndGnms/hg38/Colors_TCGA.txt')
#
#
#
#   samples <- read.table(TCGA_FAM,header=FALSE)[, 1:2]
#   samples$V2 <- gsub("0_TCGA","TCGA",samples$V2)
#   colnames(samples) <- c("FID", "IID")
#
#   pca_data <- read.table(EIGENVEC,header=FALSE, stringsAsFactors = FALSE)
#   colnames(pca_data) <- c("FID", "IID", paste("PC", 1:(ncol(pca_data) - 2), sep = ""))
#   pca_data$IID <- gsub("0_TCGA","TCGA",pca_data$IID)  #DW
#   #some end in -1 for some reason; get rid of that!
#   pca_data$IID <- gsub("-1$","",pca_data$IID)
#
#   refSamples <- read.table(refSamplesFile, header = TRUE, stringsAsFactors = FALSE,sep='\t') #DW
#   names(refSamples)[names(refSamples) == refSamplesIID] <- "IID"
#   names(refSamples)[names(refSamples) == refSamplesPop] <- "Pop"
#   refSamples <- dplyr::select_(refSamples, ~IID, ~Pop)
#   refSamples$IID <- as.character(refSamples$IID)
#   refSamples$Pop <- as.character(refSamples$Pop)
#   studySamples <- read.table(studySamplesFile,header=TRUE,sep='\t')[,c('IID','Pop')] #DW
#
#   refColors <- read.table(refColorsFile, header = TRUE, stringsAsFactors = FALSE)
#   studyColors <- read.table(studyColorsFile,header=TRUE) #DW
#
#   refSamples <- merge(refSamples, refColors, by = "Pop", all.X = TRUE)
#   studySamples <- merge(studySamples,studyColors, by = 'Pop',all.X=TRUE) #DW
#   allSamples <- rbind(refSamples,studySamples) #DW
#
#   data_all <- merge(pca_data, allSamples, by = "IID", all.x = TRUE) #DW
#   data_all$Color <- as.factor(data_all$Color)
#
#
#
#
#   ##direction of values is irrelevant, so fine to reverse sign
#   if (CANCER_NAME == 'UCEC' | CANCER_NAME == 'KIRP'){data_all$PC1 <- data_all$PC1*-1}
#   if (CANCER_NAME == 'BRCA'){data_all$PC2 <- data_all$PC2*-1}
#
#   data_all$CANCER <- CANCER_NAME
#
#
#
#   data_all$Pop <- factor(data_all$Pop, levels=c('1000 Genomes: EAS','1000 Genomes: EUR','1000 Genomes: AFR','  ','',' ','TCGA: Asian','TCGA: White','TCGA: Black','TCGA: American Indian / Alaska Native','TCGA: Native Hawaiian / Pacific Islander','TCGA: Not reported'),ordered=TRUE)
#
#
#
#   #number of samples misclassified by TCGA
#   TCGA_samples <- data_all[grepl('TCGA',data_all$IID),][,c('IID','PC1','PC2','Pop','Color')]
#   TCGA_samples$PCA_ANCESTRY <- ifelse(TCGA_samples$PC2 < -0.01 & TCGA_samples$PC1 < 0,'EUR',ifelse(TCGA_samples$PC2 > -0.015 & TCGA_samples$PC1 > 0, 'AFR',NA))
#
#   TCGA_samples <- TCGA_samples[,c('IID','Pop','PCA_ANCESTRY')]
#   names(TCGA_samples) <- c('submitter_id','race_self_reported','ancestry_PCA')
#   TCGA_samples$race_self_reported <- sub('TCGA: ','',TCGA_samples$race_self_reported)
#
#   TCGA_samples_before_filter <- TCGA_samples
#   TCGA_samples <- droplevels(subset(TCGA_samples, ancestry_PCA=='AFR' | ancestry_PCA =='EUR')) #rm non-AFR/EUR
#
#     TCGA_samples_all <- rbind(TCGA_samples_all,TCGA_samples)
#
#   #create summary table
#   TCGA_samples_summary <- data.frame(Cancer=CANCER_NAME)
#   TCGA_samples_summary$`Self-reported White` <- nrow(subset(TCGA_samples_before_filter,race_self_reported == 'White'))
#   TCGA_samples_summary$`Self-reported Black` <- nrow(subset(TCGA_samples_before_filter,race_self_reported == 'Black'))
#   TCGA_samples_summary$`PCA-classified European` <- nrow(subset(TCGA_samples,ancestry_PCA == 'EUR'))
#   TCGA_samples_summary$`PCA-classified African` <-  nrow(subset(TCGA_samples,ancestry_PCA == 'AFR'))
#
# TCGA_samples_summary_all <- rbind(TCGA_samples_summary_all, TCGA_samples_summary)
#
# data_all_cancers <- rbind(data_all_cancers,data_all)
#
# data_all_cancers$Pop <- sub('/ ','/\n',data_all_cancers$Pop)
#
# data_all_cancers$Pop <- factor(data_all_cancers$Pop, levels=c('1000 Genomes: EAS','1000 Genomes: EUR','1000 Genomes: AFR','  ','',' ','TCGA: Asian','TCGA: White','TCGA: Black','TCGA: American Indian /\nAlaska Native','TCGA: Native Hawaiian /\nPacific Islander','TCGA: Not reported'),ordered=TRUE)
#
# }
#
#
#
#
#
# TCGA_samples_summary_all[is.na(TCGA_samples_summary_all)] <- 0
# names(TCGA_samples_summary_all) <- gsub(' ','\n',names(TCGA_samples_summary_all))
#
#
#
#
# #create different layer for each population so that smaller can be superimposed on larger
#
# data_all_cancers$CANCER <- factor(data_all_cancers$CANCER, levels=c('BRCA','UCEC','PRAD','LUAD','COAD','KIRP','KIRC'),ordered=TRUE)
#
# layer_1 <- subset(data_all_cancers, Pop == '1000 Genomes: EAS')
# layer_2 <- subset(data_all_cancers, Pop == '1000 Genomes: EUR')
# layer_3 <- subset(data_all_cancers, Pop == '1000 Genomes: AFR')
# layer_4 <- subset(data_all_cancers, Pop == '')
# layer_5 <- subset(data_all_cancers, Pop == ' ')
# layer_55 <- subset(data_all_cancers, Pop == ' ')
#
# layer_6 <- subset(data_all_cancers, Pop == 'TCGA: Asian')
# layer_7 <- subset(data_all_cancers, Pop == 'TCGA: White')
# layer_8 <- subset(data_all_cancers, Pop == 'TCGA: Black')
# layer_9 <- subset(data_all_cancers, Pop == 'TCGA: American Indian /\nAlaska Native')
# layer_95 <- subset(data_all_cancers, Pop == 'TCGA: Native Hawaiian /\nPacific Islander')
# layer_10 <- subset(data_all_cancers, Pop == 'TCGA: Not reported')
#
#
#
# PLOT <- ggplot()  +  geom_point(data = layer_1, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=1) +
#   geom_point(data = layer_2, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=1.5) +
#   geom_point(data = layer_3, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=1.5) +
#   geom_point(data = layer_4, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=1.5) +
#   geom_point(data = layer_5, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=1.5) +
#   geom_point(data = layer_55, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=1.5) +
#   geom_point(data = layer_6, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=2) +
#   geom_point(data = layer_8, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=2) +
#   geom_point(data = layer_7, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=2) +
#
#   geom_point(data = layer_9, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=2) +
#   geom_point(data = layer_95, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=2) +
#   geom_point(data = layer_10, aes_string(x = "PC1", y = "PC2", color = "Pop"),size=2) +
#
#   facet_wrap(~CANCER,nrow=2) +
#
#
#
#   scale_color_manual(values = c(refColors$Color,studyColors$Color),   drop=FALSE) +
#   guides(color = guide_legend(nrow = 2, byrow = TRUE)) +
#   ggtitle('Ancestry of TCGA samples using 1000 Genomes as reference') + theme_bw() + theme(legend.position = "bottom") +
#
#
#   guides(colour = guide_legend(override.aes = list(size = 11),
#                                nrow = 6)) +
#   theme(legend.text = element_text(size = 17,margin = margin(t=6,b=6, r=10, unit = "pt")), #incr spacing b/w legnd items
#         legend.title = element_blank(),
#         axis.title.y = element_text(size = 18, face = "bold"),
#         axis.title.x = element_text(size = 18, face = "bold",margin = margin(t = 10, r = 0, b = 10, l = 0)),
#         axis.text.x = element_text(size = 14),
#         panel.spacing = unit(1.25, "lines"), #spacing b/w facets
#         axis.text.y = element_text(size = 14),
#         strip.background = element_blank(),
#         panel.background = element_rect(color = 'black',fill=NA),
#         panel.grid.major = element_blank(),
#         panel.grid.minor = element_blank(),
#         strip.text.x = element_text(size=20,face='plain'),
#         plot.title = element_text(size=22,hjust=0.5,face='bold',margin=margin(b = 15)),
#         plot.margin=unit(c(0.3,0.3,0.3,0.3),"cm"))
#
# LEGEND <- g_legend(PLOT)
#
# dummy2 <- data.frame(X = c("LUAD", "COAD"), Z = c(0.1, 0))
#
# PLOT <- PLOT  +  geom_segment(data=dummy2,aes(y=-0.03,yend=0.01, x=0,xend=0.00),size=1) +
#   geom_segment(data=dummy2,aes(y=-.01,yend=-.01, x=-.02,xend=0.03),size=1) +
# theme(legend.position = 'none')
#
#
# TABLE <- ggtexttable(as.matrix(TCGA_samples_summary_all), theme= ttheme(
#   base_style = "default",
#   base_size = 18,
#   base_colour = "black",
#   padding = unit(c(0.50, 0.45), "cm"),
#   colnames.style = colnames_style(size = 16,fill=c('grey70','grey70','grey70','grey70','grey70','grey70','white')),
#   rownames.style = rownames_style(size = 16,face = 'plain',hjust=1), #add x= if want to change position
#   tbody.style = tbody_style(size = 18)))
#
#
#
# png('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/MS_plots/FIGS0.png',height=11,width=15,res=500,units='in')
# ggarrange(PLOT,NULL,ggarrange(LEGEND,TABLE,nrow=1),nrow=3,heights=c(0.8,0.10,0.2)) + theme(plot.margin = margin(b=2,l=0.25,t=0.1,r=1.25, "cm")) #incr marrgin at bottom
# dev.off()
#
# write.table(x=TCGA_samples_all,file='/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/overall_read_depths_and_sample_information/PCA-classified_ancestry.txt',sep='\t',quote=FALSE,row.names=FALSE)

# %% [markdown]
# ### Add PCA-classified ancestry to master tables, retaining only the samples classified as EUR or AFR

# %%
# %%R
#
# PCA_ANCESTRY <- read.table('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/overall_read_depths_and_sample_information/PCA-classified_ancestry.txt',header=TRUE,sep='\t')[,c('submitter_id','ancestry_PCA')]
# PCA_ANCESTRY$submitter_id <- gsub("^([^-]*-[^-]*-[^-]*).*", "\\1",PCA_ANCESTRY$submitter_id)
# PCA_ANCESTRY$race_PCA <- ifelse(PCA_ANCESTRY$ancestry_PCA == 'EUR','White',ifelse(PCA_ANCESTRY$ancestry_PCA == 'AFR','Black',NA))
#
# for (FILE in list.files(paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/overall_read_depths_and_sample_information'),pattern="*table.txt",full.names = TRUE)){
#
#   TABLE <-read.table(FILE,header=TRUE,sep='\t')
#   names(TABLE)[names(TABLE)=='race'] <- 'race_self_reported'
#
#   TABLE <- merge(TABLE,PCA_ANCESTRY, by='submitter_id')
#
#   write.table(x=TABLE,file=gsub('.txt','_final.txt',FILE),sep='\t',row.names=FALSE,quote=FALSE)
# }

# %% [markdown]
# # PART 2 - JOINT GENOTYPING ON BRCA TO DETERMINE MINOR ALLELE FREQUENCY, MINOR ALLELE CONCENTRATION IN GERMLINE AND SOMATIC TISSUE

# %% [markdown]
# ## DOWNLOAD CAPTURE KITS AND CREATE BED OF COMMON CAPTURE REGION

# %% [markdown]
# ### 1. Create bed file containing regions of interest

# %% [markdown]
# #### Option 1: Bed file contains all protein-coding regions

# %%
# %%bash
#
# #for i in {1..22}; do cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/gencode.v22.annotation.gtf | grep protein_coding | cut -f1,4,5 | grep -w chr${i} | sort | uniq | awk '{if($2!=$3) print}' > /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/gencode.v22.annotation_chr${i}_protein-coding.bed;done;

# %% [markdown]
# #### Option 2: Bed file contains only the NimbleGen kit common capture regions
# •  Bed file contains intersection of these 3 capture kits, lifted over to hg38 via UCSC tool:
# • https://sequencing.roche.com/en/support-resources/discontinued-products/seqcap-ez-exome-v3-kit.html
# •  https://web.archive.org/web/20161106062747/http://genome.wustl.edu/pub/custom_capture/hg18_nimblegen_exome_version_2/hg18_nimblegen_exome_version_2.bed
# •  https://web.archive.org/web/20141010064923/http://www.nimblegen.com/products/seqcap/ez/v2/index.html

# %%
# %%bash
#
# #sort by chrom, then start
# for file in /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/*hg38liftover.bed; do
#
# ~/s212975.Wickland_Immunomics/tools/bedtools2/bin/bedtools sort -i ${file} > `dirname ${file}`/`basename ${file} .bed`_SORTED.bed;done;

# %%
# %%bash
#
# #run bedtools multiinter, keeping only those regions common to all three kits
# ~/s212975.Wickland_Immunomics/tools/bedtools2/bin/bedtools multiinter -i /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/SeqCap_EZ_Exome_v3_hg19_capture_targets_hg38liftover_SORTED.bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/hg18_nimblegen_exome_version_2_hg38liftover_SORTED.bed  /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/SeqCap_EZ_Exome_v2_hg38liftover_SORTED.bed | awk '$4 == 3 ' > /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/three_capture_kits_intersection_hg38_liftover.bed

# %%
# %%bash
#
# #print capture size
#
# cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/SeqCap_EZ_Exome_v3_hg19_capture_targets_hg38liftover_SORTED.bed |  awk '{print $3-$2+1}' | awk '{sum += $1} END {print sum/1000000}'
#
# cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/hg18_nimblegen_exome_version_2_hg38liftover_SORTED.bed |  awk '{print $3-$2+1}' | awk '{sum += $1} END {print sum/1000000}'
#
# cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/SeqCap_EZ_Exome_v2_hg38liftover_SORTED.bed |  awk '{print $3-$2+1}' | awk '{sum += $1} END {print sum/1000000}'
#
# cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/three_capture_kits_intersection_hg38_liftover.bed |  awk '{print $3-$2+1}' | awk '{sum += $1} END {print sum/1000000}'
# Out:
# 64.5468
# 35.9727
# 80.5869
# 31.5054

# %%
# %%bash
#
# #extract the common-capture positions from each chromosome
# for i in {1..22}; do cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/three_capture_kits_intersection_hg38_liftover.bed | grep -w chr${i} | sort | uniq | awk '{if($2!=$3) print}' > /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr${i}.bed;done;

# %% [markdown]
# ### CALCULATE READ DEPTH OF THESE BRCA SAMPLES WITHIN THIS CAPTURE REGION
# - This will do both tumor and normal
# - As before, in the overall depth analysis, including the sex chromosomes here

# %%
# %%bash
#
# #create directories for scripts and for outputs
# if [ -d "/home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bed_read_depths/BRCA_NEW" ]; then rm -r /home/mayo/m187735//s212975.Wickland_Immunomics/processing/TCGA/bed_read_depths/BRCA_NEW;
# fi;
#
# mkdir -p /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bed_read_depths/BRCA_NEW
#
# if [ -d "/home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/bed_read_depths/BRCA_NEW" ];	then rm -r /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/bed_read_depths/BRCA_NEW;
# fi;
#
# mkdir -p /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/bed_read_depths/BRCA_NEW
#
# #create scripts to run view (to count # of reads) and mpileup (to count # of bases, avg # of bases) in each bed entry region for each sample
# grep mbleg  /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/overall_read_depths_and_sample_information/BRCA_all_reads_exome_master_table_final.txt | cut -f6 | sort | uniq | while read bam; do OUTPUT_FILE='/home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bed_read_depths/BRCA_NEW/'`basename ${bam} .bam`'_bed_read_depths.txt'; echo "rm "$OUTPUT_FILE"; cut -f1-3 /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/three_capture_kits_intersection_hg38_liftover.bed |uniq | while read bed_entry; do REGION=\`echo \${bed_entry} | sed 's/ /:/' | sed 's/ /-/'\`; echo \${REGION} | tr \\\n \\\t>> "$OUTPUT_FILE";  /home/mayo/m187735/s212975.Wickland_Immunomics/tools/samtools-1.10/bin/samtools mpileup --incl-flags 2 --excl-flags 1024 --min-MQ 20 --min-BQ 0 --region \${REGION} "$bam" | awk '{sum += \$4} END {print sum \"|\" sum/NR}' | tr \\\n '|' >> "$OUTPUT_FILE"; /home/mayo/m187735/s212975.Wickland_Immunomics/tools/samtools-1.10/bin/samtools view -c -f 2 -F 1024 -q 20 "$bam" \${REGION} >> "$OUTPUT_FILE"; done" >> /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/bed_read_depths/BRCA_NEW/SAMPLE_`basename $bam .bam`.qsub;done;
#
#
# #submit qsubs
# for file in /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/bed_read_depths/BRCA_NEW/*qsub; do qsub -l h_vmem=2G -e /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/bed_read_depths/BRCA_NEW/`basename ${file} .qsub`.err -o /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/bed_read_depths/BRCA_NEW/`basename ${file} .qsub`.out -q 1-day,4-day,7-day,30-day -pe threaded 1 $file;done;
# Out:
# Your job 1142266 ("SAMPLE_0017ba4c33a07ba807b29140b0662cb1_gdc_realn.qsub") has been submitted
# Your job 1142267 ("SAMPLE_003860a34c9b244a5d8435b220ca5673_gdc_realn.qsub") has been submitted
# Your job 1142268 ("SAMPLE_0047eb6e338c99ed7e7e399875b83181_gdc_realn.qsub") has been submitted
# Your job 1142269 ("SAMPLE_00925769611d88cb0379798246946580_gdc_realn.qsub") has been submitted
# Your job 1142270 ("SAMPLE_00a0b7fe73741312c23f4f63317cc972_gdc_realn.qsub") has been submitted
# Your job 1142271 ("SAMPLE_01218e1cd1b806450e6954adedb202b1_gdc_realn.qsub") has been submitted
# Your job 1142272 ("SAMPLE_015537fb5f5fb8cdbefb1556ec7568e5_gdc_realn.qsub") has been submitted
# Your job 1142273 ("SAMPLE_01ba6cd35f5da1da90e1c2d95eab0068_gdc_realn.qsub") has been submitted
# Your job 1142274 ("SAMPLE_01c12736511241497f2e976c1764b1e4_gdc_realn.qsub") has been submitted
# Your job 1142275 ("SAMPLE_01e5961cf18d86fb266ca104136b5361_gdc_realn.qsub") has been submitted
# Your job 1142276 ("SAMPLE_0205cabb2bae0812e6966871567cb1b0_gdc_realn.qsub") has been submitted
# Your job 1142277 ("SAMPLE_021812fd40481352dc8378963e6da3c6_gdc_realn.qsub") has been submitted
# Your job 1142278 ("SAMPLE_025ddef03b5bd3acdde431df4c0d7e62_gdc_realn.qsub") has been submitted
# Your job 1142279 ("SAMPLE_02a4ce4a222d05324858158e0aab7317_gdc_realn.qsub") has been submitted
# Your job 1142280 ("SAMPLE_02e1e61e442e4704324345cb90bf566f_gdc_realn.qsub") has been submitted
# Your job 1142281 ("SAMPLE_02e5b5b2ebfab87c33d802ee14dcf9a0_gdc_realn.qsub") has been submitted
# Your job 1142282 ("SAMPLE_03208e754d13a48950c40a4121de858a_gdc_realn.qsub") has been submitted
# Your job 1142283 ("SAMPLE_0388cb85761c96abbe81e3acb58e5db6_gdc_realn.qsub") has been submitted
# Your job 1142284 ("SAMPLE_03c886e4232c4a1b2edec2ec50ab0b8f_gdc_realn.qsub") has been submitted
# Your job 1142285 ("SAMPLE_042ff07464d44bb2679ff73c60374468_gdc_realn.qsub") has been submitted
# Your job 1142286 ("SAMPLE_043219477832a79f683d987f9c0ff312_gdc_realn.qsub") has been submitted
# Your job 1143749 ("SAMPLE_fed1ead41895c59236a531158e77b931_gdc_realn.qsub") has been submitted
# Your job 1143750 ("SAMPLE_fed68ec520313a3c086bf1ae8f9cad40_gdc_realn.qsub") has been submitted
# Your job 1143751 ("SAMPLE_feedf5fc219b0b52380dcf71edf59d95_gdc_realn.qsub") has been submitted
# Your job 1143752 ("SAMPLE_ff145dba34dfe577ff828e3d42ccec3a_gdc_realn.qsub") has been submitted
# Your job 1143753 ("SAMPLE_ffa24876bf8cea367ef3e3b16bdd2203_gdc_realn.qsub") has been submitted
# Your job 1143754 ("SAMPLE_ffcd2412dfcceb96713492162bf34a97_gdc_realn.qsub") has been submitted

# %% [markdown]
# #### Make sure it's done

# %%
# %%bash
#
# for file in /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/bed_read_depths/BRCA_NEW/*txt; do wc -l $file;done | cut -d ' ' -f1 | sort | uniq -c

# %% [markdown]
# ##  Run mpileup on all positions within capture region
# #### Note that coverage of 0 willl NOT be recorded

# %% [markdown]
# #### First load the master tables that are also loaded by the analysis_and_plots.R script

# %%
# %%R
#
# ######################################
# #MASTER TABLE
# ######################################
#
# PLOT_BY_RACE_AND_SAMPLING_SITE <- function(MAPPED_READS_OR_ALL_READS,CANCER_TYPES,EXOME_OR_RNASEQ){
#
#   if (CANCER_TYPES=='all'){
#     CANCER_LIST <- c('BRCA','PRAD','LUAD','UCEC','KIRC','COAD','KIRP')
#
#     #Create dataframe to hold master table for all cancers
#     master_table_master <- data.frame()
#
#     if(MAPPED_READS_OR_ALL_READS != 'mapped_BRCA_reads_within_nimblegen_capture'){
#
#       #Load data
#       for (CANCER_NAME in CANCER_LIST){
#
#         #load overall depths data
#         master_table <- read.table(paste0('/home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/processed_data/overall_read_depths_and_sample_information/',CANCER_NAME,'_',MAPPED_READS_OR_ALL_READS,'_',EXOME_OR_RNASEQ,'_master_table_final.txt'),header=TRUE,sep='\t')
#         master_table_master <- rbind(master_table_master,master_table)
#       }
#     }
#   }
#
#   if (CANCER_TYPES != 'all'){
#     CANCER_NAME <- CANCER_TYPES
#     master_table_master <- read.table(paste0('/home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/processed_data/overall_read_depths_and_sample_information/',CANCER_NAME,'_',MAPPED_READS_OR_ALL_READS,'_',EXOME_OR_RNASEQ,'_master_table_final.txt'),header=TRUE,sep='\t')
#
#
#   }
#
#
#   #remove entries that have no exome data; some in dataframes have RNA-seq but no exome
#   master_table_master <- subset(master_table_master, (bam_full_path != 'NA'))
#
#   #set order for race
#   master_table_master <- subset(master_table_master, (race_PCA == 'White' | race_PCA == 'Black'))
#   master_table_master$race_PCA <- factor(master_table_master$race_PCA, levels = c("White","Black"),ordered=TRUE)
#
#   #rename tissue type and set order
#   master_table_master$tissue.definition <- sub("Blood_Normal","Patient Germline",master_table_master$tissue.definition)
#   master_table_master$tissue.definition <- sub("Primary_Tumor","Primary Tumor",master_table_master$tissue.definition)
#   master_table_master$tissue.definition <- factor(master_table_master$tissue.definition, levels=c('Primary Tumor','Patient Germline'))
#   master_table_master$Cancer <- factor(master_table_master$Cancer,levels=c('BRCA','PRAD','LUAD','UCEC','KIRC','COAD','KIRP'),ordered=TRUE)
#
#   #if any capture kit listed multiple times for a patient, combine them into single row, so that no patient is counted more than once for same tissue type
#   CAPTURE_KIT_FIXED <- master_table_master %>% group_by(submitter_id_long,tissue.definition) %>% dplyr::summarise(CAPTURE_KIT_FIXED = toString(CAPTURE_KIT))
#   CAPTURE_KIT_FIXED$CAPTURE_KIT_FIXED <- gsub(", ","|",CAPTURE_KIT_FIXED$CAPTURE_KIT_FIXED)
#
#   master_table_master <- merge(master_table_master, CAPTURE_KIT_FIXED, by=c('submitter_id_long','tissue.definition'))
#   master_table_master <- master_table_master[(names(master_table_master)!='CAPTURE_KIT')]
#
#   master_table_master <- unique(master_table_master)
#
#   #simplify capture kit
#     master_table_master$CAPTURE_KIT_simp <-  ifelse(grepl('hg18',master_table_master$CAPTURE_KIT_FIXED),'NimbleGen hg18 Exome v2',ifelse(grepl('v3.0',master_table_master$CAPTURE_KIT_FIXED),'NimbleGen SeqCap EZ Exome v3',ifelse(grepl('v2.0',master_table_master$CAPTURE_KIT_FIXED),'NimbleGen SeqCap EZ Exome v2',ifelse(grepl('V2.0',master_table_master$CAPTURE_KIT_FIXED),'NimbleGen SeqCap EZ Exome v2',ifelse(grepl('Custom',master_table_master$CAPTURE_KIT_FIXED),'Custom V2 Exome Bait',ifelse(grepl('Gapfiller',master_table_master$CAPTURE_KIT_FIXED),'Gapfiller_7m',ifelse(grepl('Rome',master_table_master$CAPTURE_KIT_FIXED),'Roche SeqCap EZ HGSC VCRome',ifelse(grepl('SureSelect',master_table_master$CAPTURE_KIT_FIXED),'Agilent SureSelect Human All Exon v2','Not reported'))))))))
#
#
#   #clean up capture kit and order according to date
#   master_table_master$CAPTURE_KIT_simp <- gsub("SureSelect Human All Exon 38 Mb v2","Agilent SureSelect Human All Exon v2",master_table_master$CAPTURE_KIT_simp)
#
#
#   #reorder capture kit simp
#   master_table_master$CAPTURE_KIT_simp <- factor(master_table_master$CAPTURE_KIT_simp, levels=c('Agilent SureSelect Human All Exon v2','Custom V2 Exome Bait','NimbleGen hg18 Exome v2','NimbleGen SeqCap EZ Exome v2','NimbleGen SeqCap EZ Exome v3','Roche SeqCap EZ HGSC VCRome','Gapfiller_7m','Not reported'),ordered=TRUE)
#
#   return(master_table_master)
# }
#
#
# ALL_READS_FOR_PLOTTING <- unique(PLOT_BY_RACE_AND_SAMPLING_SITE('all_reads','all','exome'))
# MAPPED_READS_FOR_PLOTTING <- unique(PLOT_BY_RACE_AND_SAMPLING_SITE('mapped_reads','all','exome'))
# UNMAPPED_READS_FOR_PLOTTING <- unique(PLOT_BY_RACE_AND_SAMPLING_SITE('unmapped_reads','all','exome'))
#
# SeqCapV2_BRCA_READS_FOR_PLOTTING <- unique(PLOT_BY_RACE_AND_SAMPLING_SITE('mapped_reads_within_nimblegen_SeqCap_EZ_Exome_v2_hg38liftover_SORTED','BRCA','exome'))
# SeqCapV3_BRCA_READS_FOR_PLOTTING <- unique(PLOT_BY_RACE_AND_SAMPLING_SITE('mapped_reads_within_nimblegen_SeqCap_EZ_Exome_v3_hg19_capture_targets_hg38liftover_SORTED','BRCA','exome'))
# hg18_BRCA_READS_FOR_PLOTTING <- unique(PLOT_BY_RACE_AND_SAMPLING_SITE('mapped_reads_within_nimblegen_hg18_nimblegen_exome_version_2_hg38liftover_SORTED','BRCA','exome'))
#
#
#
#
# ##################################
# #BRCA CAPTURE KITS -- KEEP ONLY THE SAMPLES CAPTURED BY THEIR RESPECTIVE KITS
# ##################################
#
# #if sample called by two kits, just consider as having been captured by smallest
# table(SeqCapV2_BRCA_READS_FOR_PLOTTING$CAPTURE_KIT_simp)
# SeqCapV2_BRCA_READS_FOR_PLOTTING <- subset(SeqCapV2_BRCA_READS_FOR_PLOTTING, CAPTURE_KIT_simp == 'NimbleGen SeqCap EZ Exome v2')
# SeqCapV3_BRCA_READS_FOR_PLOTTING <- subset(SeqCapV3_BRCA_READS_FOR_PLOTTING, CAPTURE_KIT_simp == 'NimbleGen SeqCap EZ Exome v3')
# hg18_BRCA_READS_FOR_PLOTTING <- subset(hg18_BRCA_READS_FOR_PLOTTING, CAPTURE_KIT_simp == 'NimbleGen hg18 Exome v2')
#
# BRCA_three_nimblegen_kits_overall_reads <- rbind(hg18_BRCA_READS_FOR_PLOTTING, SeqCapV2_BRCA_READS_FOR_PLOTTING,SeqCapV3_BRCA_READS_FOR_PLOTTING)
# Out:
# `summarise()` has grouped output by 'submitter_id_long'. You can override using the `.groups` argument.
# `summarise()` has grouped output by 'submitter_id_long'. You can override using the `.groups` argument.
# `summarise()` has grouped output by 'submitter_id_long'. You can override using the `.groups` argument.
# `summarise()` has grouped output by 'submitter_id_long'. You can override using the `.groups` argument.
# `summarise()` has grouped output by 'submitter_id_long'. You can override using the `.groups` argument.
# `summarise()` has grouped output by 'submitter_id_long'. You can override using the `.groups` argument.

# %% [markdown]
# #### Then run mpileup

# %%
# %%R
#
# CAPTURE_FILE <- '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/three_capture_kits_intersection_hg38_liftover.bed'
#
# OUTPUT_NAME <- 'All_genes'
#
#
# for (row in 1:nrow(BRCA_three_nimblegen_kits_overall_reads)){
#   BAM_PATH <- as.character(BRCA_three_nimblegen_kits_overall_reads[row,6])
#     SAMPLE_ID <- as.character(BRCA_three_nimblegen_kits_overall_reads[row,3])
#     RACE <- as.character(BRCA_three_nimblegen_kits_overall_reads[row,17])
#     TISSUE <- as.character(BRCA_three_nimblegen_kits_overall_reads[row,2])
#     CAPKIT <- as.character(BRCA_three_nimblegen_kits_overall_reads[row,19])
#
#   system(paste0('if [ ! -d /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA_NEW/',gsub(' ','_',TISSUE),'/',OUTPUT_NAME, ' ]; then mkdir -p /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA_NEW/',gsub(' ','_',TISSUE),'/',OUTPUT_NAME,'; fi'))
#
#  # system(paste0('echo "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/samtools-1.10/bin/samtools mpileup ',BAM_PATH,' --incl-flags 2 --excl-flags 1024 --min-MQ 20 --min-BQ 0 --positions ',CAPTURE_FILE ,' | cut -f1,2,4 > ',paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA/',gsub(' ','_',TISSUE),'/',OUTPUT_NAME,'/',SAMPLE_ID,'_',RACE,'_',gsub(' ','_',TISSUE),'.txt" | qsub -l h_vmem=2G -e ',paste0("/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA/",gsub(" ","_",TISSUE),"/",OUTPUT_NAME,'/',SAMPLE_ID,"_",RACE,"_",gsub(" ","_",TISSUE),".err "),paste0("-o /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA/",gsub(" ","_",TISSUE),"/",OUTPUT_NAME,'/',SAMPLE_ID,"_",RACE,"_",gsub(" ","_",TISSUE)),'.out -q 1-day,4-day,7-day,30-day -pe threaded 1 -N ',SAMPLE_ID)))
#
#   OUTPUT_FILE=paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA_NEW/',gsub(' ','_',TISSUE),'/',OUTPUT_NAME,'/',SAMPLE_ID,'_',RACE,'_',gsub(' ','_',TISSUE),'_',gsub(' ','_',CAPKIT),'.txt')
#
#   system(paste0('echo "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/samtools-1.10/bin/samtools mpileup ',BAM_PATH,' --incl-flags 2 --excl-flags 1024 --min-MQ 20 --min-BQ 0 --positions ',CAPTURE_FILE ,' | cut -f1,2,4 > ',OUTPUT_FILE,' " | qsub -l h_vmem=2G -e /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA_NEW/',gsub(" ","_",TISSUE),'/',OUTPUT_NAME,'/',SAMPLE_ID,'_',RACE,'_',gsub(' ','_',TISSUE),'.err -o /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA_NEW/',gsub(' ','_',TISSUE),'/',OUTPUT_NAME,'/',SAMPLE_ID,'_',RACE,'_',gsub(' ','_',TISSUE),'.out -q 1-day,4-day,7-day,30-day -pe threaded 1 -N ',SAMPLE_ID))
#
# }
# #note that for v3 kit, for some reason file suffix not added

# %% [markdown]
# #### Generate summary file of results from above -- depth within NimbleGen capture region (wait...why do I need this, again, if I'm using the more raw measurement in Fig 2, of just dividing overall by the capture size?)

# %%
# %%bash
#
# for TISSUE in Primary_Tumor Patient_Germline; do
#
#     RESULTS_DIREC=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA_NEW/${TISSUE}/All_genes/
#
#     for RESULTS_FILE in ${RESULTS_DIREC}/TCGA*txt;
#         do echo "echo -e 'SAMPLE\tRACE\tTISSUE\tCAPTURE_KIT\tPOSITIONS_WITH_COVERAGE_1_TO_10\tPOSITIONS_WITH_COVERAGE_11_TO_39\tPOSITIONS_WITH_COVERAGE_40_PLUS' > ${RESULTS_DIREC}/`basename ${RESULTS_FILE} .txt`.summary;
#
#         echo `basename ${RESULTS_FILE}` | cut -d '_' -f1 | tr '\n' '\t' >> ${RESULTS_DIREC}/`basename ${RESULTS_FILE} .txt`.summary;
#         echo `basename ${RESULTS_FILE}` | cut -d '_' -f2 | tr '\n' '\t' >> ${RESULTS_DIREC}/`basename ${RESULTS_FILE} .txt`.summary;
#         echo `basename ${RESULTS_FILE}` | cut -d '_' -f3,4 | sed 's/.txt//g' | tr '\n' '\t' >> ${RESULTS_DIREC}/`basename ${RESULTS_FILE} .txt`.summary;
#         echo `basename ${RESULTS_FILE}` | cut -d '_' -f5- | sed 's/.txt//g' | tr '\n' '\t' >> ${RESULTS_DIREC}/`basename ${RESULTS_FILE} .txt`.summary;
#         cat ${RESULTS_FILE} | awk  '\$3 >=1 && \$3 <= 10'  | wc -l | tr '\n' '\t' >> ${RESULTS_DIREC}/`basename ${RESULTS_FILE} .txt`.summary;
Black_Patient_Germline_NimbleGen_SeqCap_EZ_Exome_v3") has been submitted
# Your job 1171640 ("TCGA-W8-A86G_White_Patient_Germline_NimbleGen_SeqCap_EZ_Exome_v3") has been submitted
# Your job 1171641 ("TCGA-WT-AB41_Black_Patient_Germline_NimbleGen_SeqCap_EZ_Exome_v3") has been submitted
# Your job 1171642 ("TCGA-WT-AB44_White_Patient_Germline_NimbleGen_SeqCap_EZ_Exome_v3") has been submitted
# Your job 1171643 ("TCGA-XX-A899_White_Patient_Germline_NimbleGen_SeqCap_EZ_Exome_v3") has been submitted
# Your job 1171644 ("TCGA-XX-A89A_White_Patient_Germline_NimbleGen_SeqCap_EZ_Exome_v3") has been submitted
# Your job 1171645 ("TCGA-Z7-A8R5_White_Patient_Germline_NimbleGen_SeqCap_EZ_Exome_v3") has been submitted
# Your job 1171646 ("TCGA-Z7-A8R6_White_Patient_Germline_NimbleGen_SeqCap_EZ_Exome_v3") has been submitted

# %% [markdown]
# #### Combine summary files (can probably delete this -- seems not to have been used)

# %%
# %%R
#
# OUTPUT_NAME <- 'All_genes'
#
# ALL_SAMPLES <- data.frame()
#
# for (TISSUE in c('Primary_Tumor','Patient_Germline')){
#     for (FILE in list.files(paste0('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA_NEW/',TISSUE,'/',OUTPUT_NAME),pattern="*summary*",full.names = TRUE)){
#       SAMPLE <- read.table(FILE,header=TRUE,sep='\t')
#       ALL_SAMPLES <- rbind(ALL_SAMPLES,SAMPLE)
#
#     }
# }
#
# #get total capture region size
# common_capture_region <- read.table('/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/three_capture_kits_intersection_hg38_liftover.bed',header=FALSE,sep='\t')
#
# common_capture_region_size=sum(common_capture_region[,3]-common_capture_region[,2]+1)
#
# ALL_SAMPLES$TOTAL_POSITIONS_IN_CAPTURE_REGION <- common_capture_region_size
#
# ALL_SAMPLES$POSITIONS_WITH_NO_COVERAGE <- ALL_SAMPLES$TOTAL_POSITIONS_IN_CAPTURE_REGION-(ALL_SAMPLES$POSITIONS_WITH_COVERAGE_1_TO_10+ALL_SAMPLES$POSITIONS_WITH_COVERAGE_11_TO_39+ALL_SAMPLES$POSITIONS_WITH_COVERAGE_40_PLUS)
#
# ALL_SAMPLES_TUMOR <- subset(ALL_SAMPLES,TISSUE=='Primary_Tumor')
# ALL_SAMPLES_GERMLINE <- subset(ALL_SAMPLES,TISSUE=='Paient_Germline')
#
# write.table(ALL_SAMPLES_TUMOR,'/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA_NEW/Primary_Tumor/All_genes/SUMMARY_DEPTHS_ALL_SAMPLES_IN_CAPTURE_REGION.txt',sep='\t',quote=FALSE,row.names=FALSE)
# write.table(ALL_SAMPLES_GERMLINE,'/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/DP_per_position_from_bams/BRCA_NEW/Patient_Germline/All_genes/SUMMARY_DEPTHS_ALL_SAMPLES_IN_CAPTURE_REGION.txt',sep='\t',quote=FALSE,row.names=FALSE)

# %% [markdown]
# ### 2. Run HaplotypeCaller on TCGA bams

# %%
# %%bash
#
# for i in {1..22}; do
#
#     #type of cancer (e.g. LUAD, ${CANCER_NAME}, PRAD, COAD)
#     TISSUE=Blood_Normal
#     CANCER_NAME=BRCA
#     BED_FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr${i}.bed
#     PROJECT=nimblegen_capture_NOV19_chr${i}
#
#     #create directories for scripts and for outputs
#     mkdir -p /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}
#     mkdir -p /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/White
#     mkdir -p /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/Black
#
#     if [ -d "/home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/" ];
#     then rm -r /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/;
#     fi;
#
#     mkdir -p /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/
#
#
#     #list all hg38 bams on mforge for cancer type
#     echo " " > /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_bam_list_${TISSUE}.txt #first create file with blank line at top, otherwise skips when generating commands for qsub files...
#
#     #only want samples captured by a Nimblegen kit
#     if [ "$TISSUE" = "Primary_Tumor" ];
#     then cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/overall_read_depths_and_sample_information/${CANCER_NAME}_all_reads_exome_master_table_final.txt | awk '{print $1,$18,$6,$4,$16}' FS='\t' OFS='\t' | awk '$3 != "NA" && $4 == "Primary_Tumor" && $5 ~ "imble"' FS='\t' >> /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_bam_list_${TISSUE}.txt;
#
#     elif [ "$TISSUE" = "Blood_Normal" ];
#     then cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/overall_read_depths_and_sample_information/${CANCER_NAME}_all_reads_exome_master_table_final.txt | awk '{print $1,$18,$6,$4,$16}' FS='\t' OFS='\t' | awk '$3 != "NA" && $4 == "Blood_Normal" && $5 ~ "imble"' FS='\t' >> /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_bam_list_${TISSUE}.txt;
#     fi
#
#
#     #create scripts for sets of 10 samples
#     TOTAL_NUMBER_OF_BAMS=`wc -l /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_bam_list_${TISSUE}.txt | cut -d ' ' -f1`
#     NUMBER_OF_SPLITS=`echo $((TOTAL_NUMBER_OF_BAMS/10))`
#     BAM_LOOP_END=`echo $((NUMBER_OF_SPLITS*10))`
#
#
#     COUNTER=1
#     COUNTER2=11
#     #the positional variables in awk correspond to the order of cols in the bam_list.txt generated above
#     until [ ${COUNTER} -eq $(($BAM_LOOP_END+11)) ];  do awk -v a=${COUNTER} -v b=${COUNTER2} "NR==a,NR==b" /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_bam_list_${TISSUE}.txt | while read line; do awk -v PROJECT=${PROJECT}  -v BED_FILE=${BED_FILE} '{print "java -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T HaplotypeCaller -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa -I "$3" -ERC GVCF --intervals "BED_FILE" -o  /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/"PROJECT"/${CANCER_NAME}/"$4"/"$2"/"$1".g.vcf"}' OFS='\t' > /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/samples_${COUNTER}-${COUNTER2}.qsub;done;COUNTER=`echo $((${COUNTER}+10))`;COUNTER2=`echo $((${COUNTER}+10))`;done;
#
#     #submit qsubs
#     for file in /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/*qsub; do qsub -l h_vmem=10G -e /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/`basename ${file} .qsub`.err -o /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/`basename ${file} .qsub`.out -pe threaded 4 -q 1-day,4-day,7-day,30-day $file;done;
# done;
# Out:
# Your job 1149367 ("samples_1-11.qsub") has been submitted
# Your job 1149368 ("samples_101-111.qsub") has been submitted
# Your job 1149369 ("samples_11-21.qsub") has been submitted
# Your job 1149370 ("samples_111-121.qsub") has been submitted
# Your job 1149371 ("samples_121-131.qsub") has been submitted
# Your job 1149372 ("samples_131-141.qsub") has been submitted
# Your job 1149373 ("samples_141-151.qsub") has been submitted
# Your job 1149374 ("samples_151-161.qsub") has been submitted
# Your job 1149375 ("samples_161-171.qsub") has been submitted
# Your job 1149376 ("samples_171-181.qsub") has been submitted
# Your job 1149377 ("samples_181-191.qsub") has been submitted
# Your job 1149378 ("samples_191-201.qsub") has been submitted
# Your job 1149379 ("samples_201-211.qsub") has been submitted
# Your job 1149380 ("samples_21-31.qsub") has been submitted
# Your job 1149381 ("samples_211-221.qsub") has been submitted
# Your job 1149382 ("samples_221-231.qsub") has been submitted
# Your job 1149383 ("samples_231-241.qsub") has been submitted
# Your job 1149384 ("samples_241-251.qsub") has been submitted
# Your job 1149385 ("samples_251-261.qsub") has been submitted
# Your job 1149386 ("samples_261-271.qsub") has been submitted
# Your job 1149387 ("samples_271-281.qsub") has been submitted
# Your job 1149388 ("samples_281-291.qsub") has been submitted
# Your job 1149389 ("samples_291-301.qsub") has been submitted
# Your job 1149390 ("samples_301-311.qsub") has been submitted
# Your job 1149391 ("samples_31-41.qsub") has been submitted
# Your job 1149392 ("samples_311-321.qsub") has been submitted
# Your job 1149393 ("samples_321-331.qsub") has been submitted
# Your job 1149394 ("samples_331-341.qsub") has been submitted
# Your job 1149395 ("samples_341-351.qsub") has been submitted
# Your job 1149396 ("samples_351-361.qsub") has been submitted
# Your job 1149397 ("samples_361-371.qsub") has been submitted
# Your job 1149398 ("samples_371-381.qsub") has been submitted
# Your job 1149399 ("samples_381-391.qsub") has been submitted
# Your job 1149400 ("samples_391-401.qsub") has been submitted
# Your job 1149401 ("samples_401-411.qsub") has been submitted
# Your job 1149402 ("samples_41-51.qsub") has been submitted
# Your job 1149403 ("samples_411-421.qsub") has been submitted
# Your job 1149404 ("samples_421-431.qsub") has been submitted
# Your job 1149405 ("samples_431-441.qsub") has been submitted
# Your job 1149406 ("samples_441-451.qsub") has been submitted
# Your job 1149407 ("samples_451-461.qsub") has been submitted
# Your job 1149408 ("samples_461-471.qsub") has been submitted
# Your job 1149409 ("samples_471-481.qsub") has been submitted
# Your job 1149410 ("samples_481-491.qsub") has been submitted
# Your job 1149411 ("samples_491-501.qsub") has been submitted
# Your job 1149412 ("samples_501-511.qsub") has been submitted
# Your job 1149413 ("samples_51-61.qsub") has been submitted
# Your job 1149414 ("samples_511-521.qsub") has been submitted
# Your job 1149415 ("samples_521-531.qsub") has been submitted
# Your job 1149416 ("samples_531-541.qsub") has been submitted
# Your job 1149417 ("samples_541-551.qsub") has been submitted
# Your job 1149418 ("samples_551-561.qsub") has been submitted
# Your job 1149419 ("samples_561-571.qsub") has been submitted
# Your job 1149420 ("samples_571-581.qsub") has been submitted
# Your job 1149421 ("samples_581-591.qsub") has been submitted
# Your job 1149422 ("samples_591-601.qsub") has been submitted
# Your job 1149423 ("samples_601-611.qsub") has been submitted
# Your job 1149424 ("samples_61-71.qsub") has been submitted
# Your job 1149425 ("samples_611-621.qsub") has been submitted
# Your job 1149426 ("samples_621-631.qsub") has been submitted
# Your job 1149427 ("samples_631-641.qsub") has been submitted
# Your job 1149428 ("samples_641-651.qsub") has been submitted
# Your job 1149429 ("samples_651-661.qsub") has been submitted
# Your job 1149430 ("samples_661-671.qsub") has been submitted
# Your job 1149431 ("samples_671-681.qsub") has been submitted
# Your job 1149432 ("samples_681-691.qsub") has been submitted
# Your job 1149433 ("samples_691-701.qsub") has been submitted
# Your job 1149434 ("samples_701-711.qsub") has been submitted
# Your job 1149435 ("samples_71-81.qsub") has been submitted
# Your job 1149436 ("samples_711-721.qsub") has been submitted
# Your job 1149437 ("samples_721-731.qsub") has been submitted
# Your job 1149438 ("samples_731-741.qsub") has been submitted
# Your job 1149439 ("samples_741-751.qsub") has been submitted
# Your job 1149440 ("samples_81-91.qsub") has been submitted
# Your job 1149441 ("samples_91-101.qsub") has been submitted
# Your job 1149442 ("samples_1-11.qsub") has been submitted
# Your job 1149443 ("samples_101-111.qsub") has been submitted
# Your job 1149444 ("samples_11-21.qsub") has been submitted
# Your job 1149445 ("samples_111-121.qsub") has been submitted
# Your job 1149446 ("samples_121-131.qsub") has been submitted
# Your job 1149447 ("samples_131-141.qsub") has been submitted
# Your job 1149448 ("samples_141-151.qsub") has been submitted
# Your job 1149449 ("samples_151-161.qsub") has been submitted
# Your job 1149450 ("samples_161-171.qsub") has been submitted
# Your job 1149451 ("samples_171-181.qsub") has been submitted
# Your job 1149452 ("samples_181-191.qsub") has been submitted
# Your job 1149453 ("samples_191-201.qsub") has been submitted
# Your job 1149454 ("samples_201-211.qsub") has been submitted
# Your job 1149455 ("samples_21-31.qsub") has been submitted
# Your job 1149456 ("samples_211-221.qsub") has been submitted
# Your job 1149457 ("samples_221-231.qsub") has been submitted
# Your job 1149458 ("samples_231-241.qsub") has been submitted
# Your job 1149459 ("samples_241-251.qsub") has been submitted
# Your job 1149460 ("samples_251-261.qsub") has been submitted
# Your job 1149461 ("samples_261-271.qsub") has been submitted
# Your job 1149462 ("samples_271-281.qsub") has been submitted
# Your job 1149463 ("samples_281-291.qsub") has been submitted
# Your job 1149464 ("samples_291-301.qsub") has been submitted
# Your job 1149465 ("samples_301-311.qsub") has been submitted
# Your job 1149466 ("samples_31-41.qsub") has been submitted
# Your job 1149467 ("samples_311-321.qsub") has been submitted
# Your job 1149468 ("samples_321-331.qsub") has been submitted
# Your job 1149469 ("samples_331-341.qsub") has been submitted
# Your job 1149470 ("samples_341-351.qsub") has been submitted
# Your job 1149471 ("samples_351-361.qsub") has been submitted
# Your job 1149472 ("samples_361-371.qsub") has been submitted
# Your job 1149473 ("samples_371-381.qsub") has been submitted
# Your job 1149474 ("samples_381-391.qsub") has been submitted
# Your job 1149475 ("samples_391-401.qsub") has been submitted
# Your job 1149476 ("samples_401-411.qsub") has been submitted
# Your job 1149477 ("samples_41-51.qsub") has been submitted
# Your job 1149478 ("samples_411-421.qsub") has been submitted
# Your job 1149479 ("samples_421-431.qsub") has been submitted
# Your job 1149480 ("samples_431-441.qsub") has been submitted
# Your job 1149481 ("samples_441-451.qsub") has been submitted
# Your job 1149482 ("samples_451-461.qsub") has been submitted
# Your job 1149483 ("samples_461-471.qsub") has been submitted
# Your job 1149484 ("samples_471-481.qsub") has been submitted
# Your job 1149485 ("samples_481-491.qsub") has been submitted
# Your job 1149486 ("samples_491-501.qsub") has been submitted
# Your job 1149487 ("samples_501-511.qsub") has been submitted
# Your job 1149488 ("samples_51-61.qsub") has been submitted
# Your job 1149489 ("samples_511-521.qsub") has been submitted
# Your job 1149490 ("samples_521-531.qsub") has been submitted
# Your job 1149491 ("samples_531-541.qsub") has been submitted
# Your job 1149492 ("samples_541-551.qsub") has been submitted
# Your job 1149493 ("samples_551-561.qsub") has been submitted
# Your job 1149494 ("samples_561-571.qsub") has been submitted
# Your job 1149495 ("samples_571-581.qsub") has been submitted
# Your job 1149496 ("samples_581-591.qsub") has been submitted
# Your job 1149497 ("samples_591-601.qsub") has been submitted
# Your job 1149498 ("samples_601-611.qsub") has been submitted
# Your job 1149499 ("samples_61-71.qsub") has been submitted
# Your job 1149500 ("samples_611-621.qsub") has been submitted
# Your job 1149501 ("samples_621-631.qsub") has been submitted
# Your job 1149502 ("samples_631-641.qsub") has been submitted
# Your job 1149503 ("samples_641-651.qsub") has been submitted
# Your job 1149504 ("samples_651-661.qsub") has been submitted
# Your job 1149505 ("samples_661-671.qsub") has been submitted
# Your job 1149506 ("samples_671-681.qsub") has been submitted
# Your job 1149507 ("samples_681-691.qsub") has been submitted
# Your job 1149508 ("samples_691-701.qsub") has been submitted
# Your job 1149509 ("samples_701-711.qsub") has been submitted
# Your job 1149510 ("samples_71-81.qsub") has been submitted
# Your job 1149511 ("samples_711-721.qsub") has been submitted
# Your job 1149512 ("samples_721-731.qsub") has been submitted
# Your job 1149513 ("samples_731-741.qsub") has been submitted
# Your job 1149514 ("samples_741-751.qsub") has been submitted
# Your job 1149515 ("samples_81-91.qsub") has been submitted
# Your job 1149516 ("samples_91-101.qsub") has been submitted
# Your job 1149517 ("samples_1-11.qsub") has been submitted
# Your job 1149518 ("samples_101-111.qsub") has been submitted
# Your job 1149519 ("samples_11-21.qsub") has been submitted
# Your job 1149520 ("samples_111-121.qsub") has been submitted
# Your job 1149521 ("samples_121-131.qsub") has been submitted
# Your job 1149522 ("samples_131-141.qsub") has been submitted
# Your job 1149523 ("samples_141-151.qsub") has been submitted
# Your job 1149524 ("samples_151-161.qsub") has been submitted
# Your job 1149525 ("samples_161-171.qsub") has been submitted
# Your job 1149526 ("samples_171-181.qsub") has been submitted
# Your job 1149527 ("samples_181-191.qsub") has been submitted
# Your job 1149528 ("samples_191-201.qsub") has been submitted
# Your job 1149529 ("samples_201-211.qsub") has been submitted
# Your job 1149530 ("samples_21-31.qsub") has been submitted
# Your job 1149531 ("samples_211-221.qsub") has been submitted
# Your job 1149532 ("samples_221-231.qsub") has been submitted
# Your job 1149533 ("samples_231-241.qsub") has been submitted
# Your job 1149534 ("samples_241-251.qsub") has been submitted
# Your job 1149535 ("samples_251-261.qsub") has been submitted
# Your job 1149536 ("samples_261-271.qsub") has been submitted
# Your job 1149537 ("samples_271-281.qsub") has been submitted
# Your job 1149538 ("samples_281-291.qsub") has been submitted
# Your job 1149539 ("samples_291-301.qsub") has been submitted
# Your job 1149540 ("samples_301-311.qsub") has been submitted
# Your job 1149541 ("samples_31-41.qsub") has been submitted
# Your job 1149542 ("samples_311-321.qsub") has been submitted
# Your job 1149543 ("samples_321-331.qsub") has been submitted
# Your job 1149544 ("samples_331-341.qsub") has been submitted
# Your job 1149545 ("samples_341-351.qsub") has been submitted
# Your job 1149546 ("samples_351-361.qsub") has been submitted
# Your job 1149547 ("samples_361-371.qsub") has been submitted
# Your job 1149548 ("samples_371-381.qsub") has been submitted
# Your job 1149549 ("samples_381-391.qsub") has been submitted
# Your job 1149550 ("samples_391-401.qsub") has been submitted
# Your job 1149551 ("samples_401-411.qsub") has been submitted
# Your job 1149552 ("samples_41-51.qsub") has been submitted
# Your job 1149553 ("samples_411-421.qsub") has been submitted
# Your job 1149554 ("samples_421-431.qsub") has been submitted
# Your job 1149555 ("samples_431-441.qsub") has been submitted
# Your job 1149556 ("samples_441-451.qsub") has been submitted
# Your job 1149557 ("samples_451-461.qsub") has been submitted
# Your job 1149558 ("samples_461-471.qsub") has been submitted
# Your job 1149559 ("samples_471-481.qsub") has been submitted
# Your job 1149560 ("samples_481-491.qsub") has been submitted
# Your job 1149561 ("samples_491-501.qsub") has been submitted
# Your job 1149562 ("samples_501-511.qsub") has been submitted
# Your job 1149563 ("samples_51-61.qsub") has been submitted
# Your job 1149564 ("samples_511-521.qsub") has been submitted
# Your job 1149565 ("samples_521-531.qsub") has been submitted
# Your job 1149566 ("samples_531-541.qsub") has been submitted
# Your job 1149567 ("samples_541-551.qsub") has been submitted
# Your job 1149568 ("samples_551-561.qsub") has been submitted
# Your job 1149569 ("samples_561-571.qsub") has been submitted
# Your job 1149570 ("samples_571-581.qsub") has been submitted
# Your job 1149571 ("samples_581-591.qsub") has been submitted
# Your job 1149572 ("samples_591-601.qsub") has been submitted
# Your job 1149573 ("samples_601-611.qsub") has been submitted
# Your job 1149574 ("samples_61-71.qsub") has been submitted
# Your job 1149575 ("samples_611-621.qsub") has been submitted
# Your job 1149576 ("samples_621-631.qsub") has been submitted
# Your job 1149577 ("samples_631-641.qsub") has been submitted
# Your job 1149578 ("samples_641-651.qsub") has been submitted
# Your job 1149579 ("samples_651-661.qsub") has been submitted
# Your job 1149580 ("samples_661-671.qsub") has been submitted
# Your job 1149581 ("samples_671-681.qsub") has been submitted
# Your job 1149582 ("samples_681-691.qsub") has been submitted
# Your job 1149583 ("samples_691-701.qsub") has been submitted
# Your job 1149584 ("samples_701-711.qsub") has been submitted
# Your job 1149585 ("samples_71-81.qsub") has been submitted
# Your job 1149586 ("samples_711-721.qsub") has been submitted
# Your job 1149587 ("samples_721-731.qsub") has been submitted
# Your job 1149588 ("samples_731-741.qsub") has been submitted
# Your job 1149589 ("samples_741-751.qsub") has been submitted
# Your job 1149590 ("samples_81-91.qsub") has been submitted
# Your job 1149591 ("samples_91-101.qsub") has been submitted
# Your job 1149592 ("samples_1-11.qsub") has been submitted
# Your job 1149593 ("samples_101-111.qsub") has been submitted
# Your job 1149594 ("samples_11-21.qsub") has been submitted
# Your job 1149595 ("samples_111-121.qsub") has been submitted
# Your job 1149596 ("samples_121-131.qsub") has been submitted
# Your job 1149597 ("samples_131-141.qsub") has been submitted
# Your job 1149598 ("samples_141-151.qsub") has been submitted
# Your job 1149599 ("samples_151-161.qsub") has been submitted
# Your job 1149600 ("samples_161-171.qsub") has been submitted
# Your job 1149601 ("samples_171-181.qsub") has been submitted
# Your job 1149602 ("samples_181-191.qsub") has been submitted
# Your job 1149603 ("samples_191-201.qsub") has been submitted
# Your job 1149604 ("samples_201-211.qsub") has been submitted
# Your job 1149605 ("samples_21-31.qsub") has been submitted
# Your job 1149606 ("samples_211-221.qsub") has been submitted
# Your job 1149607 ("samples_221-231.qsub") has been submitted
# Your job 1149608 ("samples_231-241.qsub") has been submitted
# Your job 1149609 ("samples_241-251.qsub") has been submitted
# Your job 1149610 ("samples_251-261.qsub") has been submitted
# Your job 1149611 ("samples_261-271.qsub") has been submitted
# Your job 1149612 ("samples_271-281.qsub") has been submitted
# Your job 1149613 ("samples_281-291.qsub") has been submitted
# Your job 1149614 ("samples_291-301.qsub") has been submitted
# Your job 1149615 ("samples_301-311.qsub") has been submitted
# Your job 1149616 ("samples_31-41.qsub") has been submitted
# Your job 1149617 ("samples_311-321.qsub") has been submitted
# Your job 1149618 ("samples_321-331.qsub") has been submitted
# Your job 1149619 ("samples_331-341.qsub") has been submitted
# Your job 1149620 ("samples_341-351.qsub") has been submitted
# Your job 1149621 ("samples_351-361.qsub") has been submitted
# Your job 1149622 ("samples_361-371.qsub") has been submitted
# Your job 1149623 ("samples_371-381.qsub") has been submitted
# Your job 1149624 ("samples_381-391.qsub") has been submitted
# Your job 1149625 ("samples_391-401.qsub") has been submitted
# Your job 1149626 ("samples_401-411.qsub") has been submitted
# Your job 1149627 ("samples_41-51.qsub") has been submitted
# Your job 1149628 ("samples_411-421.qsub") has been submitted
# Your job 1149629 ("samples_421-431.qsub") has been submitted
# Your job 1149630 ("samples_431-441.qsub") has been submitted
# Your job 1149631 ("samples_441-451.qsub") has been submitted
# Your job 1149632 ("samples_451-461.qsub") has been submitted
# Your job 1149633 ("samples_461-471.qsub") has been submitted
# Your job 1149634 ("samples_471-481.qsub") has been submitted
# Your job 1149635 ("samples_481-491.qsub") has been submitted
# Your job 1149636 ("samples_491-501.qsub") has been submitted
# Your job 1149637 ("samples_501-511.qsub") has been submitted
# Your job 1149638 ("samples_51-61.qsub") has been submitted
# Your job 1149639 ("samples_511-521.qsub") has been submitted
# Your job 1149640 ("samples_521-531.qsub") has been submitted
# Your job 1149641 ("samples_531-541.qsub") has been submitted
# Your job 1149642 ("samples_541-551.qsub") has been submitted
# Your job 1149643 ("samples_551-561.qsub") has been submitted
# Your job 1149644 ("samples_561-571.qsub") has been submitted
# Your job 1149645 ("samples_571-581.qsub") has been submitted
# Your job 1149646 ("samples_581-591.qsub") has been submitted
# Your job 1149647 ("samples_591-601.qsub") has been submitted
# Your job 1149648 ("samples_601-611.qsub") has been submitted
# Your job 1149649 ("samples_61-71.qsub") has been submitted
# Your job 1149650 ("samples_611-621.qsub") has been submitted
# Your job 1149651 ("samples_621-631.qsub") has been submitted
# Your job 1149652 ("samples_631-641.qsub") has been submitted
# Your job 1149653 ("samples_641-651.qsub") has been submitted
# Your job 1149654 ("samples_651-661.qsub") has been submitted
# Your job 1149655 ("samples_661-671.qsub") has been submitted
# Your job 1149656 ("samples_671-681.qsub") has been submitted
# Your job 1149657 ("samples_681-691.qsub") has been submitted
# Your job 1149658 ("samples_691-701.qsub") has been submitted
# Your job 1149659 ("samples_701-711.qsub") has been submitted
# Your job 1149660 ("samples_71-81.qsub") has been submitted
# Your job 1149661 ("samples_711-721.qsub") has been submitted
# Your job 1149662 ("samples_721-731.qsub") has been submitted
# Your job 1149663 ("samples_731-741.qsub") has been submitted
# Your job 1149664 ("samples_741-751.qsub") has been submitted
# Your job 1149665 ("samples_81-91.qsub") has been submitted
# Your job 1149666 ("samples_91-101.qsub") has been submitted
# Your job 1149667 ("samples_1-11.qsub") has been submitted
# Your job 1149668 ("samples_101-111.qsub") has been submitted
# Your job 1149669 ("samples_11-21.qsub") has been submitted
# Your job 1149670 ("samples_111-121.qsub") has been submitted
# Your job 1149671 ("samples_121-131.qsub") has been submitted
# Your job 1149672 ("samples_131-141.qsub") has been submitted
# Your job 1149673 ("samples_141-151.qsub") has been submitted
# Your job 1149674 ("samples_151-161.qsub") has been submitted
# Your job 1149675 ("samples_161-171.qsub") has been submitted
# Your job 1149676 ("samples_171-181.qsub") has been submitted
# Your job 1149677 ("samples_181-191.qsub") has been submitted
# Your job 1149678 ("samples_191-201.qsub") has been submitted
# Your job 1149679 ("samples_201-211.qsub") has been submitted
# Your job 1149680 ("samples_21-31.qsub") has been submitted
# Your job 1149681 ("samples_211-221.qsub") has been submitted
# Your job 1149682 ("samples_221-231.qsub") has been submitted
# Your job 1149683 ("samples_231-241.qsub") has been submitted
# Your job 1149684 ("samples_241-251.qsub") has been submitted
# Your job 1149685 ("samples_251-261.qsub") has been submitted
# Your job 1149686 ("samples_261-271.qsub") has been submitted
# Your job 1149687 ("samples_271-281.qsub") has been submitted
# Your job 1149688 ("samples_281-291.qsub") has been submitted
# Your job 1149689 ("samples_291-301.qsub") has been submitted
# Your job 1149690 ("samples_301-311.qsub") has been submitted
# Your job 1149691 ("samples_31-41.qsub") has been submitted
# Your job 1149692 ("samples_311-321.qsub") has been submitted
# Your job 1149693 ("samples_321-331.qsub") has been submitted
# Your job 1149694 ("samples_331-341.qsub") has been submitted
# Your job 1149695 ("samples_341-351.qsub") has been submitted
# Your job 1149696 ("samples_351-361.qsub") has been submitted
# Your job 1149697 ("samples_361-371.qsub") has been submitted
# Your job 1149698 ("samples_371-381.qsub") has been submitted
# Your job 1149699 ("samples_381-391.qsub") has been submitted
# Your job 1149700 ("samples_391-401.qsub") has been submitted
# Your job 1149701 ("samples_401-411.qsub") has been submitted
# Your job 1149702 ("samples_41-51.qsub") has been submitted
# Your job 1149703 ("samples_411-421.qsub") has been submitted
# Your job 1149704 ("samples_421-431.qsub") has been submitted
# Your job 1149705 ("samples_431-441.qsub") has been submitted
# Your job 1149706 ("samples_441-451.qsub") has been submitted
# Your job 1149707 ("samples_451-461.qsub") has been submitted
# Your job 1149708 ("samples_461-471.qsub") has been submitted
# Your job 1149709 ("samples_471-481.qsub") has been submitted
# Your job 1149710 ("samples_481-491.qsub") has been submitted
# Your job 1149711 ("samples_491-501.qsub") has been submitted
# Your job 1149712 ("samples_501-511.qsub") has been submitted
# Your job 1149713 ("samples_51-61.qsub") has been submitted
# Your job 1149714 ("samples_511-521.qsub") has been submitted
# Your job 1149715 ("samples_521-531.qsub") has been submitted
# Your job 1149716 ("samples_531-541.qsub") has been submitted
# Your job 1149717 ("samples_541-551.qsub") has been submitted
# Your job 1149718 ("samples_551-561.qsub") has been submitted
# Your job 1149719 ("samples_561-571.qsub") has been submitted
# Your job 1149720 ("samples_571-581.qsub") has been submitted
# Your job 1149721 ("samples_581-591.qsub") has been submitted
# Your job 1149722 ("samples_591-601.qsub") has been submitted
# Your job 1149723 ("samples_601-611.qsub") has been submitted
# Your job 1149724 ("samples_61-71.qsub") has been submitted
# Your job 1149725 ("samples_611-621.qsub") has been submitted
# Your job 1149726 ("samples_621-631.qsub") has been submitted
# Your job 1149727 ("samples_631-641.qsub") has been submitted
# Your job 1149728 ("samples_641-651.qsub") has been submitted
# Your job 1149729 ("samples_651-661.qsub") has been submitted
# Your job 1149730 ("samples_661-671.qsub") has been submitted
# Your job 1149731 ("samples_671-681.qsub") has been submitted
# Your job 1149732 ("samples_681-691.qsub") has been submitted
# Your job 1149733 ("samples_691-701.qsub") has been submitted
# Your job 1149734 ("samples_701-711.qsub") has been submitted
# Your job 1149735 ("samples_71-81.qsub") has been submitted
# Your job 1149736 ("samples_711-721.qsub") has been submitted
# Your job 1149737 ("samples_721-731.qsub") has been submitted
# Your job 1149738 ("samples_731-741.qsub") has been submitted
# Your job 1149739 ("samples_741-751.qsub") has been submitted
# Your job 1149740 ("samples_81-91.qsub") has been submitted
# Your job 1149741 ("samples_91-101.qsub") has been submitted
# Your job 1149742 ("samples_1-11.qsub") has been submitted
# Your job 1149743 ("samples_101-111.qsub") has been submitted
# Your job 1149744 ("samples_11-21.qsub") has been submitted
# Your job 1149745 ("samples_111-121.qsub") has been submitted
# Your job 1149746 ("samples_121-131.qsub") has been submitted
# Your job 1149747 ("samples_131-141.qsub") has been submitted
# Your job 1149748 ("samples_141-151.qsub") has been submitted
# Your job 1149749 ("samples_151-161.qsub") has been submitted
# Your job 1149750 ("samples_161-171.qsub") has been submitted
# Your job 1149751 ("samples_171-181.qsub") has been submitted
# Your job 1149752 ("samples_181-191.qsub") has been submitted
# Your job 1149753 ("samples_191-201.qsub") has been submitted
# Your job 1149754 ("samples_201-211.qsub") has been submitted
# Your job 1149755 ("samples_21-31.qsub") has been submitted
# Your job 1149756 ("samples_211-221.qsub") has been submitted
# Your job 1149757 ("samples_221-231.qsub") has been submitted
# Your job 1149758 ("samples_231-241.qsub") has been submitted
# Your job 1149759 ("samples_241-251.qsub") has been submitted
# Your job 1149760 ("samples_251-261.qsub") has been submitted
# Your job 1149761 ("samples_261-271.qsub") has been submitted
# Your job 1149762 ("samples_271-281.qsub") has been submitted
# Your job 1149763 ("samples_281-291.qsub") has been submitted
# Your job 1149764 ("samples_291-301.qsub") has been submitted
# Your job 1149765 ("samples_301-311.qsub") has been submitted
# Your job 1149766 ("samples_31-41.qsub") has been submitted
# Your job 1149767 ("samples_311-321.qsub") has been submitted
# Your job 1149768 ("samples_321-331.qsub") has been submitted
# Your job 1149769 ("samples_331-341.qsub") has been submitted
# Your job 1149770 ("samples_341-351.qsub") has been submitted
# Your job 1149771 ("samples_351-361.qsub") has been submitted
# Your job 1149772 ("samples_361-371.qsub") has been submitted
# Your job 1149773 ("samples_371-381.qsub") has been submitted
# Your job 1149774 ("samples_381-391.qsub") has been submitted
# Your job 1149775 ("samples_391-401.qsub") has been submitted
# Your job 1149776 ("samples_401-411.qsub") has been submitted
# Your job 1149777 ("samples_41-51.qsub") has been submitted
# Your job 1149778 ("samples_411-421.qsub") has been submitted
# Your job 1149779 ("samples_421-431.qsub") has been submitted
# Your job 1149780 ("samples_431-441.qsub") has been submitted
# Your job 1149781 ("samples_441-451.qsub") has been submitted
# Your job 1149782 ("samples_451-461.qsub") has been submitted
# Your job 1149783 ("samples_461-471.qsub") has been submitted
# Your job 1149784 ("samples_471-481.qsub") has been submitted
# Your job 1149785 ("samples_481-491.qsub") has been submitted
# Your job 1149786 ("samples_491-501.qsub") has been submitted
# Your job 1149787 ("samples_501-511.qsub") has been submitted
# Your job 1149788 ("samples_51-61.qsub") has been submitted
# Your job 1149789 ("samples_511-521.qsub") has been submitted
# Your job 1149790 ("samples_521-531.qsub") has been submitted
# Your job 1149791 ("samples_531-541.qsub") has been submitted
# Your job 1149792 ("samples_541-551.qsub") has been submitted
# Your job 1149793 ("samples_551-561.qsub") has been submitted
# Your job 1149794 ("samples_561-571.qsub") has been submitted
# Your job 1149795 ("samples_571-581.qsub") has been submitted
# Your job 1149796 ("samples_581-591.qsub") has been submitted
# Your job 1149797 ("samples_591-601.qsub") has been submitted
# Your job 1149798 ("samples_601-611.qsub") has been submitted
# Your job 1149799 ("samples_61-71.qsub") has been submitted
# Your job 1149800 ("samples_611-621.qsub") has been submitted
# Your job 1149801 ("samples_621-631.qsub") has been submitted
# Your job 1149802 ("samples_631-641.qsub") has been submitted
# Your job 1149803 ("samples_641-651.qsub") has been submitted
# Your job 1149804 ("samples_651-661.qsub") has been submitted
# Your job 1149805 ("samples_661-671.qsub") has been submitted
# Your job 1149806 ("samples_671-681.qsub") has been submitted
# Your job 1149807 ("samples_681-691.qsub") has been submitted
# Your job 1149808 ("samples_691-701.qsub") has been submitted
# Your job 1149809 ("samples_701-711.qsub") has been submitted
# Your job 1149810 ("samples_71-81.qsub") has been submitted
# Your job 1149811 ("samples_711-721.qsub") has been submitted
# Your job 1149812 ("samples_721-731.qsub") has been submitted
# Your job 1149813 ("samples_731-741.qsub") has been submitted
# Your job 1149814 ("samples_741-751.qsub") has been submitted
# Your job 1149815 ("samples_81-91.qsub") has been submitted
# Your job 1149816 ("samples_91-101.qsub") has been submitted
# Your job 1149817 ("samples_1-11.qsub") has been submitted
# Your job 1149818 ("samples_101-111.qsub") has been submitted
# Your job 1149819 ("samples_11-21.qsub") has been submitted
# Your job 1149820 ("samples_111-121.qsub") has been submitted
# Your job 1149821 ("samples_121-131.qsub") has been submitted
# Your job 1149822 ("samples_131-141.qsub") has been submitted
# Your job 1149823 ("samples_141-151.qsub") has been submitted
# Your job 1149824 ("samples_151-161.qsub") has been submitted
# Your job 1149825 ("samples_161-171.qsub") has been submitted
# Your job 1149826 ("samples_171-181.qsub") has been submitted
# Your job 1149827 ("samples_181-191.qsub") has been submitted
# Your job 1149828 ("samples_191-201.qsub") has been submitted
# Your job 1149829 ("samples_201-211.qsub") has been submitted
# Your job 1149830 ("samples_21-31.qsub") has been submitted
# Your job 1149831 ("samples_211-221.qsub") has been submitted
# Your job 1149832 ("samples_221-231.qsub") has been submitted
# Your job 1149833 ("samples_231-241.qsub") has been submitted
# Your job 1149834 ("samples_241-251.qsub") has been submitted
# Your job 1149835 ("samples_251-261.qsub") has been submitted
# Your job 1149836 ("samples_261-271.qsub") has been submitted
# Your job 1149837 ("samples_271-281.qsub") has been submitted
# Your job 1149838 ("samples_281-291.qsub") has been submitted
# Your job 1149839 ("samples_291-301.qsub") has been submitted
# Your job 1149840 ("samples_301-311.qsub") has been submitted
# Your job 1149841 ("samples_31-41.qsub") has been submitted
# Your job 1149842 ("samples_311-321.qsub") has been submitted
# Your job 1149843 ("samples_321-331.qsub") has been submitted
# Your job 1149844 ("samples_331-341.qsub") has been submitted
# Your job 1149845 ("samples_341-351.qsub") has been submitted
# Your job 1149846 ("samples_351-361.qsub") has been submitted
# Your job 1149847 ("samples_361-371.qsub") has been submitted
# Your job 1149848 ("samples_371-381.qsub") has been submitted
# Your job 1149849 ("samples_381-391.qsub") has been submitted
# Your job 1149850 ("samples_391-401.qsub") has been submitted
# Your job 1149851 ("samples_401-411.qsub") has been submitted
# Your job 1149852 ("samples_41-51.qsub") has been submitted
# Your job 1149853 ("samples_411-421.qsub") has been submitted
# Your job 1149854 ("samples_421-431.qsub") has been submitted
# Your job 1149855 ("samples_431-441.qsub") has been submitted
# Your job 1149856 ("samples_441-451.qsub") has been submitted
# Your job 1149857 ("samples_451-461.qsub") has been submitted
# Your job 1149858 ("samples_461-471.qsub") has been submitted
# Your job 1149859 ("samples_471-481.qsub") has been submitted
# Your job 1149860 ("samples_481-491.qsub") has been submitted
# Your job 1149861 ("samples_491-501.qsub") has been submitted
# Your job 1149862 ("samples_501-511.qsub") has been submitted
# Your job 1149863 ("samples_51-61.qsub") has been submitted
# Your job 1149864 ("samples_511-521.qsub") has been submitted
# Your job 1149865 ("samples_521-531.qsub") has been submitted
# Your job 1149866 ("samples_531-541.qsub") has been submitted
# Your job 1149867 ("samples_541-551.qsub") has been submitted
# Your job 1149868 ("samples_551-561.qsub") has been submitted
# Your job 1149869 ("samples_561-571.qsub") has been submitted
# Your job 1149870 ("samples_571-581.qsub") has been submitted
# Your job 1149871 ("samples_581-591.qsub") has been submitted
# Your job 1149872 ("samples_591-601.qsub") has been submitted
# Your job 1149873 ("samples_601-611.qsub") has been submitted
# Your job 1149874 ("samples_61-71.qsub") has been submitted
# Your job 1149875 ("samples_611-621.qsub") has been submitted
# Your job 1149876 ("samples_621-631.qsub") has been submitted
# Your job 1149877 ("samples_631-641.qsub") has been submitted
# Your job 1149878 ("samples_641-651.qsub") has been submitted
# Your job 1149879 ("samples_651-661.qsub") has been submitted
# Your job 1149880 ("samples_661-671.qsub") has been submitted
# Your job 1149881 ("samples_671-681.qsub") has been submitted
# Your job 1149882 ("samples_681-691.qsub") has been submitted
# Your job 1149883 ("samples_691-701.qsub") has been submitted
# Your job 1149884 ("samples_701-711.qsub") has been submitted
# Your job 1149885 ("samples_71-81.qsub") has been submitted
# Your job 1149886 ("samples_711-721.qsub") has been submitted
# Your job 1149887 ("samples_721-731.qsub") has been submitted
# Your job 1149888 ("samples_731-741.qsub") has been submitted
# Your job 1149889 ("samples_741-751.qsub") has been submitted
# Your job 1149890 ("samples_81-91.qsub") has been submitted
# Your job 1149891 ("samples_91-101.qsub") has been submitted
# Your job 1149892 ("samples_1-11.qsub") has been submitted
# Your job 1149893 ("samples_101-111.qsub") has been submitted
# Your job 1149894 ("samples_11-21.qsub") has been submitted
# Your job 1149895 ("samples_111-121.qsub") has been submitted
# Your job 1149896 ("samples_121-131.qsub") has been submitted
# Your job 1149897 ("samples_131-141.qsub") has been submitted
# Your job 1149898 ("samples_141-151.qsub") has been submitted
# Your job 1149899 ("samples_151-161.qsub") has been submitted
# Your job 1149900 ("samples_161-171.qsub") has been submitted
# Your job 1149901 ("samples_171-181.qsub") has been submitted
# Your job 1149902 ("samples_181-191.qsub") has been submitted
# Your job 1149903 ("samples_191-201.qsub") has been submitted
# Your job 1149904 ("samples_201-211.qsub") has been submitted
# Your job 1149905 ("samples_21-31.qsub") has been submitted
# Your job 1149906 ("samples_211-221.qsub") has been submitted
# Your job 1149907 ("samples_221-231.qsub") has been submitted
# Your job 1149908 ("samples_231-241.qsub") has been submitted
# Your job 1149909 ("samples_241-251.qsub") has been submitted
# Your job 1149910 ("samples_251-261.qsub") has been submitted
# Your job 1149911 ("samples_261-271.qsub") has been submitted
# Your job 1149912 ("samples_271-281.qsub") has been submitted
# Your job 1149913 ("samples_281-291.qsub") has been submitted
# Your job 1149914 ("samples_291-301.qsub") has been submitted
# Your job 1149915 ("samples_301-311.qsub") has been submitted
# Your job 1149916 ("samples_31-41.qsub") has been submitted
# Your job 1149917 ("samples_311-321.qsub") has been submitted
# Your job 1149918 ("samples_321-331.qsub") has been submitted
# Your job 1149919 ("samples_331-341.qsub") has been submitted
# Your job 1149920 ("samples_341-351.qsub") has been submitted
# Your job 1149921 ("samples_351-361.qsub") has been submitted
# Your job 1149922 ("samples_361-371.qsub") has been submitted
# Your job 1149923 ("samples_371-381.qsub") has been submitted
# Your job 1149924 ("samples_381-391.qsub") has been submitted
# Your job 1149925 ("samples_391-401.qsub") has been submitted
# Your job 1149926 ("samples_401-411.qsub") has been submitted
# Your job 1149927 ("samples_41-51.qsub") has been submitted
# Your job 1149928 ("samples_411-421.qsub") has been submitted
# Your job 1149929 ("samples_421-431.qsub") has been submitted
# Your job 1149930 ("samples_431-441.qsub") has been submitted
# Your job 1149931 ("samples_441-451.qsub") has been submitted
# Your job 1149932 ("samples_451-461.qsub") has been submitted
# Your job 1149933 ("samples_461-471.qsub") has been submitted
# Your job 1149934 ("samples_471-481.qsub") has been submitted
# Your job 1149935 ("samples_481-491.qsub") has been submitted
# Your job 1149936 ("samples_491-501.qsub") has been submitted
# Your job 1149937 ("samples_501-511.qsub") has been submitted
# Your job 1149938 ("samples_51-61.qsub") has been submitted
# Your job 1149939 ("samples_511-521.qsub") has been submitted
# Your job 1149940 ("samples_521-531.qsub") has been submitted
# Your job 1149941 ("samples_531-541.qsub") has been submitted
# Your job 1149942 ("samples_541-551.qsub") has been submitted
# Your job 1149943 ("samples_551-561.qsub") has been submitted
# Your job 1149944 ("samples_561-571.qsub") has been submitted
# Your job 1149945 ("samples_571-581.qsub") has been submitted
# Your job 1149946 ("samples_581-591.qsub") has been submitted
# Your job 1149947 ("samples_591-601.qsub") has been submitted
# Your job 1149948 ("samples_601-611.qsub") has been submitted
# Your job 1149949 ("samples_61-71.qsub") has been submitted
# Your job 1149950 ("samples_611-621.qsub") has been submitted
# Your job 1149951 ("samples_621-631.qsub") has been submitted
# Your job 1149952 ("samples_631-641.qsub") has been submitted
# Your job 1149953 ("samples_641-651.qsub") has been submitted
# Your job 1149954 ("samples_651-661.qsub") has been submitted
# Your job 1149955 ("samples_661-671.qsub") has been submitted
# Your job 1149956 ("samples_671-681.qsub") has been submitted
# Your job 1149957 ("samples_681-691.qsub") has been submitted
# Your job 1149958 ("samples_691-701.qsub") has been submitted
# Your job 1149959 ("samples_701-711.qsub") has been submitted
# Your job 1149960 ("samples_71-81.qsub") has been submitted
# Your job 1149961 ("samples_711-721.qsub") has been submitted
# Your job 1149962 ("samples_721-731.qsub") has been submitted
# Your job 1149963 ("samples_731-741.qsub") has been submitted
# Your job 1149964 ("samples_741-751.qsub") has been submitted
# Your job 1149965 ("samples_81-91.qsub") has been submitted
# Your job 1149966 ("samples_91-101.qsub") has been submitted
# Your job 1149967 ("samples_1-11.qsub") has been submitted
# Your job 1149968 ("samples_101-111.qsub") has been submitted
# Your job 1149969 ("samples_11-21.qsub") has been submitted
# Your job 1149970 ("samples_111-121.qsub") has been submitted
# Your job 1149971 ("samples_121-131.qsub") has been submitted
# Your job 1149972 ("samples_131-141.qsub") has been submitted
# Your job 1149973 ("samples_141-151.qsub") has been submitted
# Your job 1149974 ("samples_151-161.qsub") has been submitted
# Your job 1149975 ("samples_161-171.qsub") has been submitted
# Your job 1149976 ("samples_171-181.qsub") has been submitted
# Your job 1149977 ("samples_181-191.qsub") has been submitted
# Your job 1149978 ("samples_191-201.qsub") has been submitted
# Your job 1149979 ("samples_201-211.qsub") has been submitted
# Your job 1149980 ("samples_21-31.qsub") has been submitted
# Your job 1149981 ("samples_211-221.qsub") has been submitted
# Your job 1149982 ("samples_221-231.qsub") has been submitted
# Your job 1149983 ("samples_231-241.qsub") has been submitted
# Your job 1149984 ("samples_241-251.qsub") has been submitted
# Your job 1149985 ("samples_251-261.qsub") has been submitted
# Your job 1149986 ("samples_261-271.qsub") has been submitted
# Your job 1149987 ("samples_271-281.qsub") has been submitted
# Your job 1149988 ("samples_281-291.qsub") has been submitted
# Your job 1149989 ("samples_291-301.qsub") has been submitted
# Your job 1149990 ("samples_301-311.qsub") has been submitted
# Your job 1149991 ("samples_31-41.qsub") has been submitted
# Your job 1149992 ("samples_311-321.qsub") has been submitted
# Your job 1149993 ("samples_321-331.qsub") has been submitted
# Your job 1149994 ("samples_331-341.qsub") has been submitted
# Your job 1149995 ("samples_341-351.qsub") has been submitted
# Your job 1149996 ("samples_351-361.qsub") has been submitted
# Your job 1149997 ("samples_361-371.qsub") has been submitted
# Your job 1149998 ("samples_371-381.qsub") has been submitted
# Your job 1149999 ("samples_381-391.qsub") has been submitted
# Your job 1150000 ("samples_391-401.qsub") has been submitted
# Your job 1150001 ("samples_401-411.qsub") has been submitted
# Your job 1150002 ("samples_41-51.qsub") has been submitted
# Your job 1150003 ("samples_411-421.qsub") has been submitted
# Your job 1150004 ("samples_421-431.qsub") has been submitted
# Your job 1150005 ("samples_431-441.qsub") has been submitted
# Your job 1150006 ("samples_441-451.qsub") has been submitted
# Your job 1150007 ("samples_451-461.qsub") has been submitted
# Your job 1150008 ("samples_461-471.qsub") has been submitted
# Your job 1150009 ("samples_471-481.qsub") has been submitted
# Your job 1150010 ("samples_481-491.qsub") has been submitted
# Your job 1150011 ("samples_491-501.qsub") has been submitted
# Your job 1150012 ("samples_501-511.qsub") has been submitted
# Your job 1150013 ("samples_51-61.qsub") has been submitted
# Your job 1150014 ("samples_511-521.qsub") has been submitted
# Your job 1150015 ("samples_521-531.qsub") has been submitted
# Your job 1150016 ("samples_531-541.qsub") has been submitted
# Your job 1150017 ("samples_541-551.qsub") has been submitted
# Your job 1150018 ("samples_551-561.qsub") has been submitted
# Your job 1150019 ("samples_561-571.qsub") has been submitted
# Your job 1150020 ("samples_571-581.qsub") has been submitted
# Your job 1150021 ("samples_581-591.qsub") has been submitted
# Your job 1150022 ("samples_591-601.qsub") has been submitted
# Your job 1150023 ("samples_601-611.qsub") has been submitted
# Your job 1150024 ("samples_61-71.qsub") has been submitted
# Your job 1150025 ("samples_611-621.qsub") has been submitted
# Your job 1150026 ("samples_621-631.qsub") has been submitted
# Your job 1150027 ("samples_631-641.qsub") has been submitted
# Your job 1150028 ("samples_641-651.qsub") has been submitted
# Your job 1150029 ("samples_651-661.qsub") has been submitted
# Your job 1150030 ("samples_661-671.qsub") has been submitted
# Your job 1150031 ("samples_671-681.qsub") has been submitted
# Your job 1150032 ("samples_681-691.qsub") has been submitted
# Your job 1150033 ("samples_691-701.qsub") has been submitted
# Your job 1150034 ("samples_701-711.qsub") has been submitted
# Your job 1150035 ("samples_71-81.qsub") has been submitted
# Your job 1150036 ("samples_711-721.qsub") has been submitted
# Your job 1150037 ("samples_721-731.qsub") has been submitted
# Your job 1150038 ("samples_731-741.qsub") has been submitted
# Your job 1150039 ("samples_741-751.qsub") has been submitted
# Your job 1150040 ("samples_81-91.qsub") has been submitted
# Your job 1150041 ("samples_91-101.qsub") has been submitted
# Your job 1150042 ("samples_1-11.qsub") has been submitted
# Your job 1150043 ("samples_101-111.qsub") has been submitted
# Your job 1150044 ("samples_11-21.qsub") has been submitted
# Your job 1150045 ("samples_111-121.qsub") has been submitted
# Your job 1150046 ("samples_121-131.qsub") has been submitted
# Your job 1150047 ("samples_131-141.qsub") has been submitted
# Your job 1150048 ("samples_141-151.qsub") has been submitted
# Your job 1150049 ("samples_151-161.qsub") has been submitted
# Your job 1150050 ("samples_161-171.qsub") has been submitted
# Your job 1150051 ("samples_171-181.qsub") has been submitted
# Your job 1150052 ("samples_181-191.qsub") has been submitted
# Your job 1150053 ("samples_191-201.qsub") has been submitted
# Your job 1150054 ("samples_201-211.qsub") has been submitted
# Your job 1150055 ("samples_21-31.qsub") has been submitted
# Your job 1150056 ("samples_211-221.qsub") has been submitted
# Your job 1150057 ("samples_221-231.qsub") has been submitted
# Your job 1150058 ("samples_231-241.qsub") has been submitted
# Your job 1150059 ("samples_241-251.qsub") has been submitted
# Your job 1150060 ("samples_251-261.qsub") has been submitted
# Your job 1150061 ("samples_261-271.qsub") has been submitted
# Your job 1150062 ("samples_271-281.qsub") has been submitted
# Your job 1150063 ("samples_281-291.qsub") has been submitted
# Your job 1150064 ("samples_291-301.qsub") has been submitted
# Your job 1150065 ("samples_301-311.qsub") has been submitted
# Your job 1150066 ("samples_31-41.qsub") has been submitted
# Your job 1150067 ("samples_311-321.qsub") has been submitted
# Your job 1150068 ("samples_321-331.qsub") has been submitted
# Your job 1150069 ("samples_331-341.qsub") has been submitted
# Your job 1150070 ("samples_341-351.qsub") has been submitted
# Your job 1150071 ("samples_351-361.qsub") has been submitted
# Your job 1150072 ("samples_361-371.qsub") has been submitted
# Your job 1150073 ("samples_371-381.qsub") has been submitted
# Your job 1150074 ("samples_381-391.qsub") has been submitted
# Your job 1150075 ("samples_391-401.qsub") has been submitted
# Your job 1150076 ("samples_401-411.qsub") has been submitted
# Your job 1150077 ("samples_41-51.qsub") has been submitted
# Your job 1150078 ("samples_411-421.qsub") has been submitted
# Your job 1150079 ("samples_421-431.qsub") has been submitted
# Your job 1150080 ("samples_431-441.qsub") has been submitted
# Your job 1150081 ("samples_441-451.qsub") has been submitted
# Your job 1150082 ("samples_451-461.qsub") has been submitted
# Your job 1150083 ("samples_461-471.qsub") has been submitted
# Your job 1150084 ("samples_471-481.qsub") has been submitted
# Your job 1150085 ("samples_481-491.qsub") has been submitted
# Your job 1150086 ("samples_491-501.qsub") has been submitted
# Your job 1150087 ("samples_501-511.qsub") has been submitted
# Your job 1150088 ("samples_51-61.qsub") has been submitted
# Your job 1150089 ("samples_511-521.qsub") has been submitted
# Your job 1150090 ("samples_521-531.qsub") has been submitted
# Your job 1150091 ("samples_531-541.qsub") has been submitted
# Your job 1150092 ("samples_541-551.qsub") has been submitted
# Your job 1150093 ("samples_551-561.qsub") has been submitted
# Your job 1150094 ("samples_561-571.qsub") has been submitted
# Your job 1150095 ("samples_571-581.qsub") has been submitted
# Your job 1150096 ("samples_581-591.qsub") has been submitted
# Your job 1150097 ("samples_591-601.qsub") has been submitted
# Your job 1150098 ("samples_601-611.qsub") has been submitted
# Your job 1150099 ("samples_61-71.qsub") has been submitted
# Your job 1150100 ("samples_611-621.qsub") has been submitted
# Your job 1150101 ("samples_621-631.qsub") has been submitted
# Your job 1150102 ("samples_631-641.qsub") has been submitted
# Your job 1150103 ("samples_641-651.qsub") has been submitted
# Your job 1150104 ("samples_651-661.qsub") has been submitted
# Your job 1150105 ("samples_661-671.qsub") has been submitted
# Your job 1150106 ("samples_671-681.qsub") has been submitted
# Your job 1150107 ("samples_681-691.qsub") has been submitted
# Your job 1150108 ("samples_691-701.qsub") has been submitted
# Your job 1150109 ("samples_701-711.qsub") has been submitted
# Your job 1150110 ("samples_71-81.qsub") has been submitted
# Your job 1150111 ("samples_711-721.qsub") has been submitted
# Your job 1150112 ("samples_721-731.qsub") has been submitted
# Your job 1150113 ("samples_731-741.qsub") has been submitted
# Your job 1150114 ("samples_741-751.qsub") has been submitted
# Your job 1150115 ("samples_81-91.qsub") has been submitted
# Your job 1150116 ("samples_91-101.qsub") has been submitted
# Your job 1150117 ("samples_1-11.qsub") has been submitted
# Your job 1150118 ("samples_101-111.qsub") has been submitted
# Your job 1150119 ("samples_11-21.qsub") has been submitted
# Your job 1150120 ("samples_111-121.qsub") has been submitted
# Your job 1150121 ("samples_121-131.qsub") has been submitted
# Your job 1150122 ("samples_131-141.qsub") has been submitted
# Your job 1150123 ("samples_141-151.qsub") has been submitted
# Your job 1150124 ("samples_151-161.qsub") has been submitted
# Your job 1150125 ("samples_161-171.qsub") has been submitted
# Your job 1150126 ("samples_171-181.qsub") has been submitted
# Your job 1150127 ("samples_181-191.qsub") has been submitted
# Your job 1150128 ("samples_191-201.qsub") has been submitted
# Your job 1150129 ("samples_201-211.qsub") has been submitted
# Your job 1150130 ("samples_21-31.qsub") has been submitted
# Your job 1150131 ("samples_211-221.qsub") has been submitted
# Your job 1150132 ("samples_221-231.qsub") has been submitted
# Your job 1150133 ("samples_231-241.qsub") has been submitted
# Your job 1150134 ("samples_241-251.qsub") has been submitted
# Your job 1150135 ("samples_251-261.qsub") has been submitted
# Your job 1150136 ("samples_261-271.qsub") has been submitted
# Your job 1150137 ("samples_271-281.qsub") has been submitted
# Your job 1150138 ("samples_281-291.qsub") has been submitted
# Your job 1150139 ("samples_291-301.qsub") has been submitted
# Your job 1150140 ("samples_301-311.qsub") has been submitted
# Your job 1150141 ("samples_31-41.qsub") has been submitted
# Your job 1150142 ("samples_311-321.qsub") has been submitted
# Your job 1150143 ("samples_321-331.qsub") has been submitted
# Your job 1150144 ("samples_331-341.qsub") has been submitted
# Your job 1150145 ("samples_341-351.qsub") has been submitted
# Your job 1150146 ("samples_351-361.qsub") has been submitted
# Your job 1150147 ("samples_361-371.qsub") has been submitted
# Your job 1150148 ("samples_371-381.qsub") has been submitted
# Your job 1150149 ("samples_381-391.qsub") has been submitted
# Your job 1150150 ("samples_391-401.qsub") has been submitted
# Your job 1150151 ("samples_401-411.qsub") has been submitted
# Your job 1150152 ("samples_41-51.qsub") has been submitted
# Your job 1150153 ("samples_411-421.qsub") has been submitted
# Your job 1150154 ("samples_421-431.qsub") has been submitted
# Your job 1150155 ("samples_431-441.qsub") has been submitted
# Your job 1150156 ("samples_441-451.qsub") has been submitted
# ...
# Your job 1150754 ("samples_421-431.qsub") has been submitted
# Your job 1150755 ("samples_431-441.qsub") has been submitted
# Your job 1150756 ("samples_441-451.qsub") has been submitted
# Your job 1150757 ("samples_451-461.qsub") has been submitted
# Your job 1150758 ("samples_461-471.qsub") has been submitted
# Your job 1150759 ("samples_471-481.qsub") has been submitted
# Your job 1150760 ("samples_481-491.qsub") has been submitted
# Your job 1150761 ("samples_491-501.qsub") has been submitted
# Your job 1150762 ("samples_501-511.qsub") has been submitted
# Your job 1150763 ("samples_51-61.qsub") has been submitted
# Your job 1150764 ("samples_511-521.qsub") has been submitted
# Your job 1150765 ("samples_521-531.qsub") has been submitted
# Your job 1150766 ("samples_531-541.qsub") has been submitted
# Your job 1150767 ("samples_541-551.qsub") has been submitted
# Your job 1150768 ("samples_551-561.qsub") has been submitted
# Your job 1150769 ("samples_561-571.qsub") has been submitted
# Your job 1150770 ("samples_571-581.qsub") has been submitted
# Your job 1150771 ("samples_581-591.qsub") has been submitted
# Your job 1150772 ("samples_591-601.qsub") has been submitted
# Your job 1150773 ("samples_601-611.qsub") has been submitted
# Your job 1150774 ("samples_61-71.qsub") has been submitted
# Your job 1150775 ("samples_611-621.qsub") has been submitted
# Your job 1150776 ("samples_621-631.qsub") has been submitted
# Your job 1150777 ("samples_631-641.qsub") has been submitted
# Your job 1150778 ("samples_641-651.qsub") has been submitted
# Your job 1150779 ("samples_651-661.qsub") has been submitted
# Your job 1150780 ("samples_661-671.qsub") has been submitted
# Your job 1150781 ("samples_671-681.qsub") has been submitted
# Your job 1150782 ("samples_681-691.qsub") has been submitted
# Your job 1150783 ("samples_691-701.qsub") has been submitted
# Your job 1150784 ("samples_701-711.qsub") has been submitted
# Your job 1150785 ("samples_71-81.qsub") has been submitted
# Your job 1150786 ("samples_711-721.qsub") has been submitted
# Your job 1150787 ("samples_721-731.qsub") has been submitted
# Your job 1150788 ("samples_731-741.qsub") has been submitted
# Your job 1150789 ("samples_741-751.qsub") has been submitted
# Your job 1150790 ("samples_81-91.qsub") has been submitted
# Your job 1150791 ("samples_91-101.qsub") has been submitted
# Your job 1150792 ("samples_1-11.qsub") has been submitted
# Your job 1150793 ("samples_101-111.qsub") has been submitted
# Your job 1150794 ("samples_11-21.qsub") has been submitted
# Your job 1150795 ("samples_111-121.qsub") has been submitted
# Your job 1150796 ("samples_121-131.qsub") has been submitted
# Your job 1150797 ("samples_131-141.qsub") has been submitted
# Your job 1150798 ("samples_141-151.qsub") has been submitted
# Your job 1150799 ("samples_151-161.qsub") has been submitted
# Your job 1150800 ("samples_161-171.qsub") has been submitted
# Your job 1150801 ("samples_171-181.qsub") has been submitted
# Your job 1150802 ("samples_181-191.qsub") has been submitted
# Your job 1150803 ("samples_191-201.qsub") has been submitted
# Your job 1150804 ("samples_201-211.qsub") has been submitted
# Your job 1150805 ("samples_21-31.qsub") has been submitted
# Your job 1150806 ("samples_211-221.qsub") has been submitted
# Your job 1150807 ("samples_221-231.qsub") has been submitted
# Your job 1150808 ("samples_231-241.qsub") has been submitted
# Your job 1150809 ("samples_241-251.qsub") has been submitted
# Your job 1150810 ("samples_251-261.qsub") has been submitted
# Your job 1150811 ("samples_261-271.qsub") has been submitted
# Your job 1150812 ("samples_271-281.qsub") has been submitted
# Your job 1150813 ("samples_281-291.qsub") has been submitted
# Your job 1150814 ("samples_291-301.qsub") has been submitted
# Your job 1150815 ("samples_301-311.qsub") has been submitted
# Your job 1150816 ("samples_31-41.qsub") has been submitted
# Your job 1150817 ("samples_311-321.qsub") has been submitted
# Your job 1150818 ("samples_321-331.qsub") has been submitted
# Your job 1150819 ("samples_331-341.qsub") has been submitted
# Your job 1150820 ("samples_341-351.qsub") has been submitted
# Your job 1150821 ("samples_351-361.qsub") has been submitted
# Your job 1150822 ("samples_361-371.qsub") has been submitted
# Your job 1150823 ("samples_371-381.qsub") has been submitted
# Your job 1150824 ("samples_381-391.qsub") has been submitted
# Your job 1150825 ("samples_391-401.qsub") has been submitted
# Your job 1150826 ("samples_401-411.qsub") has been submitted
# Your job 1150827 ("samples_41-51.qsub") has been submitted
# Your job 1150828 ("samples_411-421.qsub") has been submitted
# Your job 1150829 ("samples_421-431.qsub") has been submitted
# Your job 1150830 ("samples_431-441.qsub") has been submitted
# Your job 1150831 ("samples_441-451.qsub") has been submitted
# Your job 1150832 ("samples_451-461.qsub") has been submitted
# Your job 1150833 ("samples_461-471.qsub") has been submitted
# Your job 1150834 ("samples_471-481.qsub") has been submitted
# Your job 1150835 ("samples_481-491.qsub") has been submitted
# Your job 1150836 ("samples_491-501.qsub") has been submitted
# Your job 1150837 ("samples_501-511.qsub") has been submitted
# Your job 1150838 ("samples_51-61.qsub") has been submitted
# Your job 1150839 ("samples_511-521.qsub") has been submitted
# Your job 1150840 ("samples_521-531.qsub") has been submitted
# Your job 1150841 ("samples_531-541.qsub") has been submitted
# Your job 1150842 ("samples_541-551.qsub") has been submitted
# Your job 1150843 ("samples_551-561.qsub") has been submitted
# Your job 1150844 ("samples_561-571.qsub") has been submitted
# Your job 1150845 ("samples_571-581.qsub") has been submitted
# Your job 1150846 ("samples_581-591.qsub") has been submitted
# Your job 1150847 ("samples_591-601.qsub") has been submitted
# Your job 1150848 ("samples_601-611.qsub") has been submitted
# Your job 1150849 ("samples_61-71.qsub") has been submitted
# Your job 1150850 ("samples_611-621.qsub") has been submitted
# Your job 1150851 ("samples_621-631.qsub") has been submitted
# Your job 1150852 ("samples_631-641.qsub") has been submitted
# Your job 1150853 ("samples_641-651.qsub") has been submitted
# Your job 1150854 ("samples_651-661.qsub") has been submitted
# Your job 1150855 ("samples_661-671.qsub") has been submitted
# Your job 1150856 ("samples_671-681.qsub") has been submitted
# Your job 1150857 ("samples_681-691.qsub") has been submitted
# Your job 1150858 ("samples_691-701.qsub") has been submitted
# Your job 1150859 ("samples_701-711.qsub") has been submitted
# Your job 1150860 ("samples_71-81.qsub") has been submitted
# Your job 1150861 ("samples_711-721.qsub") has been submitted
# Your job 1150862 ("samples_721-731.qsub") has been submitted
# Your job 1150863 ("samples_731-741.qsub") has been submitted
# Your job 1150864 ("samples_741-751.qsub") has been submitted
# Your job 1150865 ("samples_81-91.qsub") has been submitted
# Your job 1150866 ("samples_91-101.qsub") has been submitted
# Your job 1150867 ("samples_1-11.qsub") has been submitted
# Your job 1150868 ("samples_101-111.qsub") has been submitted
# Your job 1150869 ("samples_11-21.qsub") has been submitted
# Your job 1150870 ("samples_111-121.qsub") has been submitted
# Your job 1150871 ("samples_121-131.qsub") has been submitted
# Your job 1150872 ("samples_131-141.qsub") has been submitted
# Your job 1150873 ("samples_141-151.qsub") has been submitted
# Your job 1150874 ("samples_151-161.qsub") has been submitted
# Your job 1150875 ("samples_161-171.qsub") has been submitted
# Your job 1150876 ("samples_171-181.qsub") has been submitted
# Your job 1150877 ("samples_181-191.qsub") has been submitted
# Your job 1150878 ("samples_191-201.qsub") has been submitted
# Your job 1150879 ("samples_201-211.qsub") has been submitted
# Your job 1150880 ("samples_21-31.qsub") has been submitted
# Your job 1150881 ("samples_211-221.qsub") has been submitted
# Your job 1150882 ("samples_221-231.qsub") has been submitted
# Your job 1150883 ("samples_231-241.qsub") has been submitted
# Your job 1150884 ("samples_241-251.qsub") has been submitted
# Your job 1150885 ("samples_251-261.qsub") has been submitted
# Your job 1150886 ("samples_261-271.qsub") has been submitted
# Your job 1150887 ("samples_271-281.qsub") has been submitted
# Your job 1150888 ("samples_281-291.qsub") has been submitted
# Your job 1150889 ("samples_291-301.qsub") has been submitted
# Your job 1150890 ("samples_301-311.qsub") has been submitted
# Your job 1150891 ("samples_31-41.qsub") has been submitted
# Your job 1150892 ("samples_311-321.qsub") has been submitted
# Your job 1150893 ("samples_321-331.qsub") has been submitted
# Your job 1150894 ("samples_331-341.qsub") has been submitted
# Your job 1150895 ("samples_341-351.qsub") has been submitted
# Your job 1150896 ("samples_351-361.qsub") has been submitted
# Your job 1150897 ("samples_361-371.qsub") has been submitted
# Your job 1150898 ("samples_371-381.qsub") has been submitted
# Your job 1150899 ("samples_381-391.qsub") has been submitted
# Your job 1150900 ("samples_391-401.qsub") has been submitted
# Your job 1150901 ("samples_401-411.qsub") has been submitted
# Your job 1150902 ("samples_41-51.qsub") has been submitted
# Your job 1150903 ("samples_411-421.qsub") has been submitted
# Your job 1150904 ("samples_421-431.qsub") has been submitted
# Your job 1150905 ("samples_431-441.qsub") has been submitted
# Your job 1150906 ("samples_441-451.qsub") has been submitted
# Your job 1150907 ("samples_451-461.qsub") has been submitted
# Your job 1150908 ("samples_461-471.qsub") has been submitted
# Your job 1150909 ("samples_471-481.qsub") has been submitted
# Your job 1150910 ("samples_481-491.qsub") has been submitted
# Your job 1150911 ("samples_491-501.qsub") has been submitted
# Your job 1150912 ("samples_501-511.qsub") has been submitted
# Your job 1150913 ("samples_51-61.qsub") has been submitted
# Your job 1150914 ("samples_511-521.qsub") has been submitted
# Your job 1150915 ("samples_521-531.qsub") has been submitted
# Your job 1150916 ("samples_531-541.qsub") has been submitted
# Your job 1150917 ("samples_541-551.qsub") has been submitted
# Your job 1150918 ("samples_551-561.qsub") has been submitted
# Your job 1150919 ("samples_561-571.qsub") has been submitted
# Your job 1150920 ("samples_571-581.qsub") has been submitted
# Your job 1150921 ("samples_581-591.qsub") has been submitted
# Your job 1150922 ("samples_591-601.qsub") has been submitted
# Your job 1150923 ("samples_601-611.qsub") has been submitted
# Your job 1150924 ("samples_61-71.qsub") has been submitted
# Your job 1150925 ("samples_611-621.qsub") has been submitted
# Your job 1150926 ("samples_621-631.qsub") has been submitted
# Your job 1150927 ("samples_631-641.qsub") has been submitted
# Your job 1150928 ("samples_641-651.qsub") has been submitted
# Your job 1150929 ("samples_651-661.qsub") has been submitted
# Your job 1150930 ("samples_661-671.qsub") has been submitted
# Your job 1150931 ("samples_671-681.qsub") has been submitted
# Your job 1150932 ("samples_681-691.qsub") has been submitted
# Your job 1150933 ("samples_691-701.qsub") has been submitted
# Your job 1150934 ("samples_701-711.qsub") has been submitted
# Your job 1150935 ("samples_71-81.qsub") has been submitted
# Your job 1150936 ("samples_711-721.qsub") has been submitted
# Your job 1150937 ("samples_721-731.qsub") has been submitted
# Your job 1150938 ("samples_731-741.qsub") has been submitted
# Your job 1150939 ("samples_741-751.qsub") has been submitted
# Your job 1150940 ("samples_81-91.qsub") has been submitted
# Your job 1150941 ("samples_91-101.qsub") has been submitted
# Your job 1150942 ("samples_1-11.qsub") has been submitted
# Your job 1150943 ("samples_101-111.qsub") has been submitted
# Your job 1150944 ("samples_11-21.qsub") has been submitted
# Your job 1150945 ("samples_111-121.qsub") has been submitted
# Your job 1150946 ("samples_121-131.qsub") has been submitted
# Your job 1150947 ("samples_131-141.qsub") has been submitted
# Your job 1150948 ("samples_141-151.qsub") has been submitted
# Your job 1150949 ("samples_151-161.qsub") has been submitted
# Your job 1150950 ("samples_161-171.qsub") has been submitted
# Your job 1150951 ("samples_171-181.qsub") has been submitted
# Your job 1150952 ("samples_181-191.qsub") has been submitted
# Your job 1150953 ("samples_191-201.qsub") has been submitted
# Your job 1150954 ("samples_201-211.qsub") has been submitted
# Your job 1150955 ("samples_21-31.qsub") has been submitted
# Your job 1150956 ("samples_211-221.qsub") has been submitted
# Your job 1150957 ("samples_221-231.qsub") has been submitted
# Your job 1150958 ("samples_231-241.qsub") has been submitted
# Your job 1150959 ("samples_241-251.qsub") has been submitted
# Your job 1150960 ("samples_251-261.qsub") has been submitted
# Your job 1150961 ("samples_261-271.qsub") has been submitted
# Your job 1150962 ("samples_271-281.qsub") has been submitted
# Your job 1150963 ("samples_281-291.qsub") has been submitted
# Your job 1150964 ("samples_291-301.qsub") has been submitted
# Your job 1150965 ("samples_301-311.qsub") has been submitted
# Your job 1150966 ("samples_31-41.qsub") has been submitted
# Your job 1150967 ("samples_311-321.qsub") has been submitted
# Your job 1150968 ("samples_321-331.qsub") has been submitted
# Your job 1150969 ("samples_331-341.qsub") has been submitted
# Your job 1150970 ("samples_341-351.qsub") has been submitted
# Your job 1150971 ("samples_351-361.qsub") has been submitted
# Your job 1150972 ("samples_361-371.qsub") has been submitted
# Your job 1150973 ("samples_371-381.qsub") has been submitted
# Your job 1150974 ("samples_381-391.qsub") has been submitted
# Your job 1150975 ("samples_391-401.qsub") has been submitted
# Your job 1150976 ("samples_401-411.qsub") has been submitted
# Your job 1150977 ("samples_41-51.qsub") has been submitted
# Your job 1150978 ("samples_411-421.qsub") has been submitted
# Your job 1150979 ("samples_421-431.qsub") has been submitted
# Your job 1150980 ("samples_431-441.qsub") has been submitted
# Your job 1150981 ("samples_441-451.qsub") has been submitted
# Your job 1150982 ("samples_451-461.qsub") has been submitted
# Your job 1150983 ("samples_461-471.qsub") has been submitted
# Your job 1150984 ("samples_471-481.qsub") has been submitted
# Your job 1150985 ("samples_481-491.qsub") has been submitted
# Your job 1150986 ("samples_491-501.qsub") has been submitted
# Your job 1150987 ("samples_501-511.qsub") has been submitted
# Your job 1150988 ("samples_51-61.qsub") has been submitted
# Your job 1150989 ("samples_511-521.qsub") has been submitted
# Your job 1150990 ("samples_521-531.qsub") has been submitted
# Your job 1150991 ("samples_531-541.qsub") has been submitted
# Your job 1150992 ("samples_541-551.qsub") has been submitted
# Your job 1150993 ("samples_551-561.qsub") has been submitted
# Your job 1150994 ("samples_561-571.qsub") has been submitted
# Your job 1150995 ("samples_571-581.qsub") has been submitted
# Your job 1150996 ("samples_581-591.qsub") has been submitted
# Your job 1150997 ("samples_591-601.qsub") has been submitted
# Your job 1150998 ("samples_601-611.qsub") has been submitted
# Your job 1150999 ("samples_61-71.qsub") has been submitted
# Your job 1151000 ("samples_611-621.qsub") has been submitted
# Your job 1151001 ("samples_621-631.qsub") has been submitted
# Your job 1151002 ("samples_631-641.qsub") has been submitted
# Your job 1151003 ("samples_641-651.qsub") has been submitted
# Your job 1151004 ("samples_651-661.qsub") has been submitted
# Your job 1151005 ("samples_661-671.qsub") has been submitted
# Your job 1151006 ("samples_671-681.qsub") has been submitted
# Your job 1151007 ("samples_681-691.qsub") has been submitted
# Your job 1151008 ("samples_691-701.qsub") has been submitted
# Your job 1151009 ("samples_701-711.qsub") has been submitted
# Your job 1151010 ("samples_71-81.qsub") has been submitted
# Your job 1151011 ("samples_711-721.qsub") has been submitted
# Your job 1151012 ("samples_721-731.qsub") has been submitted
# Your job 1151013 ("samples_731-741.qsub") has been submitted
# Your job 1151014 ("samples_741-751.qsub") has been submitted
# Your job 1151015 ("samples_81-91.qsub") has been submitted
# Your job 1151016 ("samples_91-101.qsub") has been submitted

# %% [markdown]
# #### Check number of files output

# %%
# %%bash
#
# PROJECT=nimblegen_capture_NOV19
# CANCER_NAME=BRCA
#
# for TISSUE in  Blood_Normal
# do
#     for i in {1..22}; do echo "chr"${i} ${TISSUE}; ls /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/${PROJECT}_chr${i}/${CANCER_NAME}/${TISSUE}/White/*idx | wc -l;ls /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/${PROJECT}_chr${i}/${CANCER_NAME}/${TISSUE}/Black/*idx | wc -l; done;
# done
# Out:
# chr1 Blood_Normal
# 581
# 161
# chr2 Blood_Normal
# 581
# 161
# chr3 Blood_Normal
# 581
# 161
# chr4 Blood_Normal
# 581
# 161
# chr5 Blood_Normal
# 581
# 161
# chr6 Blood_Normal
# 581
# 161
# chr7 Blood_Normal
# 581
# 161
# chr8 Blood_Normal
# 581
# 161
# chr9 Blood_Normal
# 581
# 161
# chr10 Blood_Normal
# 581
# 161
# chr11 Blood_Normal
# 581
# 161
# chr12 Blood_Normal
# 581
# 161
# chr13 Blood_Normal
# 581
# 161
# chr14 Blood_Normal
# 581
# 161
# chr15 Blood_Normal
# 581
# 161
# chr16 Blood_Normal
# 581
# 161
# chr17 Blood_Normal
# 581
# 161
# chr18 Blood_Normal
# 581
# 161
# chr19 Blood_Normal
# 581
# 161
# chr20 Blood_Normal
# 581
# 161
# chr21 Blood_Normal
# 581
# 161
# chr22 Blood_Normal
# 581
# 161

# %% [markdown]
# ### 3. Run CombineGVCFs on GVCFs

# %%
# %%bash
#
#
# for i in {1..22}; do
#
#     PROJECT=nimblegen_capture_NOV19_chr${i}
#     CANCER_NAME=BRCA
#     TISSUE=Blood_Normal
#
#
#     #create directory for output
#     mkdir /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/combined
#
#     #list all8 GVCFs
#     ls /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/*/*vcf > /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_${TISSUE}_gvcf_list.txt
#
#     grep ${TISSUE} /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_${TISSUE}_gvcf_list.txt | grep "White" > /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_gvcf_list_${TISSUE}_White.txt
#
#     grep ${TISSUE} /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_${TISSUE}_gvcf_list.txt | grep "Black" > /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_gvcf_list_${TISSUE}_Black.txt
#
#
#
#     for GROUP in {${TISSUE}_White,${TISSUE}_Black};
#      do
#
#     #create scripts for sets of 50 samples
#     TOTAL_NUMBER_OF_GVCFS=`wc -l /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_gvcf_list_${GROUP}.txt | cut -d ' ' -f1`
#     NUMBER_OF_SPLITS=`echo $((TOTAL_NUMBER_OF_GVCFS/50))`
#     GVCF_LOOP_END=`echo $((NUMBER_OF_SPLITS*50))`
#
#
#     COUNTER=1
#     COUNTER2=50
#
#      #the positional variables in awk correspond to the order of cols in the GVCF_list.txt generated above
#      #group gvcfs into sets of 50, and use list of samples/paths in that group as parameter to CombineGVCFs
#      #use tr to remove newline characters in the lists, replacing all except the last one with '--variant'
#
#      until [ ${COUNTER} -eq $(($GVCF_LOOP_END+51)) ]; do echo -e "java -Xmx15g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T CombineGVCFs -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa --variant " | tr '\n' ' ' > /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/combined_${GROUP}_${COUNTER}-${COUNTER2}.qsub; awk -v a=${COUNTER} -v b=${COUNTER2} "NR==a,NR==b" /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}/${CANCER_NAME}_gvcf_list_${GROUP}.txt | tr '\n' '\t' | sed '$s/\t$/ /' | sed 's/\t/ --variant /g' >> /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/combined_${GROUP}_${COUNTER}-${COUNTER2}.qsub; echo "-o /home/mayo/m187735/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/combined/${GROUP}_samples_${COUNTER}-${COUNTER2}.g.vcf" >> /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/combined_${GROUP}_${COUNTER}-${COUNTER2}.qsub;COUNTER=`echo $((${COUNTER}+50))`;COUNTER2=`echo $((${COUNTER}+49))`;done;
#     done
#
#
#     rm /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}
("combined_Blood_Normal_White_51-100.qsub") has been submitted
# Your job 1161533 ("combined_Blood_Normal_White_551-600.qsub") has been submitted
# Your job 1161534 ("combined_Blood_Normal_Black_1-50.qsub") has been submitted
# Your job 1161535 ("combined_Blood_Normal_Black_101-150.qsub") has been submitted
# Your job 1161536 ("combined_Blood_Normal_Black_151-200.qsub") has been submitted
# Your job 1161537 ("combined_Blood_Normal_Black_51-100.qsub") has been submitted
# Your job 1161538 ("combined_Blood_Normal_White_1-50.qsub") has been submitted
# Your job 1161539 ("combined_Blood_Normal_White_101-150.qsub") has been submitted
# Your job 1161540 ("combined_Blood_Normal_White_151-200.qsub") has been submitted
# Your job 1161541 ("combined_Blood_Normal_White_201-250.qsub") has been submitted
# Your job 1161542 ("combined_Blood_Normal_White_251-300.qsub") has been submitted
# Your job 1161543 ("combined_Blood_Normal_White_301-350.qsub") has been submitted
# Your job 1161544 ("combined_Blood_Normal_White_351-400.qsub") has been submitted
# Your job 1161545 ("combined_Blood_Normal_White_401-450.qsub") has been submitted
# Your job 1161546 ("combined_Blood_Normal_White_451-500.qsub") has been submitted
# Your job 1161547 ("combined_Blood_Normal_White_501-550.qsub") has been submitted
# Your job 1161548 ("combined_Blood_Normal_White_51-100.qsub") has been submitted
# Your job 1161549 ("combined_Blood_Normal_White_551-600.qsub") has been submitted

# %% [markdown]
# #### Check number of files output

# %%
# %%bash
#
# PROJECT=nimblegen_capture_NOV19
# CANCER_NAME=BRCA
#
# for TISSUE in Blood_Normal
# do
# 	for i in {1..22}; do echo "chr"${i} ${TISSUE}; ls /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/${PROJECT}_chr${i}/${CANCER_NAME}/${TISSUE}/combined/*vcf |wc -l ;ls /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/${PROJECT}_chr${i}/${CANCER_NAME}/${TISSUE}/combined/*idx | wc -l;done;
# done
# Out:
# chr1 Blood_Normal
# 16
# 16
# chr2 Blood_Normal
# 16
# 16
# chr3 Blood_Normal
# 16
# 16
# chr4 Blood_Normal
# 16
# 16
# chr5 Blood_Normal
# 16
# 16
# chr6 Blood_Normal
# 16
# 16
# chr7 Blood_Normal
# 16
# 16
# chr8 Blood_Normal
# 16
# 16
# chr9 Blood_Normal
# 16
# 16
# chr10 Blood_Normal
# 16
# 16
# chr11 Blood_Normal
# 16
# 16
# chr12 Blood_Normal
# 16
# 16
# chr13 Blood_Normal
# 16
# 16
# chr14 Blood_Normal
# 16
# 16
# chr15 Blood_Normal
# 16
# 16
# chr16 Blood_Normal
# 16
# 16
# chr17 Blood_Normal
# 16
# 16
# chr18 Blood_Normal
# 16
# 16
# chr19 Blood_Normal
# 16
# 16
# chr20 Blood_Normal
# 16
# 16
# chr21 Blood_Normal
# 16
# 16
# chr22 Blood_Normal
# 16
# 16

# %% [markdown]
# ### 4. Run GenotypeGVCFs on combined GVCFs

# %%
# %%bash
#
#
# for i in {1..22}; do
#
#     CANCER_NAME=BRCA
#     TISSUE=Blood_Normal
#     PROJECT=nimblegen_capture_NOV19_chr${i}
#
#     #create directory for output
#     OUTPUT_DIR=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}
#
#     if [ -d "/home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/" ];
#     then rm -r ${OUTPUT_DIR};
#     fi;
#
#     mkdir -p $OUTPUT_DIR
#     mkdir -p /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/GenotypeGVCFs_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}
#
#     INPUT_DIR=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/HaplotypeCaller_on_TCGA_bams/${PROJECT}/${CANCER_NAME}/${TISSUE}/combined/
#
#     #for GROUP in {${TISSUE}_Black,${TISSUE}_White};
#     #	do
#         #	for GVCF in ${INPUT_DIR}/${GROUP}_samples*g.vcf; do GVCFS_LIST="${GVCFS_LIST} --variant ${GVCF}"; done
#             for GVCF in ${INPUT_DIR}/*samples*g.vcf; do GVCFS_LIST="${GVCFS_LIST} --variant ${GVCF}"; done
#
#             #echo "java -Xmx20g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T GenotypeGVCFs -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa ${GVCFS_LIST} -o ${OUTPUT_DIR}/${GROUP}.vcf --disable_auto_index_creation_and_locking_when_reading_rods -nt 24" > /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/GenotypeGVCFs_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/${GROUP}.qsub
#             echo "java -Xmx20g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T GenotypeGVCFs -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa ${GVCFS_LIST} -o ${OUTPUT_DIR}/BlackWhite.vcf --disable_auto_index_creation_and_locking_when_reading_rods -nt 24" > /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/GenotypeGVCFs_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/BlackWhite.qsub
#             GVCFS_LIST=""
#     #done
#
#
#     rm /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/GenotypeGVCFs_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/*err 2> /dev/null
#     rm /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/GenotypeGVCFs_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/*out 2> /dev/null
#
#     for file in /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/GenotypeGVCFs_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/*qsub; do qsub -l h_vmem=20G -e /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/GenotypeGVCFs_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/`basename ${file} .qsub`.err -o /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/GenotypeGVCFs_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/`basename ${file} .qsub`.out -q 4-day -pe threaded 24 -N chr${i}_GenotypeGVCFs $file;done;
# done
# Out:
# Your job 1161714 ("chr1_GenotypeGVCFs") has been submitted
# Your job 1161715 ("chr2_GenotypeGVCFs") has been submitted
# Your job 1161716 ("chr3_GenotypeGVCFs") has been submitted
# Your job 1161717 ("chr4_GenotypeGVCFs") has been submitted
# Your job 1161718 ("chr5_GenotypeGVCFs") has been submitted
# Your job 1161719 ("chr6_GenotypeGVCFs") has been submitted
# Your job 1161720 ("chr7_GenotypeGVCFs") has been submitted
# Your job 1161721 ("chr8_GenotypeGVCFs") has been submitted
# Your job 1161722 ("chr9_GenotypeGVCFs") has been submitted
# Your job 1161723 ("chr10_GenotypeGVCFs") has been submitted
# Your job 1161724 ("chr11_GenotypeGVCFs") has been submitted
# Your job 1161725 ("chr12_GenotypeGVCFs") has been submitted
# Your job 1161726 ("chr13_GenotypeGVCFs") has been submitted
# Your job 1161727 ("chr14_GenotypeGVCFs") has been submitted
# Your job 1161728 ("chr15_GenotypeGVCFs") has been submitted
# Your job 1161729 ("chr16_GenotypeGVCFs") has been submitted
# Your job 1161730 ("chr17_GenotypeGVCFs") has been submitted
# Your job 1161731 ("chr18_GenotypeGVCFs") has been submitted
# Your job 1161732 ("chr19_GenotypeGVCFs") has been submitted
# Your job 1161733 ("chr20_GenotypeGVCFs") has been submitted
# Your job 1161734 ("chr21_GenotypeGVCFs") has been submitted
# Your job 1161735 ("chr22_GenotypeGVCFs") has been submitted
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr1/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr2/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr3/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr4/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr5/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr6/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr7/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr8/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr9/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr10/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr11/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr12/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr13/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr14/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr15/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr16/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr17/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr18/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr19/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr20/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr21/BRCA/Blood_Normal': No such file or directory
# rm: cannot remove '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr22/BRCA/Blood_Normal': No such file or directory

# %% [markdown]
# #### Check number of files output

# %%
# %%bash
#
# PROJECT=nimblegen_capture_NOV19
# CANCER_NAME=BRCA
#
# for TISSUE in Blood_Normal
# do
# 	for i in {1..22}; do echo "chr"${i} ${TISSUE}; ls /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/${PROJECT}_chr${i}/${CANCER_NAME}/${TISSUE}/*vcf |wc -l ;ls /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/${PROJECT}_chr${i}/${CANCER_NAME}/${TISSUE}/*idx | wc -l;done;
# done
# Out:
# chr1 Blood_Normal
# 1
# 1
# chr2 Blood_Normal
# 1
# 1
# chr3 Blood_Normal
# 1
# 1
# chr4 Blood_Normal
# 1
# 1
# chr5 Blood_Normal
# 1
# 1
# chr6 Blood_Normal
# 1
# 1
# chr7 Blood_Normal
# 1
# 1
# chr8 Blood_Normal
# 1
# 1
# chr9 Blood_Normal
# 1
# 1
# chr10 Blood_Normal
# 1
# 1
# chr11 Blood_Normal
# 1
# 1
# chr12 Blood_Normal
# 1
# 1
# chr13 Blood_Normal
# 1
# 1
# chr14 Blood_Normal
# 1
# 1
# chr15 Blood_Normal
# 1
# 1
# chr16 Blood_Normal
# 1
# 1
# chr17 Blood_Normal
# 1
# 1
# chr18 Blood_Normal
# 1
# 1
# chr19 Blood_Normal
# 1
# 1
# chr20 Blood_Normal
# 1
# 1
# chr21 Blood_Normal
# 1
# 1
# chr22 Blood_Normal
# 1
# 1

# %% [markdown]
# #### Once GenotypeGVCFs output confirmed, delete combined GVCFs to conserve space

# %% [markdown]
# ### 5. Run CatVariants on genotyped GVCFs to combine all chromosomes

# %% [markdown]
# ##### Both together

# %%
# %%bash
#
# PROJECT=nimblegen_capture_NOV19
# CANCER_NAME=BRCA
#
# mkdir -p /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/${PROJECT}_all_chr/${CANCER_NAME}/
#
# for TISSUE in Blood_Normal
# do
#     VCFS_LIST=''
#
#     for VCF in `ls -v /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/${PROJECT}_chr*/${CANCER_NAME}/${TISSUE}/BlackWhite.vcf`;
#
#         do
#             VCFS_LIST="${VCFS_LIST} --variant ${VCF}"  ;
#          done;
#
# 	java -cp /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar org.broadinstitute.gatk.tools.CatVariants -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa ${VCFS_LIST} -out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/${PROJECT}_all_chr/${CANCER_NAME}/${TISSUE}_BlackWhite.vcf
# done
# Out:
# .........10.........20..
# There were no warn messages.
# INFO  13:21:35,769 HelpFormatter - -------------------------------------------------------
# INFO  13:21:35,771 HelpFormatter - Program Name: org.broadinstitute.gatk.tools.CatVariants
# INFO  13:21:35,774 HelpFormatter - Program Args: -R /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr1/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr2/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr3/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr4/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr5/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr6/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr7/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr8/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr9/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr10/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr11/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr12/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr13/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr14/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr15/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr16/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr17/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/nimblegen_capture_NOV19_chr18/BRCA/Blood_Normal/BlackWhite.vcf --variant /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVC ...
# INFO  13:21:35,780 HelpFormatter - Executing as m187735@mforgehn2.mayo.edu on Linux 3.10.0-1160.42.2.el7.x86_64 amd64; OpenJDK 64-Bit Server VM 1.8.0_302-b08.
# INFO  13:21:35,781 HelpFormatter - Date/Time: 2021/11/19 13:21:35
# INFO  13:21:35,781 HelpFormatter - -------------------------------------------------------
# INFO  13:21:35,781 HelpFormatter - -------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Done. ------------------------------------------------------------------------------------------

# %% [markdown]
# ### 5. Run VQSR

# %%
# %%bash
#
#
# CANCER_NAME=BRCA
# TISSUE=Blood_Normal
# PROJECT=nimblegen_capture_NOV19_all_chr
#
#
# #create directory for output
# OUTPUT_DIR=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}
# #rm -r $OUTPUT_DIR #delete if already exists
# mkdir -p $OUTPUT_DIR
# mkdir -p /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/VQSR_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}
#
# INPUT_DIR=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/GenotypeGVCFs_on_TCGA/${PROJECT}/${CANCER_NAME}/
#
# #set VQSR variables
# REF=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/GRCh38.d1.vd1.fa
# HAPMAP=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/VQSR/hapmap_3.3.hg38.vcf.gz
# OMNI=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/VQSR/1000G_omni2.5.hg38.vcf.gz
# G1000=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/VQSR/1000G_phase1.snps.high_confidence.hg38.vcf.gz
# DBSNP=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/VQSR/Homo_sapiens_assembly38.dbsnp138.vcf
# MILLS=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/VQSR/Mills_and_1000G_gold_standard.indels.hg38.vcf.gz
#
#
# #for GROUP in {${TISSUE}_Black,${TISSUE}_White}; #NOTE: REPLACED ALL INSTANCES OF ${GROUP} WITH ${TISSUE}_BlackWhite
# #	do
#
# 		INPUT=${INPUT_DIR}/${TISSUE}_BlackWhite.vcf
#
# 		############################
# 		#SNPs############
# 		############################
# 		echo "java -Xmx10g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T VariantRecalibrator -R ${REF} -input ${INPUT} -tranche 100.0 -tranche 99.9 -tranche 99.0 -tranche 90.0 -mode SNP -an QD -an MQ -an MQRankSum -an ReadPosRankSum -an FS -an SOR -an InbreedingCoeff -resource:hapmap,VCF,known=false,training=true,truth=true,prior=15.0 ${HAPMAP} -resource:omni,known=false,training=true,truth=true,prior=12.0 ${OMNI} -resource:1000G,known=false,training=true,truth=false,prior=10.0 ${G1000} -resource:dbsnp,known=true,training=false,truth=false,prior=2.0 ${DBSNP} -recalFile ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_recalibrate_SNPs -tranchesFile ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_tranches_SNPs -rscriptFile ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_VQSR_SNPs_only.plots.R --disable_auto_index_creation_and_locking_when_reading_rods --target_titv 3.2
#
# 		java -Xmx10g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T ApplyRecalibration -R ${REF} -input ${INPUT} -o ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_VQSR_SNPs_only.vcf  -nt 5 -recalFile ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_recalibrate_SNPs -tranchesFile ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_tranches_SNPs --ts_filter_level 99.5 -mode SNP" > /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/VQSR_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/${TISSUE}_BlackWhite.qsub
#
#
# 		############################
# 		#INDELs############
# 		############################
# 		echo "java -Xmx10g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T VariantRecalibrator -R ${REF} -input ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_VQSR_SNPs_only.vcf -tranche 100.0 -tranche 99.9 -tranche 99.0 -tranche 90.0 -mode INDEL -an QD -an MQRankSum -an ReadPosRankSum -an FS -an SOR -an InbreedingCoeff --maxGaussians 4 -resource:mills,known=false,training=true,truth=true,prior=12.0 ${MILLS} -resource:dbsnp,known=true,training=false,truth=false,prior=2.0 ${DBSNP} -recalFile ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_VQSR_SNPs_recalibrate_INDELs -tranchesFile ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_VQSR_SNPs_tranches_INDELs --disable_auto_index_creation_and_locking_when_reading_rods
#
#
# 		java -Xmx10g -jar /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/GenomeAnalysisTK.jar -T ApplyRecalibration -R ${REF} -input ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_VQSR_SNPs_only.vcf -o ${OUTPUT_DIR}/${TISSUE}_BlackWhite_final_VQSR.vcf -recalFile ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_VQSR_SNPs_recalibrate_INDELs -tranchesFile ${OUTPUT_DIR}/${TISSUE}_BlackWhite.vcf_VQSR_SNPs_tranches_INDELs --ts_filter_level 99 -mode INDEL" >> /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/VQSR_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/${TISSUE}_BlackWhite.qsub
#
#
# 		#submit job
# 		rm /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/VQSR_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/${TISSUE}_BlackWhite.err 2> /dev/null
# 		rm /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/VQSR_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/${TISSUE}_BlackWhite.out 2> /dev/null
#
# 		qsub -l h_vmem=20G -e /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/VQSR_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/${TISSUE}_BlackWhite.err -o /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/VQSR_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/${TISSUE}_BlackWhite.out -q 4-day -pe threaded 6 -N VQSR_${PROJECT} /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/VQSR_on_TCGA/${PROJECT}/${CANCER_NAME}/${TISSUE}/${TISSUE}_BlackWhite.qsub;
# Out:
# Your job 1161946 ("VQSR_nimblegen_capture_NOV19_all_chr") has been submitted

# %% [markdown]
# ## DATA PROCESSING AND ANALYSIS

# %% [markdown]
# ###  1. Split VQSR file by chromosome to speed up analysis
# • This will take ~20 minutes
# • Note the need to rename sample IDs in VCF header. This is to facilitate matching of sample IDs in VCF (current format: H_LS-3C-AALK-10A-01D-A41F-09) to sample IDs in the master table file (current format: TCGA-3C-AALK) that's based on TCGA metdata. Matching IDs is necessary so that the low-coverage, medium-coverage and high-coverage samples from the master table can be extracted separately from the plink MAF file that's generated from the VCFs.
# • Also note that the bam file had an irregular name for one of the samples that does not resemble its true TCGA ID, hence the manual substitution.

# %%
# %%bash
#
# PROJECT=nimblegen_capture_NOV19
# CANCER_NAME=BRCA
#
# for TISSUE in Blood_Normal;
#     do
#         VQSR_OUTPUT_FILE=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/${PROJECT}_all_chr/${CANCER_NAME}/${TISSUE}/${TISSUE}_BlackWhite_final_VQSR.vcf;
#
#                for i in {1..22};
#                     do
#                         mkdir -p `dirname ${VQSR_OUTPUT_FILE}`/chr${i}
#
#                         cat <(grep -v ^## ${VQSR_OUTPUT_FILE} |  head -n1 | sed 's/H_LS/TCGA/g' | sed 's/Pooled_DNA-2011-03/TCGA-AQ-A04L/' | sed 's/\t/\n/g' | cut -d '-' -f1-3 | sed 's/\n/\t/g' | tr '\n' '\t') <(echo) <(awk -v CHR=$i '$1=="chr"CHR' ${VQSR_OUTPUT_FILE}) > `dirname ${VQSR_OUTPUT_FILE}`/chr${i}/`basename ${VQSR_OUTPUT_FILE} .vcf`_chr.vcf &
#                     done;
#
#     done

# %% [markdown]
# ### 2. Subset the PASS variants and annotate using Annovar (including population allele frequencies)

# %%
# %%bash
#
# for i in {1..22}; do
#
#     CANCER_NAME=BRCA
#     TISSUE=Blood_Normal
#     PROJECT=nimblegen_capture_NOV19_all_chr/${CANCER_NAME}/${TISSUE}/chr${i}
#
#     #create directory for output
#     OUTPUT_DIR=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/${PROJECT}/
#     #rm -r $OUTPUT_DIR #delete if already exists
#     mkdir -p $OUTPUT_DIR
#     mkdir -p /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/annotate_PASS_TCGA/${PROJECT}
#
#     INPUT_DIR=/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/VQSR_on_TCGA/${PROJECT}/
#
#
#     INPUT=${INPUT_DIR}/${TISSUE}_BlackWhite_final_VQSR_chr.vcf
#
#     INPUT_PASS=${OUTPUT_DIR}/`basename ${INPUT} .vcf`_PASS.vcf
#
#     echo "awk '/#/ || /PASS/' ${INPUT}> ${INPUT_PASS}
#
#     cd /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/annovar/
#
#     perl /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/annovar/table_annovar.pl ${INPUT_PASS} humandb -buildver hg38 --out ${INPUT_PASS} -remove -protocol refGene,dbnsfp30a,EUR.sites.2015_08,AFR.sites.2015_08 -operation gx,f,f,f -nastring . -vcfinput " > /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/annotate_PASS_TCGA/${PROJECT}/BlackWhite.qsub;
#
#
#
#
#     rm /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/annotate_PASS_TCGA/${PROJECT}/*err 2> /dev/null
#     rm /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/annotate_PASS_TCGA/${PROJECT}/*out 2> /dev/null;
#
#     for file in /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/annotate_PASS_TCGA/${PROJECT}/*qsub; do qsub -l h_vmem=20G -e /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/annotate_PASS_TCGA/${PROJECT}/`basename ${file} .qsub`.err -o /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/annotate_PASS_TCGA/${PROJECT}/`basename ${file} .qsub`.out -q 1-day -pe threaded 4 -N `basename ${PROJECT}`_annotate $file;done;
# done
# Out:
# Your job 1162508 ("chr1_annotate") has been submitted
# Your job 1162509 ("chr2_annotate") has been submitted
# Your job 1162510 ("chr3_annotate") has been submitted
# Your job 1162511 ("chr4_annotate") has been submitted
# Your job 1162512 ("chr5_annotate") has been submitted
# Your job 1162513 ("chr6_annotate") has been submitted
# Your job 1162514 ("chr7_annotate") has been submitted
# Your job 1162515 ("chr8_annotate") has been submitted
# Your job 1162516 ("chr9_annotate") has been submitted
# Your job 1162517 ("chr10_annotate") has been submitted
# Your job 1162518 ("chr11_annotate") has been submitted
# Your job 1162519 ("chr12_annotate") has been submitted
# Your job 1162520 ("chr13_annotate") has been submitted
# Your job 1162521 ("chr14_annotate") has been submitted
# Your job 1162522 ("chr15_annotate") has been submitted
# Your job 1162523 ("chr16_annotate") has been submitted
# Your job 1162524 ("chr17_annotate") has been submitted
# Your job 1162525 ("chr18_annotate") has been submitted
# Your job 1162526 ("chr19_annotate") has been submitted
# Your job 1162527 ("chr20_annotate") has been submitted
# Your job 1162528 ("chr21_annotate") has been submitted
# Your job 1162529 ("chr22_annotate") has been submitted

# %% [markdown]
# #### If black and white genotyped together, must now create separated VCFs for each race

# %%
# %%bash
#
# PROJECT=nimblegen_capture_NOV19
# for TISSUE in Blood_Normal;
#    do
#     for RACE in Black White;
#         do
#             for i in {1..22};
#                 do
#                     cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/bams_lists_hg38/${PROJECT}_chr${i}/BRCA_gvcf_list_${TISSUE}_${RACE}.txt | cut -d '/' -f14 | sed 's/\.g\.vcf//g' | cut -d '-' -f1-3> /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/${PROJECT}_all_chr/BRCA/${TISSUE}/chr${i}/${RACE}_sample_list.txt
#
#
#                     /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/vcftools_0.1.13/bin/vcftools --vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/${PROJECT}_all_chr/BRCA/${TISSUE}/chr${i}/${TISSUE}_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf --keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/${PROJECT}_all_chr/BRCA/${TISSUE}/chr${i}/${RACE}_sample_list.txt --recode --recode-INFO-all --out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/${PROJECT}_all_chr/BRCA/${TISSUE}/chr${i}/${TISSUE}_BlackWhite_${RACE}_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
#                 done;
#         done;
#     done;
# Out:
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr1/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr1/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr1/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 39253 out of a possible 39253 Sites
# Run Time = 33.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr2/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr2/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr2/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 26840 out of a possible 26840 Sites
# Run Time = 22.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr3/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr3/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr3/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 21191 out of a possible 21191 Sites
# Run Time = 17.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr4/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr4/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr4/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 14539 out of a possible 14539 Sites
# Run Time = 12.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr5/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr5/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr5/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 16687 out of a possible 16687 Sites
# Run Time = 14.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr6/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr6/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr6/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 18324 out of a possible 18324 Sites
# Run Time = 15.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr7/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr7/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr7/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 19736 out of a possible 19736 Sites
# Run Time = 16.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr8/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr8/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr8/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 13466 out of a possible 13466 Sites
# Run Time = 11.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr9/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr9/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr9/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 16824 out of a possible 16824 Sites
# Run Time = 13.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr10/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr10/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr10/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 15498 out of a possible 15498 Sites
# Run Time = 13.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr11/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr11/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr11/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 24046 out of a possible 24046 Sites
# Run Time = 20.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr12/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr12/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr12/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 19384 out of a possible 19384 Sites
# Run Time = 17.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr13/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr13/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr13/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 6575 out of a possible 6575 Sites
# Run Time = 5.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr14/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr14/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr14/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 13627 out of a possible 13627 Sites
# Run Time = 12.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr15/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr15/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr15/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 12917 out of a possible 12917 Sites
# Run Time = 10.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr16/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr16/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr16/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 18668 out of a possible 18668 Sites
# Run Time = 14.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr17/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr17/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr17/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 23123 out of a possible 23123 Sites
# Run Time = 20.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr18/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr18/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr18/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 5983 out of a possible 5983 Sites
# Run Time = 5.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr19/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr19/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr19/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 30327 out of a possible 30327 Sites
# Run Time = 26.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr20/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr20/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr20/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 10401 out of a possible 10401 Sites
# Run Time = 9.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr21/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr21/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr21/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 5103 out of a possible 5103 Sites
# Run Time = 4.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr22/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr22/Black_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr22/Blood_Normal_BlackWhite_Black_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 161 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 9769 out of a possible 9769 Sites
# Run Time = 9.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr1/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr1/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr1/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 39253 out of a possible 39253 Sites
# Run Time = 67.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr2/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr2/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr2/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 26840 out of a possible 26840 Sites
# Run Time = 46.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr3/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr3/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr3/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 21191 out of a possible 21191 Sites
# Run Time = 39.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr4/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr4/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr4/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 14539 out of a possible 14539 Sites
# Run Time = 24.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr5/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr5/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr5/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 16687 out of a possible 16687 Sites
# Run Time = 30.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr6/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr6/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr6/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 18324 out of a possible 18324 Sites
# Run Time = 32.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr7/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr7/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr7/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 19736 out of a possible 19736 Sites
# Run Time = 33.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr8/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr8/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr8/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 13466 out of a possible 13466 Sites
# Run Time = 21.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr9/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr9/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr9/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 16824 out of a possible 16824 Sites
# Run Time = 27.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr10/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr10/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr10/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 15498 out of a possible 15498 Sites
# Run Time = 25.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr11/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr11/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr11/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 24046 out of a possible 24046 Sites
# Run Time = 40.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr12/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr12/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr12/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 19384 out of a possible 19384 Sites
# Run Time = 33.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr13/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr13/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr13/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 6575 out of a possible 6575 Sites
# Run Time = 10.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr14/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr14/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr14/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 13627 out of a possible 13627 Sites
# Run Time = 23.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr15/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr15/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr15/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 12917 out of a possible 12917 Sites
# Run Time = 21.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr16/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr16/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr16/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 18668 out of a possible 18668 Sites
# Run Time = 32.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr17/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr17/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr17/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 23123 out of a possible 23123 Sites
# Run Time = 40.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr18/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr18/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr18/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 5983 out of a possible 5983 Sites
# Run Time = 10.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr19/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr19/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr19/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 30327 out of a possible 30327 Sites
# Run Time = 51.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr20/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr20/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr20/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 10401 out of a possible 10401 Sites
# Run Time = 18.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr21/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr21/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr21/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 5103 out of a possible 5103 Sites
# Run Time = 9.00 seconds
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr22/Blood_Normal_BlackWhite_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--keep /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr22/White_sample_list.txt
# 	--recode-INFO-all
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/nimblegen_capture_NOV19_all_chr/BRCA/Blood_Normal/chr22/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf
# 	--recode
#
# Keeping individuals in 'keep' list
# After filtering, kept 580 out of 742 Individuals
# Outputting VCF file...
# After filtering, kept 9769 out of a possible 9769 Sites
# Run Time = 16.00 seconds

# %% [markdown]
# ### 3. Downsample Whites so that have equivalent number of both racial groups (optional)

# %%
# %%R
#
# PREFIX <- 'nimblegen_capture_NOV19'
#
# for (CHROM in seq(1,22)){
#
#   HEADER <- system(paste0("grep -v ^## /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/",PREFIX,"_all_chr/BRCA/Blood_Normal/chr",CHROM,"/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf.recode.vcf | head -n1"),intern = TRUE)
#   HEADER <- strsplit(HEADER,split="\t")[[1]]
#
#   VCF <- read.table(paste0("/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/",PREFIX,"_all_chr/BRCA/Blood_Normal/chr",CHROM,"/Blood_Normal_BlackWhite_White_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf.recode.vcf"),sep='\t',header=FALSE)
#
#   names(VCF) <- HEADER
#
#
#   NUMBER_TO_SELECT = 161
#
#   set.seed(10) #to ensure same ones selected for each chromosome VCF!
#
#   RANDOM_VCFS <- sample(names(VCF)[grepl('TCGA',names(VCF))],size = NUMBER_TO_SELECT)
#
#
#   VCF <- cbind(VCF[names(VCF)[!grepl('TCGA',names(VCF))]],VCF[,RANDOM_VCFS])
#
#   write.table(VCF,paste0("/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/annotate_PASS_TCGA/",PREFIX,"_all_chr/BRCA/Blood_Normal/chr",CHROM,"/Blood_Normal_BlackWhite_White_DOWNSAMPLED_final_VQSR_chr_PASS.vcf.hg38_multianno.vcf.recode.vcf"),sep='\t',row.names=FALSE,quote=FALSE)
# }

# %% [markdown]
# ### 4. Retrieve the population-level (1000 Genomes) MAFs and calculate per-locus depths (DP) (BY COVERAGE LEVEL) from annotated VCFs
# - Keep all BIALLELIC loci, regardless of VQSLOD and genotype

# %% [markdown]
# #### Script: [extract_annotated_population_MAFs_cohort_DPs_and_MAFs_by_coverage_level.R](./Scripts/extract_annotated_population_MAFs_cohort_DPs_and_MAFs_by_coverage_level.R)

# %%
# %%bash
#
# PROJECT=nimblegen_capture_NOV19
# CANCER_NAME=BRCA
#
#
# for TISSUE in Blood_Normal
#     do
#     PREFIX=${PROJECT}_all_chr/${CANCER_NAME}/${TISSUE}/chr
#     for i in {1..22};
#         do
#             for RACE in BlackWhite_White_DOWNSAMPLED;
#
#                 do
#            echo "/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/R-3.6.2/bin/Rscript --vanilla /home/mayo/m187735/s212975.Wickland_Immunomics/GitHub/Racial_Disparities_in_Exome_Read_Depth/Scripts/extract_annotated_population_MAFs_cohort_DPs_and_MAFs_by_coverage_level.R ${PREFIX}${i} ${RACE} ${TISSUE}" | qsub -l h_vmem=1G -e /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/annotate_PASS_TCGA/${PREFIX}${i}/${TISSUE}_${RACE}_population_MAF_cohort_DPs_and_MAFs_by_coverage_level.err -o /home/mayo/m187735/s212975.Wickland_Immunomics/commands_to_qsub/TCGA/annotate_PASS_TCGA/${PREFIX}${i}/${TISSUE}_${RACE}_population_MAF_cohort_DPs_and_MAFs_by_coverage_level.out -N  extr_chr${i}_${RACE} -q 1-day,4-day,lg-mem -pe threaded 1
#                 done;
#         done;
#     done
# Out:
# Your job 1433035 ("extr_chr1_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433036 ("extr_chr2_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433037 ("extr_chr3_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433038 ("extr_chr4_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433039 ("extr_chr5_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433040 ("extr_chr6_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433041 ("extr_chr7_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433042 ("extr_chr8_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433043 ("extr_chr9_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433044 ("extr_chr10_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433045 ("extr_chr11_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433046 ("extr_chr12_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433047 ("extr_chr13_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433048 ("extr_chr14_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433049 ("extr_chr15_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433050 ("extr_chr16_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433051 ("extr_chr17_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433052 ("extr_chr18_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433053 ("extr_chr19_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433054 ("extr_chr20_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433055 ("extr_chr21_BlackWhite_White_DOWNSAMPLED") has been submitted
# Your job 1433056 ("extr_chr22_BlackWhite_White_DOWNSAMPLED") has been submitted

# %% [markdown]
# ### 4. Extract *all* 1000 Genomes positions from common capture region; want to compare Black vs. White MAF in that region

# %%
# %%bash
#
#  awk '{print "chr"$1,$2,$3,$4,$5}' OFS="\t" /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants.vcf > /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf

# %%
# %%bash
#
# mkdir /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region
#
#
# for i in {1..22}; do /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/tools/vcftools_0.1.13/bin/vcftools --vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf --bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr${i}.bed  --recode --out  /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr${i} & done
# Out:
# mkdir: cannot create directory '/research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region': File exists
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr1
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr1.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr4
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr4.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr3
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr3.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr5
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr5.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr6
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr6.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr2
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr2.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr8
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr8.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr12
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr12.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr9
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr9.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr10
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr10.bed
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr7
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr7.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr21
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr21.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr19
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr19.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr11
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr11.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
#
# VCFtools - v0.1.13
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr13
# 	--recode
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr17
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr13.bed
# 	--recode
#
# VCFtools - v0.1.13
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr17.bed
# (C) Adam Auton and Anthony Marcketta 2009
#
#
# VCFtools - v0.1.13
#
# Parameters as interpreted:
# (C) Adam Auton and Anthony Marcketta 2009
#
#
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr22
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr22.bed
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr20
#
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr20.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr14
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr14.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr18
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr18.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr15
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr15.bed
#
#
# VCFtools - v0.1.13
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/1000Genomes/1000Genomes_all_chr_all_variants_nochr.vcf
# 	--out /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr16
# 	--recode
# 	--bed /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/beds/intersection_three_nimblegen_kits_hg38_DW_chr16.bed
#
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# After filtering, kept 0 out of 0 Individuals
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# Outputting VCF file...
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# Outputting VCF file...
# After filtering, kept 0 out of 0 Individuals
# After filtering, kept 0 out of 0 Individuals
# Outputting VCF file...
# Outputting VCF file...
# 	Read 2879 BED file entries.
# 	Read 4214 BED file entries.
# 	Read 9173 BED file entries.
# 	Read 5948 BED file entries.
# 	Read 16960 BED file entries.
# 	Read 11086 BED file entries.
# 	Read 11214 BED file entries.
# 	Read 17619 BED file entries.
# 	Read 13178 BED file entries.
# 	Read 6983 BED file entries.
# 	Read 9380 BED file entries.
# 	Read 15933 BED file entries.
# 	Read 28959 BED file entries.
# 	Read 12938 BED file entries.
# 	Read 16188 BED file entries.
# 	Read 5006 BED file entries.
# 	Read 10856 BED file entries.
# 	Read 8954 BED file entries.
# 	Read 21509 BED file entries.
# 	Read 13099 BED file entries.
# 	Read 14960 BED file entries.
# 	Read 11749 BED file entries.
# After filtering, kept 19023 out of a possible 78122254 Sites
# Run Time = 465.00 seconds
# After filtering, kept 39820 out of a possible 78122254 Sites
# Run Time = 506.00 seconds
# After filtering, kept 23946 out of a possible 78122254 Sites
# Run Time = 588.00 seconds
# After filtering, kept 42418 out of a possible 78122254 Sites
# Run Time = 649.00 seconds
# After filtering, kept 27130 out of a possible 78122254 Sites
# Run Time = 649.00 seconds
# After filtering, kept 51751 out of a possible 78122254 Sites
# Run Time = 767.00 seconds
# After filtering, kept 74680 out of a possible 78122254 Sites
# Run Time = 790.00 seconds
# After filtering, kept 54456 out of a possible 78122254 Sites
# Run Time = 806.00 seconds
# After filtering, kept 113226 out of a possible 78122254 Sites
# Run Time = 917.00 seconds
# After filtering, kept 92050 out of a possible 78122254 Sites
# Run Time = 967.00 seconds
# After filtering, kept 66030 out of a possible 78122254 Sites
# Run Time = 982.00 seconds
# After filtering, kept 56236 out of a possible 78122254 Sites
# Run Time = 988.00 seconds
# After filtering, kept 61958 out of a possible 78122254 Sites
# Run Time = 1054.00 seconds
# After filtering, kept 59659 out of a possible 78122254 Sites
# Run Time = 1138.00 seconds
# After filtering, kept 80185 out of a possible 78122254 Sites
# Run Time = 1177.00 seconds
# After filtering, kept 74951 out of a possible 78122254 Sites
# Run Time = 1195.00 seconds
# After filtering, kept 71430 out of a possible 78122254 Sites
# Run Time = 1202.00 seconds
# After filtering, kept 68144 out of a possible 78122254 Sites
# Run Time = 1209.00 seconds
# After filtering, kept 93585 out of a possible 78122254 Sites
# Run Time = 1257.00 seconds
# After filtering, kept 87320 out of a possible 78122254 Sites
# Run Time = 1637.00 seconds
# After filtering, kept 111542 out of a possible 78122254 Sites
# Run Time = 2356.00 seconds
# After filtering, kept 154548 out of a possible 78122254 Sites
# Run Time = 2901.00 seconds

# %%
# %%bash
#
# for i in {1..22}; do cat /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/chr${i}.recode.vcf >> /research/bsi/projects/PI/tertiary/Asmann_Yan_wangy3/s212975.Wickland_Immunomics/processing/TCGA/processed_data/capture_kit/1000Genomes_within_common_capture_region/1000Genomes_within_common_capture_region_all_chr.vcf;done
